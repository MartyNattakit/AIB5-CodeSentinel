# %%
# --- Google Colab Setup (Cell 0) ---
# This cell installs Ollama, starts the server, and pulls the specific model.

print("Installing necessary Python packages...")
# Remove pandas/numpy/matplotlib/requests/scikit-learn from !pip as they are usually pre-installed
# Adding explicitly to ensure if not present (though they generally are)
# !pip install pandas numpy scikit-learn requests

print("Installing Ollama...")
# Download and execute the Ollama installation script
# !curl -fsSL https://ollama.com/install.sh | sh

import subprocess
import time
import os
import socket
from pathlib import Path

# Set environment variable for Ollama to listen on all interfaces within the Colab VM
# This allows other Colab cells to connect to the Ollama server.
os.environ['OLLAMA_HOST'] = '0.0.0.0'
OLLAMA_PORT = 11434 # Ollama's default API port

print("Ensuring no previous Ollama processes are running...")
# Kill any existing Ollama processes to ensure a clean start
# !pkill ollama || true

print(f"Starting Ollama server on port {OLLAMA_PORT} in background...")
# Start the Ollama server as a background process
ollama_process = subprocess.Popen(["ollama", "serve"],
                                  stdout=subprocess.DEVNULL, # Redirect stdout to /dev/null
                                  stderr=subprocess.DEVNULL, # Redirect stderr to /dev/null
                                  preexec_fn=os.setsid) # Detach from the current process group
print(f"Ollama server process started with PID: {ollama_process.pid}")

print(f"Waiting for Ollama server to become available on port {OLLAMA_PORT}...")
max_wait_time = 90 # seconds (increased for model loading)
start_time = time.time()
server_ready = False

# Loop to check if the Ollama server is responsive
while time.time() - start_time < max_wait_time:
    try:
        # Attempt to create a socket connection to the Ollama server
        with socket.create_connection(('127.0.0.1', OLLAMA_PORT), timeout=1):
            server_ready = True
            break
    except (ConnectionRefusedError, socket.timeout):
        # If connection is refused or times out, check if the Ollama process is still running
        if ollama_process.poll() is not None:
            print(f"Ollama server process died unexpectedly (exit code: {ollama_process.poll()}).")
            print("Please check previous logs for errors or try restarting the runtime.")
            server_ready = False
            break
        print(f"  Still waiting for Ollama... ({int(time.time() - start_time)}s elapsed)")
        time.sleep(5) # Wait 5 seconds before retrying
    except Exception as e:
        print(f"An unexpected error occurred during Ollama startup check: {e}")
        server_ready = False
        break

if not server_ready:
    print(f"Ollama server did not become available on port {OLLAMA_PORT} within {max_wait_time} seconds. Aborting setup.")
    if ollama_process.poll() is None: # If the process is still running, try to terminate it
        ollama_process.terminate()
        print("Attempted to terminate non-responsive Ollama process.")
    raise RuntimeError("Ollama server failed to start or become ready.")
else:
    print(f"Ollama server is now available on port {OLLAMA_PORT}.")

# --- Pull the specific model for this notebook ---
MODEL_NAME = "qwen:7b" # <--- MODEL TO PULL FOR THIS NOTEBOOK
print(f"\nPulling {MODEL_NAME} model...")
# Run the ollama pull command
pull_process = subprocess.run(["ollama", "pull", MODEL_NAME], capture_output=True, text=True)
print(pull_process.stdout)
if pull_process.stderr:
    print("Ollama pull stderr:", pull_process.stderr)
    if "Error" in pull_process.stderr or "failed" in pull_process.stderr.lower():
        raise RuntimeError(f"Failed to pull Ollama model: {pull_process.stderr}")
print(f"{MODEL_NAME} pull complete.")

# Check if model is available (list all downloaded models)
list_process = subprocess.run(["ollama", "list"], capture_output=True, text=True)
print(f"\nAvailable Ollama models after pulling {MODEL_NAME}:")
print(list_process.stdout)
if list_process.stderr:
    print("Ollama list stderr:", list_process.stderr)

# Verify GPU availability with nvidia-smi
print("\nChecking GPU availability with nvidia-smi...")
# !nvidia-smi

# Set the base URL and model name as environment variables for use in subsequent cells
OLLAMA_API_BASE_URL = f"http://127.0.0.1:{OLLAMA_PORT}"
print(f"Set Ollama API base URL for direct requests to: {OLLAMA_API_BASE_URL}")
# %env OLLAMA_MODEL_NAME=$MODEL_NAME
# %env OLLAMA_API_BASE_URL=$OLLAMA_API_BASE_URL
# Out:
# Installing necessary Python packages...
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Installing Ollama...
# >>> Cleaning up old version at /usr/local/lib/ollama
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ######################################################################## 100.0%
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
# Ensuring no previous Ollama processes are running...
# Starting Ollama server on port 11434 in background...
# Ollama server process started with PID: 6866
# Waiting for Ollama server to become available on port 11434...
#   Still waiting for Ollama... (0s elapsed)
# Ollama server is now available on port 11434.
#
# Pulling qwen:7b model...
#
# Ollama pull stderr: pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest
# pulling 87f26aae09c7: 100% ▕██████████████████▏ 4.5 GB
# pulling 7c7b8e244f6a: 100% ▕██████████████████▏ 6.9 KB
# pulling 1da0581fd4ce: 100% ▕██████████████████▏  130 B
# pulling f02dd72bb242: 100% ▕██████████████████▏   59 B
# pulling c0312cf22ef0: 100% ▕██████████████████▏  483 B
# verifying sha256 digest
# writing manifest
# success
#
# qwen:7b pull complete.
#
# Available Ollama models after pulling qwen:7b:
# NAME       ID              SIZE      MODIFIED
# qwen:7b    2091ee8c8d8f    4.5 GB    Less than a second ago
#
#
# Checking GPU availability with nvidia-smi...
# Thu Jun 12 10:16:45 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8              9W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Set Ollama API base URL for direct requests to: http://127.0.0.1:11434
# env: OLLAMA_MODEL_NAME=qwen:7b
# env: OLLAMA_API_BASE_URL=http://127.0.0.1:11434

# %%
# Cell 1: Initialize Client & Confirm Server is Running
import os
import json
import pandas as pd
import numpy as np # Used later for classification_report
import matplotlib.pyplot as plt # Used later for plotting
import requests
import time
import socket
import re

# Use the API base URL from the environment variable set in Cell 0
base_url = os.getenv('OLLAMA_API_BASE_URL')
api_url_generate = f"{base_url}/api/generate" # Direct generate endpoint
api_url_show = f"{base_url}/api/show" # To check model details

print(f"Using Ollama API at: {base_url}")
print(f"Model to use: {os.getenv('OLLAMA_MODEL_NAME')}")


# Confirm server is running and model is accessible (more robust check)
def check_ollama_and_model(base_url, model_name):
    try:
        # Check if Ollama server is generally responsive
        response = requests.get(f"{base_url}/api/tags", timeout=10)
        response.raise_for_status() # Raise an exception for bad status codes
        print("Ollama server is responsive.")

        # Check if the specific model is loaded
        payload = {"name": model_name}
        response = requests.post(api_url_show, json=payload, timeout=10)
        response.raise_for_status()
        print(f"Model '{model_name}' is loaded and accessible.")
        return True
    except requests.exceptions.ConnectionError as e:
        print(f"Error: Could not connect to Ollama server at {base_url}. Please ensure it's running.")
        print(f"Details: {e}")
        return False
    except requests.exceptions.Timeout:
        print(f"Error: Request to Ollama server timed out.")
        return False
    except requests.exceptions.RequestException as e:
        print(f"Error checking Ollama or model: {e}")
        if response:
            print(f"Response status: {response.status_code}")
            print(f"Response body: {response.text}")
        return False

if not check_ollama_and_model(base_url, os.getenv('OLLAMA_MODEL_NAME')):
    raise RuntimeError("Ollama server or model not ready. Please check Cell 0 execution.")
else:
    print("Ollama server and model are ready for use.")

# Note: The OpenAI client (from `openai` library) is not directly used here
# because we're interacting with Ollama's native API via `requests` as set up.
# If you explicitly need `openai` client for `ollama` (e.g., using `ollama run --port 8000`),
# then ensure `base_url` points to that port and the `client` object is initialized.
# Out:
# Using Ollama API at: http://127.0.0.1:11434
# Model to use: qwen:7b
# Ollama server is responsive.
# Model 'qwen:7b' is loaded and accessible.
# Ollama server and model are ready for use.

# %%
# Cell 2: Load Full Prepared Dataset (2400 Samples) and create stratified splits
import pandas as pd
from sklearn.model_selection import train_test_split # We can use this or manual group by

# Load the already-prepared dataset. Adjust path if your file is in Google Drive.
full_df = pd.read_csv('/content/cwe_top5_sampled_with_juliet_none.csv')
total_samples = len(full_df)
print(f"Total samples in full dataset: {total_samples}")

# Validate dataset
print("Validating full dataset...")
expected_cwes = {'CWE121', 'CWE78', 'CWE122', 'CWE190', 'CWE191', 'none'}
assert set(full_df['cwe'].unique()) == expected_cwes, "Unexpected CWE values found!"
assert full_df['code'].notna().all(), "Missing code values found!"

print("\nFull dataset CWE distribution:")
print(full_df['cwe'].value_counts())

# --- Create Stratified Training and Testing Splits ---
# We need 320 samples per class for training (1920 total)
# and 80 samples per class for testing (480 total).

train_split_df = pd.DataFrame()
test_split_df = pd.DataFrame()

# Group by 'cwe' and split each group
for cwe_type in expected_cwes:
    cwe_subset = full_df[full_df['cwe'] == cwe_type].reset_index(drop=True)

    # Ensure there are enough samples for the split
    if len(cwe_subset) < (320 + 80):
        print(f"Warning: Not enough samples for CWE type '{cwe_type}'. Expected at least 400, found {len(cwe_subset)}. This might cause issues.")
        # Handle cases where there might not be 400 samples per class if necessary
        # For now, we'll proceed, but it might result in fewer than 320/80 if data is short.

    # Take the first 320 for training, and next 80 for testing for each CWE type
    train_split_df = pd.concat([train_split_df, cwe_subset.iloc[:320]])
    test_split_df = pd.concat([test_split_df, cwe_subset.iloc[320:320+80]]) # Ensure it's 320+80 if some subsets are smaller

# Shuffle the splits to randomize the order within them, important for training/batching
train_split_df = train_split_df.sample(frac=1, random_state=42).reset_index(drop=True)
test_split_df = test_split_df.sample(frac=1, random_state=42).reset_index(drop=True)


print(f"\nTraining split size: {len(train_split_df)} samples")
print("Training split CWE distribution:")
print(train_split_df['cwe'].value_counts())

print(f"\nTesting split size: {len(test_split_df)} samples")
print("Testing split CWE distribution:")
print(test_split_df['cwe'].value_counts())

print("\nSample code from training split:", train_split_df['code'].iloc[0][:100]) # Truncate for display
print("Sample code from testing split:", test_split_df['code'].iloc[0][:100])

# Display head of splits (optional)
print("\nTrain Split Head:")
print(train_split_df.head())
print("\nTest Split Head:")
print(test_split_df.head())
# Out:
# Total samples in full dataset: 2400
# Validating full dataset...
#
# Full dataset CWE distribution:
# cwe
# CWE121    400
# CWE78     400
# CWE190    400
# CWE191    400
# CWE122    400
# none      400
# Name: count, dtype: int64
#
# Training split size: 1920 samples
# Training split CWE distribution:
# cwe
# CWE122    320
# none      320
# CWE190    320
# CWE191    320
# CWE78     320
# CWE121    320
# Name: count, dtype: int64
#
# Testing split size: 480 samples
# Testing split CWE distribution:
# cwe
# CWE78     80
# none      80
# CWE191    80
# CWE122    80
# CWE121    80
# CWE190    80
# Name: count, dtype: int64
#
# Sample code from training split: #include "std_testcase.h"
# #ifdef _WIN32
# #include <winsock2.h>
# #include <windows.h>
# #include <direct.
# Sample code from testing split: #include "std_testcase.h"
# #include <wchar.h>
# #ifdef _WIN32
# #define COMMAND_INT_PATH "%WINDIR%\\syste
#
# Train Split Head:
#                                                 file     cwe label  \
# 0  CWE122_Heap_Based_Buffer_Overflow__c_CWE129_co...  CWE122  good
# 1                                synthetic_none_21.c    none   NaN
# 2  CWE190_Integer_Overflow__int64_t_fscanf_add_54d.c  CWE190  good
# 3  CWE190_Integer_Overflow__unsigned_int_rand_mul...  CWE190   bad
# 4   CWE190_Integer_Overflow__char_fscanf_preinc_21.c  CWE190   bad
#
#                                                 code
# 0  #include "std_testcase.h"\n#ifdef _WIN32\n#inc...
# 1        void func() { int x = 5; printf("%d", x); }
# 2  #include "std_testcase.h"\n#ifndef OMITBAD\nvo...
# 3  #include "std_testcase.h"\n#ifndef OMITBAD\nst...
# 4  #include "std_testcase.h"\n#ifndef OMITBAD\nst...
#
# Test Split Head:
#                                                 file     cwe label  \
# 0  CWE78_OS_Command_Injection__char_file_w32_spaw...   CWE78  good
# 1                               synthetic_none_334.c    none   NaN
# 2  CWE191_Integer_Underflow__int_listen_socket_pr...  CWE191  good
# 3  CWE122_Heap_Based_Buffer_Overflow__sizeof_stru...  CWE122  good
# 4        CWE191_Integer_Underflow__char_min_sub_11.c  CWE191   bad
#
#                                                 code
# 0  #include "std_testcase.h"\n#include <wchar.h>\...
# 1  int main() { char str[] = "test"; puts(str); r...
# 2  #include "std_testcase.h"\n#ifdef _WIN32\n#inc...
# 3  #include "std_testcase.h"\n#ifndef OMITBAD\nvo...
# 4  #include "std_testcase.h"\n#ifndef OMITBAD\nvo...

# %%
# Cell 3: Define Prompt (Exact from Old Code)
# The prompt is critical for guiding the model's output to your desired JSON format.
prompt = (
    "You are a security analysis tool. Analyze the C source code for vulnerabilities and respond **only** with a JSON object containing 'reason' and 'answer' fields. Do not include any additional text, explanations, or markdown outside the JSON. Use this exact format:\n"
    "{ \"reason\": \"Explanation of vulnerability\", \"answer\": \"CWE121\" }\n"
    "The 'answer' field must be one of: 'CWE121', 'CWE78', 'CWE122', 'CWE190', 'CWE191', or 'none'. Match the 'answer' to the vulnerability type described in the 'reason'. Examples:\n"
    "- Code with `memcpy` without bounds check: { \"reason\": \"Stack-based buffer overflow due to unchecked memcpy\", \"answer\": \"CWE121\" }\n"
    "- Code with `system` using user input: { \"reason\": \"OS command injection via unsanitized input to system\", \"answer\": \"CWE78\" }\n"
    "- Code with `malloc` and overflow: { \"reason\": \"Heap-based buffer overflow due to improper malloc usage\", \"answer\": \"CWE122\" }\n"
    "- Code with large integer multiplication: { \"reason\": \"Integer overflow from unchecked multiplication\", \"answer\": \"CWE190\" }\n"
    "- Code with negative integer decrement: { \"reason\": \"Integer underflow from unchecked decrement\", \"answer\": \"CWE191\" }\n"
    "- Code with no obvious vulnerability: { \"reason\": \"No vulnerability detected\", \"answer\": \"none\" }\n"
    "Here is the code:\n\n"
)

# Apply the prompt to both training and testing splits
train_split_df['full_prompt'] = prompt + "\n\n" + train_split_df['code']
test_split_df['full_prompt'] = prompt + "\n\n" + test_split_df['code']

print("Prompt sample from training split (truncated):", train_split_df['full_prompt'].iloc[0][:500])
print("\nPrompt sample from testing split (truncated):", test_split_df['full_prompt'].iloc[0][:500])
# Out:
# Prompt sample from training split (truncated): You are a security analysis tool. Analyze the C source code for vulnerabilities and respond **only** with a JSON object containing 'reason' and 'answer' fields. Do not include any additional text, explanations, or markdown outside the JSON. Use this exact format:
# { "reason": "Explanation of vulnerability", "answer": "CWE121" }
# The 'answer' field must be one of: 'CWE121', 'CWE78', 'CWE122', 'CWE190', 'CWE191', or 'none'. Match the 'answer' to the vulnerability type described in the 'reason'. Exam
#
# Prompt sample from testing split (truncated): You are a security analysis tool. Analyze the C source code for vulnerabilities and respond **only** with a JSON object containing 'reason' and 'answer' fields. Do not include any additional text, explanations, or markdown outside the JSON. Use this exact format:
# { "reason": "Explanation of vulnerability", "answer": "CWE121" }
# The 'answer' field must be one of: 'CWE121', 'CWE78', 'CWE122', 'CWE190', 'CWE191', or 'none'. Match the 'answer' to the vulnerability type described in the 'reason'. Exam

# %%
# Cell 4: Create Backups directory and initialize response lists
from pathlib import Path
import json
import pandas as pd # Ensure pandas is imported

# Define paths for Colab environment
BACKUP_DIR = Path("/content/CodeSentinel/Backups")
RESULTS_DIR = Path("/content/CodeSentinel/Results/_2")

BACKUP_DIR.mkdir(parents=True, exist_ok=True)
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

# Define backup filenames for each split
MODEL_NAME = os.getenv('OLLAMA_MODEL_NAME').replace(':', '_').replace('/', '-') # Sanitize model name for filename
TRAIN_BACKUP_PATH = BACKUP_DIR / f"Result-{MODEL_NAME}-CWE-train.csv"
TEST_BACKUP_PATH = BACKUP_DIR / f"Result-{MODEL_NAME}-CWE-test.csv"

def save_responses(responses_list, path):
    """Saves a list of raw string responses to a CSV file."""
    print(f"Debug: Responses before saving to {path}:")
    cleaned_responses = []
    for idx, response in enumerate(responses_list):
        if pd.isna(response) or response is None:
            print(f"Response {idx} is invalid (NaN/None), replacing with fallback for saving.")
            response = json.dumps({"reason": "Invalid response", "answer": "none"})
        # Ensure it's a string representation of JSON
        if not isinstance(response, str):
            response = json.dumps(response) # Convert dicts back to string JSON if needed
        print(f"Response {idx}: {response[:100]}... (type: {type(response)})") # Truncate for print
        cleaned_responses.append(response)
    df = pd.DataFrame(cleaned_responses, columns=['raw_response_json_string'])
    df.to_csv(path, index=False)
    print(f"Responses saved to: {path}")

# Start fresh by resetting responses for both splits
training_responses = []
testing_responses = []
print("Response lists reset to empty for fresh start.")
# Out:
# Response lists reset to empty for fresh start.

# %%
# Cell 5: Run Inference Loops for Training and Testing Splits
import requests
import time
import json
import os # Make sure os is imported
from tqdm.notebook import tqdm # For nice progress bars in Colab
from sklearn.metrics import confusion_matrix, classification_report # For evaluation later

# Retrieve API details from environment variables
api_url_generate = f"{os.getenv('OLLAMA_API_BASE_URL')}/api/generate"
MODEL_NAME_FULL = os.getenv('OLLAMA_MODEL_NAME') # The full model name with colon

max_retries = 3
retry_delay = 5  # seconds
debug_mode = False # Set to True for very verbose logging per request (can slow down)

def process_dataframe_for_inference(df_to_process, response_list_target):
    """
    Processes a DataFrame, sends prompts to Ollama, and appends raw responses to a list.
    Handles retries and errors.
    """
    err_logs_local = []
    print(f"\nStarting inference for {len(df_to_process)} samples using model '{MODEL_NAME_FULL}'...")

    for index, row in tqdm(df_to_process.iterrows(), total=len(df_to_process), desc="Processing Samples"):
        attempts = 0
        success = False
        source_code = row['code'] # Use original code from row for prompt construction
        full_prompt_text = row['full_prompt'] # Use the pre-constructed full_prompt

        if debug_mode:
            print(f"\nASKED (Index {index}):")
            print(f"Source (truncated): {source_code[:200]}...")
            print(f"Full Prompt (truncated): {full_prompt_text[:300]}...")

        while attempts < max_retries and not success:
            try:
                if debug_mode:
                    print(f"Attempt {attempts + 1}: Sending request to {api_url_generate}...")
                start_time = time.time()
                payload = {
                    "model": MODEL_NAME_FULL,
                    "prompt": full_prompt_text,
                    "stream": False # We want the full response at once
                }

                if debug_mode:
                    print(f"Payload length: {len(payload['prompt'])} chars")

                response = requests.post(api_url_generate, json=payload, timeout=300) # Increased timeout to 300s (5 min) for large models/prompts
                response.raise_for_status() # Raise an error for bad status codes (4xx or 5xx)

                end_time = time.time()
                full_ollama_response = response.json()
                raw_content = full_ollama_response.get('response', '') # The actual text response from Ollama

                if debug_mode:
                    print(f"Request took {end_time - start_time:.2f} seconds")
                    print(f"Full Ollama JSON response: {json.dumps(full_ollama_response, indent=2)}")
                    print(f"Raw content from 'response' field: {raw_content[:200]}...")

                # Append the raw response string (or full JSON dict if preferred for later parsing)
                # Storing the full JSON dict ensures all metadata is preserved
                response_list_target.append(full_ollama_response)
                success = True

            except requests.RequestException as e:
                attempts += 1
                end_time = time.time()
                log_entry = {
                    "index": index,
                    "error_type": type(e).__name__,
                    "message": str(e),
                    "attempt": attempts,
                    "elapsed_time": end_time - start_time,
                    "response_status_code": getattr(response, 'status_code', 'N/A'),
                    "response_text_preview": getattr(response, 'text', 'No response')[:500]
                }
                err_logs_local.append(log_entry)
                print(f"ERROR at index {index}, attempt {attempts}/{max_retries} : {e}")
                print(f"Request failed after {end_time - start_time:.2f} seconds.")

                if attempts < max_retries:
                    print(f"Retrying in {retry_delay} seconds...")
                    time.sleep(retry_delay)
                else:
                    fallback_response_dict = {
                        "response": json.dumps({"reason": "Failed after max attempts", "answer": "none"}),
                        "status": "error",
                        "error_message": f"Max retries reached: {log_entry['message']}"
                    }
                    response_list_target.append(fallback_response_dict)
                    print(f"Max retries reached for index {index}, stored fallback response.")
            except Exception as e: # Catch any other unexpected errors
                attempts += 1
                end_time = time.time()
                log_entry = {
                    "index": index,
                    "error_type": type(e).__name__,
                    "message": str(e),
                    "attempt": attempts,
                    "elapsed_time": end_time - start_time,
                    "response_status_code": 'N/A', # No response object here
                    "response_text_preview": 'No response due to non-request error'
                }
                err_logs_local.append(log_entry)
                print(f"UNEXPECTED ERROR at index {index}, attempt {attempts}/{max_retries} : {e}")
                if attempts < max_retries:
                    print(f"Retrying in {retry_delay} seconds...")
                    time.sleep(retry_delay)
                else:
                    fallback_response_dict = {
                        "response": json.dumps({"reason": "Failed due to unexpected error", "answer": "none"}),
                        "status": "error",
                        "error_message": f"Unexpected error after max retries: {log_entry['message']}"
                    }
                    response_list_target.append(fallback_response_dict)
                    print(f"Max retries reached for index {index} due to unexpected error, stored fallback.")

    print(f"Inference loop finished. Total errors logged for this run: {len(err_logs_local)}")
    return err_logs_local

# Global error log list
all_err_logs = []

# --- Run inference for Training Split ---
print("--- Running Inference for Training Split ---")
train_err_logs = process_dataframe_for_inference(train_split_df, training_responses)
all_err_logs.extend(train_err_logs)
save_responses(training_responses, TRAIN_BACKUP_PATH)

# --- Run inference for Testing Split ---
print("\n--- Running Inference for Testing Split ---")
test_err_logs = process_dataframe_for_inference(test_split_df, testing_responses)
all_err_logs.extend(test_err_logs)
save_responses(testing_responses, TEST_BACKUP_PATH)

print("\nAll inference tasks complete.")
# Out:
# --- Running Inference for Training Split ---
#
# Starting inference for 1920 samples using model 'qwen:7b'...
# Processing Samples:   0%|          | 0/1920 [00:00<?, ?it/s]
# Inference loop finished. Total errors logged for this run: 0
# Debug: Responses before saving to /content/CodeSentinel/Backups/Result-qwen_7b-CWE-train.csv:
# Response 0: {"model": "qwen:7b", "created_at": "2025-06-12T10:16:57.368369609Z", "response": "It seems you have ... (type: <class 'str'>)
# Response 1: {"model": "qwen:7b", "created_at": "2025-06-12T10:16:58.404620714Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 2: {"model": "qwen:7b", "created_at": "2025-06-12T10:16:59.825546238Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 3: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:01.151430784Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 4: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:02.768796916Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 5: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:03.963393878Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 6: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:05.135701345Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 7: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:06.241277476Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 8: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:07.417222521Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 9: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:08.500781422Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 10: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:09.385301065Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 11: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:10.267500082Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 12: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:12.25211178Z", "response": "{ \"reason\": \"Cod... (type: <class 'str'>)
# Response 13: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:13.892141678Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 14: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:16.960613521Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 15: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:18.31474431Z", "response": "{ \"reason\": \"Cod... (type: <class 'str'>)
# Response 16: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:19.30926709Z", "response": "{ \"reason\": \"No ... (type: <class 'str'>)
# Response 17: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:20.903469248Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 18: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:22.998233661Z", "response": "{ \"reason\": \"Ex... (type: <class 'str'>)
# Response 19: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:27.105040635Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 20: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:29.006634934Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 21: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:30.115691411Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 22: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:31.259637272Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 23: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:32.332771446Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 24: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:38.451130318Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 25: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:39.700800012Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 26: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:40.64920888Z", "response": "{ \"reason\": \"Sta... (type: <class 'str'>)
# Response 27: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:41.848426413Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 28: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:43.142186596Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 29: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:44.23779032Z", "response": "{  \"reason\":  \"S... (type: <class 'str'>)
# Response 30: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:46.190902153Z", "response": "{ \"reason\": \"Ex... (type: <class 'str'>)
# Response 31: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:47.400152688Z", "response": "{ \"reason\": \"Do... (type: <class 'str'>)
# Response 32: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:50.709502197Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 33: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:51.795575449Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 34: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:54.12307777Z", "response": "{ \"reason\": \"Cod... (type: <class 'str'>)
# Response 35: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:55.531479023Z", "response": "{ \"reason\": \"Un... (type: <class 'str'>)
# Response 36: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:57.199724074Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 37: {"model": "qwen:7b", "created_at": "2025-06-12T10:17:59.071294478Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 38: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:00.281743098Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 39: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:02.111655963Z", "response": "{ \"reason\": \"Ou... (type: <class 'str'>)
# Response 40: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:03.196247805Z", "response": "{ \"reason\": \"No... (type: <class 'str'>)
# Response 41: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:04.111744798Z", "response": "{ \"reason\": \"In... (type: <class 'str'>)
# Response 42: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:05.105770314Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 43: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:06.933956052Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 44: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:07.859866948Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 45: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:16.140134636Z", "response": "This code defines ... (type: <class 'str'>)
# Response 46: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:18.701896589Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 47: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:19.833040661Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 48: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:21.038739247Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 49: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:22.433565805Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 50: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:23.361124311Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 51: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:25.356584404Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 52: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:26.294106976Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 53: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:27.682236103Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 54: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:28.90429116Z", "response": "{  \"reason\":  \"C... (type: <class 'str'>)
# Response 55: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:29.915311107Z", "response": "{ \"reason\": \"In... (type: <class 'str'>)
# Response 56: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:31.369032993Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 57: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:33.273478128Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 58: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:34.734514159Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 59: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:36.299119943Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 60: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:37.229134613Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 61: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:38.391089623Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 62: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:40.057712096Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 63: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:41.660390525Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 64: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:43.005953572Z", "response": "{ \"reason\": \"In... (type: <class 'str'>)
# Response 65: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:44.510108569Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 66: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:46.24788845Z", "response": "{ \"reason\": \"Cod... (type: <class 'str'>)
# Response 67: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:47.301698676Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 68: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:49.067185076Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 69: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:50.179216835Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 70: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:51.412424528Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 71: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:52.891301012Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 72: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:54.152425865Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 73: {"model": "qwen:7b", "created_at": "2025-06-12T10:18:55.117763816Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 74: {"model": "qwen:7b", "created_at": "2025-06-12T10:19:03.997086155Z", "response": "The code you provi... (type: <class 'str'>)
# Response 75: {"model": "qwen:7b", "created_at": "2025-06-12T10:19:05.909571123Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 76: {"model": "qwen:7b", "created_at": "2025-06-12T10:19:15.704961514Z", "response": "The code snippet y... (type: <class 'str'>)
# Response 77: {"model": "qwen:7b", "created_at": "2025-06-12T10:19:18.445485773Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 78: {"model": "qwen:7b", "created_at": "2025-06-12T10:19:20.072441286Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 79: {"model": "qwen:7b", "created_at": "2025-06-12T10:19:21.210514071Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 80: {"model": "qwen:7b", "created_at": "2025-06-12T10:19:22.37376036Z", "response": "{ \"reason\": \"Pot... (type: <class 'str'>)
# Response 81: {"model": "qwen:7b", "created_at": "2025-06-12T10:19:23.86452597Z", "response": "{ \"reason\": \"Pot... (type: <class 'str'>)
# Response 82: {"model": "qwen:7b", "created_at": "2025-06-12T10:19:29.594395079Z", "response": "{ \"reason\": \"Mu... (type: <class 'str'>)
# Response 83: {"model": "qwen:7b", "created_at": "2025-06-12T10:19:30.757516882Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 84: {"model": "qwen:7b", "created_at": "2025-06-12T10:19:37.914998558Z", "response": "{ \"reason\": \"Mu... (type: <class 'str'>)
# Response 85: {"model": "qwen:7b", "created_at": "2025-06-12T10:19:39.609909364Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 86: {"model": "qwen:7b", "created_at": "2025-06-12T10:19:44.574321215Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 87: {"model": "qwen:7b", "created_at": "2025-06-12T10:19:46.293528297Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 88: {"model": "qwen:7b", "created_at": "2025-06-12T10:19:51.274582406Z", "response": "{ \"reason\": \"Mu... (type: <class 'str'>)
# Response 89: {"model": "qwen:7b", "created_at": "2025-06-12T10:19:53.092499811Z", "response": "{ \"reason\": \"Us... (type: <class 'str'>)
# Response 90: {"model": "qwen:7b", "created_at": "2025-06-12T10:19:54.288279722Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 91: {"model": "qwen:7b", "created_at": "2025-06-12T10:19:55.424936832Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 92: {"model": "qwen:7b", "created_at": "2025-06-12T10:19:56.399289176Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 93: {"model": "qwen:7b", "created_at": "2025-06-12T10:20:00.020931928Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 94: {"model": "qwen:7b", "created_at": "2025-06-12T10:20:01.752856073Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 95: {"model": "qwen:7b", "created_at": "2025-06-12T10:20:10.126409662Z", "response": "The provided code ... (type: <class 'str'>)
# Response 96: {"model": "qwen:7b", "created_at": "2025-06-12T10:20:14.00415612Z", "response": "{  \"reason\":  \"C... (type: <class 'str'>)
# Response 97: {"model": "qwen:7b", "created_at": "2025-06-12T10:20:15.847367462Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 98: {"model": "qwen:7b", "created_at": "2025-06-12T10:20:16.905562515Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 99: {"model": "qwen:7b", "created_at": "2025-06-12T10:20:17.988174374Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 100: {"model": "qwen:7b", "created_at": "2025-06-12T10:20:19.423575903Z", "response": "{ \"reason\": \"In... (type: <class 'str'>)
# Response 101: {"model": "qwen:7b", "created_at": "2025-06-12T10:20:20.791797172Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 102: {"model": "qwen:7b", "created_at": "2025-06-12T10:20:22.500284812Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 103: {"model": "qwen:7b", "created_at": "2025-06-12T10:20:34.629737582Z", "response": "This C source code... (type: <class 'str'>)
# Response 104: {"model": "qwen:7b", "created_at": "2025-06-12T10:20:36.129736498Z", "response": "{ \"reason\": \"Ex... (type: <class 'str'>)
# Response 105: {"model": "qwen:7b", "created_at": "2025-06-12T10:20:37.342836861Z", "response": "{ \"reason\": \"No... (type: <class 'str'>)
# Response 106: {"model": "qwen:7b", "created_at": "2025-06-12T10:20:38.297396898Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 107: {"model": "qwen:7b", "created_at": "2025-06-12T10:20:45.399933818Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 108: {"model": "qwen:7b", "created_at": "2025-06-12T10:20:46.534940057Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 109: {"model": "qwen:7b", "created_at": "2025-06-12T10:20:47.505242192Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 110: {"model": "qwen:7b", "created_at": "2025-06-12T10:20:51.393556267Z", "response": "{ \"reason\": \"Mu... (type: <class 'str'>)
# Response 111: {"model": "qwen:7b", "created_at": "2025-06-12T10:20:53.109285175Z", "response": "{ \"reason\": \"OS... (type: <class 'str'>)
# Response 112: {"model": "qwen:7b", "created_at": "2025-06-12T10:20:55.401076335Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 113: {"model": "qwen:7b", "created_at": "2025-06-12T10:21:04.156604213Z", "response": "The code you've pr... (type: <class 'str'>)
# Response 114: {"model": "qwen:7b", "created_at": "2025-06-12T10:21:14.792404761Z", "response": "The provided code ... (type: <class 'str'>)
# Response 115: {"model": "qwen:7b", "created_at": "2025-06-12T10:21:15.801621775Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 116: {"model": "qwen:7b", "created_at": "2025-06-12T10:21:17.350746481Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 117: {"model": "qwen:7b", "created_at": "2025-06-12T10:21:19.29799146Z", "response": "{ \"reason\": \"Mul... (type: <class 'str'>)
# Response 118: {"model": "qwen:7b", "created_at": "2025-06-12T10:21:24.325036784Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 119: {"model": "qwen:7b", "created_at": "2025-06-12T10:21:25.343279584Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 120: {"model": "qwen:7b", "created_at": "2025-06-12T10:21:27.21083137Z", "response": "{ \"reason\": \"Use... (type: <class 'str'>)
# Response 121: {"model": "qwen:7b", "created_at": "2025-06-12T10:21:28.639114306Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 122: {"model": "qwen:7b", "created_at": "2025-06-12T10:21:29.678193529Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 123: {"model": "qwen:7b", "created_at": "2025-06-12T10:21:30.946213528Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 124: {"model": "qwen:7b", "created_at": "2025-06-12T10:21:34.670023069Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 125: {"model": "qwen:7b", "created_at": "2025-06-12T10:21:37.148143756Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 126: {"model": "qwen:7b", "created_at": "2025-06-12T10:21:38.142011826Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 127: {"model": "qwen:7b", "created_at": "2025-06-12T10:21:39.296277424Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 128: {"model": "qwen:7b", "created_at": "2025-06-12T10:21:40.941125126Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 129: {"model": "qwen:7b", "created_at": "2025-06-12T10:21:42.711799165Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 130: {"model": "qwen:7b", "created_at": "2025-06-12T10:21:47.666412332Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 131: {"model": "qwen:7b", "created_at": "2025-06-12T10:21:49.154738514Z", "response": "{ \"reason\": \"He... (type: <class 'str'>)
# Response 132: {"model": "qwen:7b", "created_at": "2025-06-12T10:21:50.267432599Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 133: {"model": "qwen:7b", "created_at": "2025-06-12T10:21:51.292669748Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 134: {"model": "qwen:7b", "created_at": "2025-06-12T10:21:52.306733042Z", "response": "{ \"reason\": \"In... (type: <class 'str'>)
# Response 135: {"model": "qwen:7b", "created_at": "2025-06-12T10:21:54.254814323Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 136: {"model": "qwen:7b", "created_at": "2025-06-12T10:21:55.475534695Z", "response": "{ \"reason\": \"Mu... (type: <class 'str'>)
# Response 137: {"model": "qwen:7b", "created_at": "2025-06-12T10:21:56.517596883Z", "response": "{ \"reason\": \"No... (type: <class 'str'>)
# Response 138: {"model": "qwen:7b", "created_at": "2025-06-12T10:21:58.111424036Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 139: {"model": "qwen:7b", "created_at": "2025-06-12T10:21:59.762975398Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 140: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:01.152363871Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 141: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:02.280721713Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 142: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:03.423222312Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 143: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:04.744703718Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 144: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:06.33170082Z", "response": "{ \"reason\": \"Cod... (type: <class 'str'>)
# Response 145: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:08.070221301Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 146: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:08.972303414Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 147: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:10.089651004Z", "response": "{ \"reason\": \"In... (type: <class 'str'>)
# Response 148: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:11.342140602Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 149: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:13.152502423Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 150: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:14.556403865Z", "response": "{ \"reason\": \"In... (type: <class 'str'>)
# Response 151: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:15.348877204Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 152: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:16.688887929Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 153: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:17.626442025Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 154: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:18.850499113Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 155: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:20.513054404Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 156: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:21.879183732Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 157: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:23.146221474Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 158: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:24.278574184Z", "response": "{ \"reason\": \"In... (type: <class 'str'>)
# Response 159: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:26.997503833Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 160: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:28.514689433Z", "response": "{ \"reason\": \"Un... (type: <class 'str'>)
# Response 161: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:29.587248335Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 162: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:30.620848224Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 163: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:31.617721634Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 164: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:33.184013971Z", "response": "{ \"reason\": \"Us... (type: <class 'str'>)
# Response 165: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:42.723880464Z", "response": "This code defines ... (type: <class 'str'>)
# Response 166: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:43.962717431Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 167: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:45.356739723Z", "response": "{ \"reason\": \"No... (type: <class 'str'>)
# Response 168: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:46.197046857Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 169: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:48.622976617Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 170: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:50.475452077Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 171: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:52.757252475Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 172: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:54.279162045Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 173: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:56.500474894Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 174: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:57.82571809Z", "response": "{ \"reason\": \"Sta... (type: <class 'str'>)
# Response 175: {"model": "qwen:7b", "created_at": "2025-06-12T10:22:58.988940732Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 176: {"model": "qwen:7b", "created_at": "2025-06-12T10:23:00.315638188Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 177: {"model": "qwen:7b", "created_at": "2025-06-12T10:23:01.565009511Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 178: {"model": "qwen:7b", "created_at": "2025-06-12T10:23:03.410925988Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 179: {"model": "qwen:7b", "created_at": "2025-06-12T10:23:04.42424316Z", "response": "{ \"reason\": \"Int... (type: <class 'str'>)
# Response 180: {"model": "qwen:7b", "created_at": "2025-06-12T10:23:05.468978852Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 181: {"model": "qwen:7b", "created_at": "2025-06-12T10:23:07.632482272Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 182: {"model": "qwen:7b", "created_at": "2025-06-12T10:23:08.793182187Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 183: {"model": "qwen:7b", "created_at": "2025-06-12T10:23:10.622575226Z", "response": "{ \"reason\": \"Ex... (type: <class 'str'>)
# Response 184: {"model": "qwen:7b", "created_at": "2025-06-12T10:23:11.812925479Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 185: {"model": "qwen:7b", "created_at": "2025-06-12T10:23:13.485245688Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 186: {"model": "qwen:7b", "created_at": "2025-06-12T10:23:14.490090224Z", "response": "{ \"reason\": \"In... (type: <class 'str'>)
# Response 187: {"model": "qwen:7b", "created_at": "2025-06-12T10:23:16.290889525Z", "response": "{ \"reason\": \"Ex... (type: <class 'str'>)
# Response 188: {"model": "qwen:7b", "created_at": "2025-06-12T10:23:18.810357641Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 189: {"model": "qwen:7b", "created_at": "2025-06-12T10:23:21.393220675Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 190: {"model": "qwen:7b", "created_at": "2025-06-12T10:23:24.916621393Z", "response": "{ \"reason\": \"Mu... (type: <class 'str'>)
# Response 191: {"model": "qwen:7b", "created_at": "2025-06-12T10:23:31.453422381Z", "response": "The code you provi... (type: <class 'str'>)
# Response 192: {"model": "qwen:7b", "created_at": "2025-06-12T10:23:32.692637311Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 193: {"model": "qwen:7b", "created_at": "2025-06-12T10:23:39.685223338Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 194: {"model": "qwen:7b", "created_at": "2025-06-12T10:23:41.009217033Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 195: {"model": "qwen:7b", "created_at": "2025-06-12T10:23:42.280010951Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 196: {"model": "qwen:7b", "created_at": "2025-06-12T10:23:43.323342085Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 197: {"model": "qwen:7b", "created_at": "2025-06-12T10:23:44.752489783Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 198: {"model": "qwen:7b", "created_at": "2025-06-12T10:23:45.904299351Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 199: {"model": "qwen:7b", "created_at": "2025-06-12T10:23:47.104030246Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 200: {"model": "qwen:7b", "created_at": "2025-06-12T10:23:48.356686243Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 201: {"model": "qwen:7b", "created_at": "2025-06-12T10:23:49.612844847Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 202: {"model": "qwen:7b", "created_at": "2025-06-12T10:23:51.754524588Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 203: {"model": "qwen:7b", "created_at": "2025-06-12T10:23:55.250780814Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 204: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:01.08026311Z", "response": "{ \"reason\": \"Cod... (type: <class 'str'>)
# Response 205: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:03.771674412Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 206: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:04.89918962Z", "response": "{ \"reason\": \"Sta... (type: <class 'str'>)
# Response 207: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:05.989744392Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 208: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:06.91813387Z", "response": "{ \"reason\": \"Pot... (type: <class 'str'>)
# Response 209: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:08.893467816Z", "response": "{ \"reason\": \"Vu... (type: <class 'str'>)
# Response 210: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:11.001759358Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 211: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:12.294246744Z", "response": "{ \"reason\": \"Do... (type: <class 'str'>)
# Response 212: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:13.424668657Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 213: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:15.658895038Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 214: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:16.908982142Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 215: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:18.132759219Z", "response": "{ \"reason\": \"He... (type: <class 'str'>)
# Response 216: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:27.671101112Z", "response": "This code defines ... (type: <class 'str'>)
# Response 217: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:28.775611877Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 218: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:30.847278535Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 219: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:36.829890284Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 220: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:38.529327075Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 221: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:39.661732227Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 222: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:40.854835927Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 223: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:41.859501028Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 224: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:43.386898279Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 225: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:44.429350311Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 226: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:45.136985068Z", "response": "{ \"reason\": \"No... (type: <class 'str'>)
# Response 227: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:46.99012482Z", "response": "{ \"reason\": \"Cod... (type: <class 'str'>)
# Response 228: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:48.490644281Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 229: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:50.86757748Z", "response": "{ \"reason\": \"Cod... (type: <class 'str'>)
# Response 230: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:53.484614461Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 231: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:54.952807992Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 232: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:55.788827158Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 233: {"model": "qwen:7b", "created_at": "2025-06-12T10:24:57.814184908Z", "response": "{ \"reason\": \"Bo... (type: <class 'str'>)
# Response 234: {"model": "qwen:7b", "created_at": "2025-06-12T10:25:05.344256534Z", "response": "The code is a C pr... (type: <class 'str'>)
# Response 235: {"model": "qwen:7b", "created_at": "2025-06-12T10:25:06.435687519Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 236: {"model": "qwen:7b", "created_at": "2025-06-12T10:25:08.281878045Z", "response": "{ \"reason\": \"Un... (type: <class 'str'>)
# Response 237: {"model": "qwen:7b", "created_at": "2025-06-12T10:25:10.218081284Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 238: {"model": "qwen:7b", "created_at": "2025-06-12T10:25:11.35354078Z", "response": "{ \"reason\": \"Sta... (type: <class 'str'>)
# Response 239: {"model": "qwen:7b", "created_at": "2025-06-12T10:25:13.474087292Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 240: {"model": "qwen:7b", "created_at": "2025-06-12T10:25:15.116850681Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 241: {"model": "qwen:7b", "created_at": "2025-06-12T10:25:21.807204036Z", "response": "The provided code ... (type: <class 'str'>)
# Response 242: {"model": "qwen:7b", "created_at": "2025-06-12T10:25:23.509183461Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 243: {"model": "qwen:7b", "created_at": "2025-06-12T10:25:26.770622165Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 244: {"model": "qwen:7b", "created_at": "2025-06-12T10:25:30.002659945Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 245: {"model": "qwen:7b", "created_at": "2025-06-12T10:25:37.366209514Z", "response": "{ \"reason\": \"Do... (type: <class 'str'>)
# Response 246: {"model": "qwen:7b", "created_at": "2025-06-12T10:25:38.538788618Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 247: {"model": "qwen:7b", "created_at": "2025-06-12T10:25:40.131061129Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 248: {"model": "qwen:7b", "created_at": "2025-06-12T10:25:41.485942154Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 249: {"model": "qwen:7b", "created_at": "2025-06-12T10:25:42.565548722Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 250: {"model": "qwen:7b", "created_at": "2025-06-12T10:25:43.953600085Z", "response": "{ \"reason\": \"In... (type: <class 'str'>)
# Response 251: {"model": "qwen:7b", "created_at": "2025-06-12T10:25:45.23989183Z", "response": "{ \"reason\": \"Pot... (type: <class 'str'>)
# Response 252: {"model": "qwen:7b", "created_at": "2025-06-12T10:25:46.968683939Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 253: {"model": "qwen:7b", "created_at": "2025-06-12T10:25:48.169527042Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 254: {"model": "qwen:7b", "created_at": "2025-06-12T10:25:57.843251412Z", "response": "The code you provi... (type: <class 'str'>)
# Response 255: {"model": "qwen:7b", "created_at": "2025-06-12T10:25:59.060531109Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 256: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:01.673656451Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 257: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:03.059691688Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 258: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:04.675451641Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 259: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:06.068012097Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 260: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:06.99820173Z", "response": "{ \"reason\": \"Sta... (type: <class 'str'>)
# Response 261: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:08.251061204Z", "response": "{ \"reason\": \"Mu... (type: <class 'str'>)
# Response 262: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:09.293264969Z", "response": "{ \"reason\": \"In... (type: <class 'str'>)
# Response 263: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:10.326422661Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 264: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:11.460495442Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 265: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:12.88222869Z", "response": "{ \"reason\": \"Pot... (type: <class 'str'>)
# Response 266: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:13.981670244Z", "response": "{  \"reason\": \"S... (type: <class 'str'>)
# Response 267: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:15.606960378Z", "response": "{ \"reason\": \"OS... (type: <class 'str'>)
# Response 268: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:17.197667686Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 269: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:18.791989719Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 270: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:21.683382654Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 271: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:23.805375951Z", "response": "{ \"reason\": \"Ex... (type: <class 'str'>)
# Response 272: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:26.42400301Z", "response": "{ \"reason\": \"Cod... (type: <class 'str'>)
# Response 273: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:28.148001866Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 274: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:31.407614244Z", "response": "{ \"reason\": \"Mu... (type: <class 'str'>)
# Response 275: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:32.46350667Z", "response": "{ \"reason\": \"Pot... (type: <class 'str'>)
# Response 276: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:33.730188831Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 277: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:36.791556836Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 278: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:44.981377793Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 279: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:46.013374509Z", "response": "{ \"reason\": \"In... (type: <class 'str'>)
# Response 280: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:48.693312644Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 281: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:50.177329905Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 282: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:51.420055832Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 283: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:52.37598056Z", "response": "{ \"reason\": \"Sim... (type: <class 'str'>)
# Response 284: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:53.704749145Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 285: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:55.054193425Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 286: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:56.016194373Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 287: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:57.147369507Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 288: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:58.269219413Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 289: {"model": "qwen:7b", "created_at": "2025-06-12T10:26:59.929690795Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 290: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:00.971015144Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 291: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:01.94885441Z", "response": "{ \"reason\": \"Sta... (type: <class 'str'>)
# Response 292: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:03.063857194Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 293: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:04.475516409Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 294: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:05.52716955Z", "response": "{ \"reason\": \"Sta... (type: <class 'str'>)
# Response 295: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:06.733637567Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 296: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:07.820817371Z", "response": "{ \"reason\": \"In... (type: <class 'str'>)
# Response 297: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:09.196081066Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 298: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:10.508158695Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 299: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:11.579130401Z", "response": "{ \"reason\": \"In... (type: <class 'str'>)
# Response 300: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:13.827949476Z", "response": "{ \"reason\": \"Ex... (type: <class 'str'>)
# Response 301: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:15.166982567Z", "response": "{ \"reason\": \"In... (type: <class 'str'>)
# Response 302: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:16.250567681Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 303: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:17.141506566Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 304: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:18.356133904Z", "response": "{  \"reason\": \"D... (type: <class 'str'>)
# Response 305: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:19.420861973Z", "response": "{ \"reason\": \"In... (type: <class 'str'>)
# Response 306: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:21.104196314Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 307: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:22.596256599Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 308: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:24.184146086Z", "response": "{ \"reason\": \"Un... (type: <class 'str'>)
# Response 309: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:25.847793575Z", "response": "{ \"reason\": \"Ex... (type: <class 'str'>)
# Response 310: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:27.322923711Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 311: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:33.850240051Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 312: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:35.238405098Z", "response": "{ \"reason\": \"Ou... (type: <class 'str'>)
# Response 313: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:38.7868055Z", "response": "{  \"reason\":  \"In... (type: <class 'str'>)
# Response 314: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:40.204713262Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 315: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:41.282789844Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 316: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:42.279579754Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 317: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:43.428959457Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 318: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:45.178340157Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 319: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:46.681786972Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 320: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:47.673564346Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 321: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:49.596513395Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 322: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:51.130545664Z", "response": "{ \"reason\": \"Mu... (type: <class 'str'>)
# Response 323: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:52.521645018Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 324: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:53.838019378Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 325: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:56.435029599Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 326: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:57.798384142Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 327: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:58.541600722Z", "response": "{ \"reason\": \"No... (type: <class 'str'>)
# Response 328: {"model": "qwen:7b", "created_at": "2025-06-12T10:27:59.59912653Z", "response": "{  \"reason\": \"St... (type: <class 'str'>)
# Response 329: {"model": "qwen:7b", "created_at": "2025-06-12T10:28:00.583891375Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 330: {"model": "qwen:7b", "created_at": "2025-06-12T10:28:01.695382835Z", "response": "{ \"reason\": \"No... (type: <class 'str'>)
# Response 331: {"model": "qwen:7b", "created_at": "2025-06-12T10:28:02.567629258Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 332: {"model": "qwen:7b", "created_at": "2025-06-12T10:28:03.581779004Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 333: {"model": "qwen:7b", "created_at": "2025-06-12T10:28:13.863554883Z", "response": "This code defines ... (type: <class 'str'>)
# Response 334: {"model": "qwen:7b", "created_at": "2025-06-12T10:28:14.976383776Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 335: {"model": "qwen:7b", "created_at": "2025-06-12T10:28:16.241733942Z", "response": "{ \"reason\": \"No... (type: <class 'str'>)
# Response 336: {"model": "qwen:7b", "created_at": "2025-06-12T10:28:17.524354383Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 337: {"model": "qwen:7b", "created_at": "2025-06-12T10:28:19.399876322Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 338: {"model": "qwen:7b", "created_at": "2025-06-12T10:28:20.795088897Z", "response": "{ \"reason\": \"Mu... (type: <class 'str'>)
# Response 339: {"model": "qwen:7b", "created_at": "2025-06-12T10:28:22.211869191Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 340: {"model": "qwen:7b", "created_at": "2025-06-12T10:28:23.281914584Z", "response": "{ \"reason\": \"In... (type: <class 'str'>)
# ...
# Response 367: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:07.144070377Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 368: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:08.150610684Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 369: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:10.05332937Z", "response": "{ \"reason\": \"OS ... (type: <class 'str'>)
# Response 370: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:11.254385828Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 371: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:12.463808381Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 372: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:17.210717073Z", "response": "The provided code ... (type: <class 'str'>)
# Response 373: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:18.816505311Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 374: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:21.284105194Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 375: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:22.500158323Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 376: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:24.221492755Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 377: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:24.937940811Z", "response": "{ \"reason\": \"No... (type: <class 'str'>)
# Response 378: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:26.028686891Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 379: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:27.396006949Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 380: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:28.726787846Z", "response": "{ \"reason\": \"He... (type: <class 'str'>)
# Response 381: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:29.657031994Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 382: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:30.49422805Z", "response": "{ \"reason\": \"No ... (type: <class 'str'>)
# Response 383: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:32.071689342Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 384: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:33.331480024Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 385: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:34.780899051Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 386: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:36.251280697Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 387: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:37.299744417Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 388: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:38.197404382Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 389: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:39.369806683Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 390: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:40.434779652Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 391: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:41.547789391Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 392: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:42.711290754Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 393: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:43.707450253Z", "response": "{ \"reason\": \"In... (type: <class 'str'>)
# Response 394: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:44.976191772Z", "response": "{ \"reason\": \"He... (type: <class 'str'>)
# Response 395: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:46.107546592Z", "response": "{  \"reason\": \"H... (type: <class 'str'>)
# Response 396: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:47.643878274Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 397: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:51.117372828Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 398: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:52.190563345Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 399: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:53.474352215Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 400: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:54.862364153Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 401: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:56.440987751Z", "response": "{ \"reason\": \"Ou... (type: <class 'str'>)
# Response 402: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:58.014578465Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 403: {"model": "qwen:7b", "created_at": "2025-06-12T11:31:59.895112396Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 404: {"model": "qwen:7b", "created_at": "2025-06-12T11:32:00.911109526Z", "response": "{ \"reason\": \"In... (type: <class 'str'>)
# Response 405: {"model": "qwen:7b", "created_at": "2025-06-12T11:32:12.076967429Z", "response": "The provided code ... (type: <class 'str'>)
# Response 406: {"model": "qwen:7b", "created_at": "2025-06-12T11:32:13.025371101Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 407: {"model": "qwen:7b", "created_at": "2025-06-12T11:32:13.883482494Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 408: {"model": "qwen:7b", "created_at": "2025-06-12T11:32:15.986163374Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 409: {"model": "qwen:7b", "created_at": "2025-06-12T11:32:17.507157341Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 410: {"model": "qwen:7b", "created_at": "2025-06-12T11:32:18.748935951Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 411: {"model": "qwen:7b", "created_at": "2025-06-12T11:32:20.503292007Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 412: {"model": "qwen:7b", "created_at": "2025-06-12T11:32:27.850725991Z", "response": "{ \"reason\": \"Mu... (type: <class 'str'>)
# Response 413: {"model": "qwen:7b", "created_at": "2025-06-12T11:32:28.97250378Z", "response": "{ \"reason\": \"Sta... (type: <class 'str'>)
# Response 414: {"model": "qwen:7b", "created_at": "2025-06-12T11:32:30.164974755Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 415: {"model": "qwen:7b", "created_at": "2025-06-12T11:32:31.520802018Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 416: {"model": "qwen:7b", "created_at": "2025-06-12T11:32:32.493573481Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 417: {"model": "qwen:7b", "created_at": "2025-06-12T11:32:34.647077769Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 418: {"model": "qwen:7b", "created_at": "2025-06-12T11:32:37.036232872Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 419: {"model": "qwen:7b", "created_at": "2025-06-12T11:32:38.51032428Z", "response": "{ \"reason\": \"Cod... (type: <class 'str'>)
# Response 420: {"model": "qwen:7b", "created_at": "2025-06-12T11:32:39.729882796Z", "response": "{ \"reason\": \"He... (type: <class 'str'>)
# Response 421: {"model": "qwen:7b", "created_at": "2025-06-12T11:32:46.101247661Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 422: {"model": "qwen:7b", "created_at": "2025-06-12T11:32:47.265451463Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 423: {"model": "qwen:7b", "created_at": "2025-06-12T11:32:48.795581421Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 424: {"model": "qwen:7b", "created_at": "2025-06-12T11:32:49.963300285Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 425: {"model": "qwen:7b", "created_at": "2025-06-12T11:32:51.157181139Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 426: {"model": "qwen:7b", "created_at": "2025-06-12T11:32:52.278690102Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 427: {"model": "qwen:7b", "created_at": "2025-06-12T11:32:58.469592696Z", "response": "{ \"reason\": \"Mu... (type: <class 'str'>)
# Response 428: {"model": "qwen:7b", "created_at": "2025-06-12T11:32:59.499052774Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 429: {"model": "qwen:7b", "created_at": "2025-06-12T11:33:10.249577248Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 430: {"model": "qwen:7b", "created_at": "2025-06-12T11:33:11.204120209Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 431: {"model": "qwen:7b", "created_at": "2025-06-12T11:33:12.07532929Z", "response": "{  \"reason\":  \"N... (type: <class 'str'>)
# Response 432: {"model": "qwen:7b", "created_at": "2025-06-12T11:33:13.148941158Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 433: {"model": "qwen:7b", "created_at": "2025-06-12T11:33:14.321560238Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 434: {"model": "qwen:7b", "created_at": "2025-06-12T11:33:15.540167276Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 435: {"model": "qwen:7b", "created_at": "2025-06-12T11:33:16.835765261Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 436: {"model": "qwen:7b", "created_at": "2025-06-12T11:33:18.665164641Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 437: {"model": "qwen:7b", "created_at": "2025-06-12T11:33:19.667862255Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 438: {"model": "qwen:7b", "created_at": "2025-06-12T11:33:21.375844298Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 439: {"model": "qwen:7b", "created_at": "2025-06-12T11:33:22.377374012Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 440: {"model": "qwen:7b", "created_at": "2025-06-12T11:33:23.628685896Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 441: {"model": "qwen:7b", "created_at": "2025-06-12T11:33:25.09784464Z", "response": "{ \"reason\": \"Uns... (type: <class 'str'>)
# Response 442: {"model": "qwen:7b", "created_at": "2025-06-12T11:33:32.847087235Z", "response": "The provided code ... (type: <class 'str'>)
# Response 443: {"model": "qwen:7b", "created_at": "2025-06-12T11:33:38.160732648Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 444: {"model": "qwen:7b", "created_at": "2025-06-12T11:33:45.416767601Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 445: {"model": "qwen:7b", "created_at": "2025-06-12T11:33:47.29907556Z", "response": "{ \"reason\": \"Cod... (type: <class 'str'>)
# Response 446: {"model": "qwen:7b", "created_at": "2025-06-12T11:33:48.435185037Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 447: {"model": "qwen:7b", "created_at": "2025-06-12T11:33:50.157451015Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 448: {"model": "qwen:7b", "created_at": "2025-06-12T11:33:53.990751589Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 449: {"model": "qwen:7b", "created_at": "2025-06-12T11:33:55.242259683Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 450: {"model": "qwen:7b", "created_at": "2025-06-12T11:33:56.676211781Z", "response": "{ \"reason\": \"Mu... (type: <class 'str'>)
# Response 451: {"model": "qwen:7b", "created_at": "2025-06-12T11:33:57.67821675Z", "response": "{ \"reason\": \"Sta... (type: <class 'str'>)
# Response 452: {"model": "qwen:7b", "created_at": "2025-06-12T11:33:59.133668152Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 453: {"model": "qwen:7b", "created_at": "2025-06-12T11:34:00.845654563Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 454: {"model": "qwen:7b", "created_at": "2025-06-12T11:34:02.478851559Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 455: {"model": "qwen:7b", "created_at": "2025-06-12T11:34:03.760266846Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 456: {"model": "qwen:7b", "created_at": "2025-06-12T11:34:04.925133179Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 457: {"model": "qwen:7b", "created_at": "2025-06-12T11:34:06.215559896Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 458: {"model": "qwen:7b", "created_at": "2025-06-12T11:34:07.282742492Z", "response": "{ \"reason\": \"He... (type: <class 'str'>)
# Response 459: {"model": "qwen:7b", "created_at": "2025-06-12T11:34:10.803049526Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 460: {"model": "qwen:7b", "created_at": "2025-06-12T11:34:15.786662176Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 461: {"model": "qwen:7b", "created_at": "2025-06-12T11:34:17.511961039Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 462: {"model": "qwen:7b", "created_at": "2025-06-12T11:34:18.681607086Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 463: {"model": "qwen:7b", "created_at": "2025-06-12T11:34:21.187587389Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 464: {"model": "qwen:7b", "created_at": "2025-06-12T11:34:22.550137283Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 465: {"model": "qwen:7b", "created_at": "2025-06-12T11:34:23.861900315Z", "response": "{ \"reason\": \"Po... (type: <class 'str'>)
# Response 466: {"model": "qwen:7b", "created_at": "2025-06-12T11:34:24.772381174Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 467: {"model": "qwen:7b", "created_at": "2025-06-12T11:34:25.945410063Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 468: {"model": "qwen:7b", "created_at": "2025-06-12T11:34:27.433761105Z", "response": "{  \"reason\":  \"... (type: <class 'str'>)
# Response 469: {"model": "qwen:7b", "created_at": "2025-06-12T11:34:28.429207749Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 470: {"model": "qwen:7b", "created_at": "2025-06-12T11:34:30.14381586Z", "response": "{ \"reason\": \"Sta... (type: <class 'str'>)
# Response 471: {"model": "qwen:7b", "created_at": "2025-06-12T11:34:31.182358131Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 472: {"model": "qwen:7b", "created_at": "2025-06-12T11:34:33.371550653Z", "response": "{ \"reason\": \"Fi... (type: <class 'str'>)
# Response 473: {"model": "qwen:7b", "created_at": "2025-06-12T11:34:34.509223725Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 474: {"model": "qwen:7b", "created_at": "2025-06-12T11:34:37.857134115Z", "response": "{ \"reason\": \"Co... (type: <class 'str'>)
# Response 475: {"model": "qwen:7b", "created_at": "2025-06-12T11:34:43.425044031Z", "response": "{ \"reason\": \"Mu... (type: <class 'str'>)
# Response 476: {"model": "qwen:7b", "created_at": "2025-06-12T11:34:44.925764014Z", "response": "{ \"reason\": \"Us... (type: <class 'str'>)
# Response 477: {"model": "qwen:7b", "created_at": "2025-06-12T11:34:46.246233983Z", "response": "{ \"reason\": \"St... (type: <class 'str'>)
# Response 478: {"model": "qwen:7b", "created_at": "2025-06-12T11:34:47.177116919Z", "response": "{ \"reason\": \"Si... (type: <class 'str'>)
# Response 479: {"model": "qwen:7b", "created_at": "2025-06-12T11:34:48.345076099Z", "response": "{ \"reason\": \"He... (type: <class 'str'>)
# Responses saved to: /content/CodeSentinel/Backups/Result-qwen_7b-CWE-test.csv
#
# All inference tasks complete.

# %%
# Cell 6: Parse and Evaluate Results (Fixed Multi-Class for Both Splits & Standardized Labels)
import re
import json
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np # For formatting confusion matrix

# Function to extract JSON from Ollama's full response object (KEEP THIS AS IS from last fix)
def extract_json_from_ollama_response(ollama_response_dict):
    """
    Extracts the JSON object from Ollama's 'response' field, handling potential malformed JSON.
    Expected input: a dictionary from response.json()
    Expected output: a dictionary {"reason": ..., "answer": ...} or a fallback.
    """
    raw_response_text = ollama_response_dict.get('response', '')
    if not raw_response_text:
        return {"reason": "Empty or missing 'response' field from Ollama", "answer": "none"}

    try:
        # Find the first and last curly braces to extract the JSON string
        start = raw_response_text.find('{')
        end = raw_response_text.rfind('}') + 1

        parsed_json = None
        if start != -1 and end != -1 and start < end:
            json_string = raw_response_text[start:end]
            try:
                parsed_json = json.loads(json_string)
            except json.JSONDecodeError:
                # If substring parse fails, try parsing the whole raw_response_text
                pass # Fall through to next attempt

        if parsed_json is None: # If substring didn't work, or was empty
            try:
                parsed_json = json.loads(raw_response_text)
            except json.JSONDecodeError:
                # If full text parse fails, try fixing quotes
                fixed_text = raw_response_text.replace("'", '"')
                try:
                    parsed_json = json.loads(fixed_text)
                except json.JSONDecodeError:
                    return {"reason": f"Failed to parse JSON even after quote fix: '{raw_response_text}'", "answer": "none"}

        # --- IMPORTANT NEW LOGIC (as in previous fix) ---
        # Handle cases where the model might output JSON wrapped in an array, e.g., '[{"reason":..., "answer":...}]'
        if isinstance(parsed_json, list) and len(parsed_json) > 0 and isinstance(parsed_json[0], dict):
            return parsed_json[0] # Take the first dictionary from the list
        elif isinstance(parsed_json, dict):
            return parsed_json
        else:
            # If it's not a dict and not a list containing a dict, it's an unexpected format
            return {"reason": f"Unexpected final JSON structure after parsing: {type(parsed_json).__name__} | Raw: '{raw_response_text}'", "answer": "none"}

    except Exception as e:
        # Catch any other unexpected errors during the process
        return {"reason": f"Critical error during JSON extraction: {e} | Raw: '{raw_response_text}'", "answer": "none"}

def evaluate_results(df_original, responses_list, data_split_name):
    """
    Processes responses, calculates metrics, and prints evaluation report for a given data split.
    """
    print(f"\n--- Evaluating Results for {data_split_name} Split ({len(responses_list)} samples) ---")

    if not responses_list:
        print(f"No responses to evaluate for {data_split_name} split.")
        return

    # Create a DataFrame for model answers
    model_answers_dicts = [extract_json_from_ollama_response(res_dict) for res_dict in responses_list]
    model_answers_df = pd.DataFrame(model_answers_dicts)

    # Ensure model_answer and model_reason columns exist, providing defaults
    model_answers_df['model_answer_raw'] = model_answers_df['answer'].fillna('none').astype(str)
    model_answers_df['model_reason'] = model_answers_df['reason'].fillna('No reason provided').astype(str)

    # --- NEW LOGIC: Standardize Model Answers ---
    # Define our target labels explicitly
    target_labels = ['CWE121', 'CWE78', 'CWE122', 'CWE190', 'CWE191', 'none']

    def standardize_label(raw_label):
        # Convert to string and uppercase for easier matching
        label = str(raw_label).upper()

        # Check for exact matches
        if label in target_labels:
            return label

        # Check for 'none' variations
        if 'NO VULNERABILITY' in label or 'NONE' == label.strip():
            return 'none'

        # Check for specific CWE patterns
        if 'CWE121' in label:
            return 'CWE121'
        if 'CWE78' in label:
            return 'CWE78'
        if 'CWE122' in label:
            return 'CWE122'
        if 'CWE190' in label:
            return 'CWE190'
        if 'CWE191' in label:
            return 'CWE191'

        # If none of the above, default to 'none' or log it as an issue
        return 'none'

    # Apply the standardization
    model_answers_df['model_answer'] = model_answers_df['model_answer_raw'].apply(standardize_label)

    # Join with the original DataFrame subset to get true labels and other info
    combined_df = df_original.reset_index(drop=True).copy()
    combined_df['model_answer'] = model_answers_df['model_answer']
    combined_df['model_reason'] = model_answers_df['model_reason']
    combined_df['model_answer_raw'] = model_answers_df['model_answer_raw'] # Keep raw for debugging

    # Compute verdict
    combined_df['verdict'] = combined_df['cwe'] == combined_df['model_answer']

    # Compute multi-class metrics
    true_labels = combined_df['cwe']
    pred_labels = combined_df['model_answer']

    # Define all possible labels explicitly for consistent report and matrix
    all_labels = sorted(list(set(target_labels))) # Use target_labels directly for consistency

    # Accuracy (overall accuracy)
    accuracy = combined_df['verdict'].mean()
    print(f"Accuracy ({data_split_name}): {accuracy:.3f}")

    # Confusion Matrix
    cm = confusion_matrix(true_labels, pred_labels, labels=all_labels)
    print(f"\nConfusion Matrix ({data_split_name}):")
    print("Labels order:", all_labels)
    # --- CUSTOM CONFUSION MATRIX PRINTING ---
    cm_list = cm.tolist()
    # Determine maximum width for each number to align columns
    # We add 1 for potential leading space if a number is negative (though unlikely for CM counts)
    max_widths = [max(len(str(item)) for item in col) for col in zip(*cm_list)]

    for row in cm_list:
        formatted_row = []
        for i, item in enumerate(row):
            formatted_row.append(f"{item:>{max_widths[i]}}") # Right-align each number within its max width
        print(f"[{' '.join(formatted_row)}]") # Join with space, wrap in brackets


    # Classification Report
    report = classification_report(true_labels, pred_labels, labels=all_labels, zero_division=0)
    print(f"\nClassification Report ({data_split_name}):")
    print(report)

    # Save filtered results
    output_filename_base = f"Result-{MODEL_NAME}-{data_split_name}-CWE.csv"
    output_path = RESULTS_DIR / output_filename_base
    filtered_df_output = combined_df[['cwe', 'model_answer', 'model_answer_raw', 'verdict', 'model_reason', 'file', 'code']]
    filtered_df_output.to_csv(output_path, index=False)
    print(f"Filtered results saved to '{output_path}'")

# --- Perform evaluation for each split ---
evaluate_results(train_split_df, training_responses, "Training")
evaluate_results(test_split_df, testing_responses, "Testing")

if all_err_logs:
    print("\n--- Consolidated Error Log ---")
    for log_entry in all_err_logs:
        print(f"Index: {log_entry['index']}, Error Type: {log_entry['error_type']}, Message: {log_entry['message']}")
        if log_entry.get('response_status_code') != 'N/A':
            print(f"  Status: {log_entry['response_status_code']}, Preview: {log_entry['response_text_preview']}")
else:
    print("\nNo errors logged during inference.")
# Out:
# --- Evaluating Results for Training Split (1920 samples) ---
# Accuracy (Training): 0.385
#
# Confusion Matrix (Training):
# Labels order: ['CWE121', 'CWE122', 'CWE190', 'CWE191', 'CWE78', 'none']
# [263 16  6  0  14  21]
# [204 59  3  0  18  36]
# [190 17 66  1  11  35]
# [164 13 65 14  16  48]
# [ 73  0  1  0 215  31]
# [196  0  0  0   1 123]
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#       CWE121       0.24      0.82      0.37       320
#       CWE122       0.56      0.18      0.28       320
#       CWE190       0.47      0.21      0.29       320
#       CWE191       0.93      0.04      0.08       320
#        CWE78       0.78      0.67      0.72       320
#         none       0.42      0.38      0.40       320
#
#     accuracy                           0.39      1920
#    macro avg       0.57      0.39      0.36      1920
# weighted avg       0.57      0.39      0.36      1920
#
# Filtered results saved to '/content/CodeSentinel/Results/_2/Result-qwen_7b-Training-CWE.csv'
#
# --- Evaluating Results for Testing Split (480 samples) ---
# Accuracy (Testing): 0.362
#
# Confusion Matrix (Testing):
# Labels order: ['CWE121', 'CWE122', 'CWE190', 'CWE191', 'CWE78', 'none']
# [67  7  1 0  3  2]
# [42 15  1 0  8 14]
# [46  7 11 0  4 12]
# [45  4 15 4  7  5]
# [17  0  0 0 50 13]
# [53  0  0 0  0 27]
#
# Classification Report (Testing):
#               precision    recall  f1-score   support
#
#       CWE121       0.25      0.84      0.38        80
#       CWE122       0.45      0.19      0.27        80
#       CWE190       0.39      0.14      0.20        80
#       CWE191       1.00      0.05      0.10        80
#        CWE78       0.69      0.62      0.66        80
#         none       0.37      0.34      0.35        80
#
#     accuracy                           0.36       480
#    macro avg       0.53      0.36      0.33       480
# weighted avg       0.53      0.36      0.33       480
#
# Filtered results saved to '/content/CodeSentinel/Results/_2/Result-qwen_7b-Testing-CWE.csv'
#
# No errors logged during inference.
