# %%
# --- Google Colab Setup (Cell 0) ---
# This cell installs Ollama, starts the server, and pulls the specific model.

print("Installing necessary Python packages...")
# Remove pandas/numpy/matplotlib/requests/scikit-learn from !pip as they are usually pre-installed
# Adding explicitly to ensure if not present (though they generally are)
# !pip install pandas numpy scikit-learn requests

print("Installing Ollama...")
# Download and execute the Ollama installation script
# !curl -fsSL https://ollama.com/install.sh | sh

import subprocess
import time
import os
import socket
from pathlib import Path

# Set environment variable for Ollama to listen on all interfaces within the Colab VM
# This allows other Colab cells to connect to the Ollama server.
os.environ['OLLAMA_HOST'] = '0.0.0.0'
OLLAMA_PORT = 11434 # Ollama's default API port

print("Ensuring no previous Ollama processes are running...")
# Kill any existing Ollama processes to ensure a clean start
# !pkill ollama || true

print(f"Starting Ollama server on port {OLLAMA_PORT} in background...")
# Start the Ollama server as a background process
ollama_process = subprocess.Popen(["ollama", "serve"],
                                  stdout=subprocess.DEVNULL, # Redirect stdout to /dev/null
                                  stderr=subprocess.DEVNULL, # Redirect stderr to /dev/null
                                  preexec_fn=os.setsid) # Detach from the current process group
print(f"Ollama server process started with PID: {ollama_process.pid}")

print(f"Waiting for Ollama server to become available on port {OLLAMA_PORT}...")
max_wait_time = 90 # seconds (increased for model loading)
start_time = time.time()
server_ready = False

# Loop to check if the Ollama server is responsive
while time.time() - start_time < max_wait_time:
    try:
        # Attempt to create a socket connection to the Ollama server
        with socket.create_connection(('127.0.0.1', OLLAMA_PORT), timeout=1):
            server_ready = True
            break
    except (ConnectionRefusedError, socket.timeout):
        # If connection is refused or times out, check if the Ollama process is still running
        if ollama_process.poll() is not None:
            print(f"Ollama server process died unexpectedly (exit code: {ollama_process.poll()}).")
            print("Please check previous logs for errors or try restarting the runtime.")
            server_ready = False
            break
        print(f"  Still waiting for Ollama... ({int(time.time() - start_time)}s elapsed)")
        time.sleep(5) # Wait 5 seconds before retrying
    except Exception as e:
        print(f"An unexpected error occurred during Ollama startup check: {e}")
        server_ready = False
        break

if not server_ready:
    print(f"Ollama server did not become available on port {OLLAMA_PORT} within {max_wait_time} seconds. Aborting setup.")
    if ollama_process.poll() is None: # If the process is still running, try to terminate it
        ollama_process.terminate()
        print("Attempted to terminate non-responsive Ollama process.")
    raise RuntimeError("Ollama server failed to start or become ready.")
else:
    print(f"Ollama server is now available on port {OLLAMA_PORT}.")

# --- Pull the specific model for this notebook ---
MODEL_NAME = "gemma:2b-instruct-q4_0" # <--- MODEL TO PULL FOR THIS NOTEBOOK
print(f"\nPulling {MODEL_NAME} model...")
# Run the ollama pull command
pull_process = subprocess.run(["ollama", "pull", MODEL_NAME], capture_output=True, text=True)
print(pull_process.stdout)
if pull_process.stderr:
    print("Ollama pull stderr:", pull_process.stderr)
    if "Error" in pull_process.stderr or "failed" in pull_process.stderr.lower():
        raise RuntimeError(f"Failed to pull Ollama model: {pull_process.stderr}")
print(f"{MODEL_NAME} pull complete.")

# Check if model is available (list all downloaded models)
list_process = subprocess.run(["ollama", "list"], capture_output=True, text=True)
print(f"\nAvailable Ollama models after pulling {MODEL_NAME}:")
print(list_process.stdout)
if list_process.stderr:
    print("Ollama list stderr:", list_process.stderr)

# Verify GPU availability with nvidia-smi
print("\nChecking GPU availability with nvidia-smi...")
# !nvidia-smi

# Set the base URL and model name as environment variables for use in subsequent cells
OLLAMA_API_BASE_URL = f"http://127.0.0.1:{OLLAMA_PORT}"
print(f"Set Ollama API base URL for direct requests to: {OLLAMA_API_BASE_URL}")
# %env OLLAMA_MODEL_NAME=$MODEL_NAME
# %env OLLAMA_API_BASE_URL=$OLLAMA_API_BASE_URL
# Out:
# Installing necessary Python packages...
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Installing Ollama...
# >>> Cleaning up old version at /usr/local/lib/ollama
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ######################################################################## 100.0%
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
# Ensuring no previous Ollama processes are running...
# Starting Ollama server on port 11434 in background...
# Ollama server process started with PID: 8078
# Waiting for Ollama server to become available on port 11434...
#   Still waiting for Ollama... (0s elapsed)
# Ollama server is now available on port 11434.
#
# Pulling gemma:2b-instruct-q4_0 model...
#
# Ollama pull stderr: pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest
# pulling c1864a5eb193: 100% ▕██████████████████▏ 1.7 GB
# pulling 097a36493f71: 100% ▕██████████████████▏ 8.4 KB
# pulling 109037bec39c: 100% ▕██████████████████▏  136 B
# pulling 22a838ceb7fb: 100% ▕██████████████████▏   84 B
# pulling 887433b89a90: 100% ▕██████████████████▏  483 B
# verifying sha256 digest
# writing manifest
# success
#
# gemma:2b-instruct-q4_0 pull complete.
#
# Available Ollama models after pulling gemma:2b-instruct-q4_0:
# NAME                      ID              SIZE      MODIFIED
# gemma:2b-instruct-q4_0    b50d6c999e59    1.7 GB    Less than a second ago
#
#
# Checking GPU availability with nvidia-smi...
# Thu Jun 12 10:16:37 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   71C    P8             11W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Set Ollama API base URL for direct requests to: http://127.0.0.1:11434
# env: OLLAMA_MODEL_NAME=gemma:2b-instruct-q4_0
# env: OLLAMA_API_BASE_URL=http://127.0.0.1:11434

# %%
# Cell 1: Initialize Client & Confirm Server is Running
import os
import json
import pandas as pd
import numpy as np # Used later for classification_report
import matplotlib.pyplot as plt # Used later for plotting
import requests
import time
import socket
import re

# Use the API base URL from the environment variable set in Cell 0
base_url = os.getenv('OLLAMA_API_BASE_URL')
api_url_generate = f"{base_url}/api/generate" # Direct generate endpoint
api_url_show = f"{base_url}/api/show" # To check model details

print(f"Using Ollama API at: {base_url}")
print(f"Model to use: {os.getenv('OLLAMA_MODEL_NAME')}")


# Confirm server is running and model is accessible (more robust check)
def check_ollama_and_model(base_url, model_name):
    try:
        # Check if Ollama server is generally responsive
        response = requests.get(f"{base_url}/api/tags", timeout=10)
        response.raise_for_status() # Raise an exception for bad status codes
        print("Ollama server is responsive.")

        # Check if the specific model is loaded
        payload = {"name": model_name}
        response = requests.post(api_url_show, json=payload, timeout=10)
        response.raise_for_status()
        print(f"Model '{model_name}' is loaded and accessible.")
        return True
    except requests.exceptions.ConnectionError as e:
        print(f"Error: Could not connect to Ollama server at {base_url}. Please ensure it's running.")
        print(f"Details: {e}")
        return False
    except requests.exceptions.Timeout:
        print(f"Error: Request to Ollama server timed out.")
        return False
    except requests.exceptions.RequestException as e:
        print(f"Error checking Ollama or model: {e}")
        if response:
            print(f"Response status: {response.status_code}")
            print(f"Response body: {response.text}")
        return False

if not check_ollama_and_model(base_url, os.getenv('OLLAMA_MODEL_NAME')):
    raise RuntimeError("Ollama server or model not ready. Please check Cell 0 execution.")
else:
    print("Ollama server and model are ready for use.")

# Note: The OpenAI client (from `openai` library) is not directly used here
# because we're interacting with Ollama's native API via `requests` as set up.
# If you explicitly need `openai` client for `ollama` (e.g., using `ollama run --port 8000`),
# then ensure `base_url` points to that port and the `client` object is initialized.
# Out:
# Using Ollama API at: http://127.0.0.1:11434
# Model to use: gemma:2b-instruct-q4_0
# Ollama server is responsive.
# Model 'gemma:2b-instruct-q4_0' is loaded and accessible.
# Ollama server and model are ready for use.

# %%
# Cell 2: Load Full Prepared Dataset (2400 Samples) and create stratified splits
import pandas as pd
from sklearn.model_selection import train_test_split # We can use this or manual group by

# Load the already-prepared dataset. Adjust path if your file is in Google Drive.
full_df = pd.read_csv('/content/cwe_top5_sampled_with_juliet_none.csv')
total_samples = len(full_df)
print(f"Total samples in full dataset: {total_samples}")

# Validate dataset
print("Validating full dataset...")
expected_cwes = {'CWE121', 'CWE78', 'CWE122', 'CWE190', 'CWE191', 'none'}
assert set(full_df['cwe'].unique()) == expected_cwes, "Unexpected CWE values found!"
assert full_df['code'].notna().all(), "Missing code values found!"

print("\nFull dataset CWE distribution:")
print(full_df['cwe'].value_counts())

# --- Create Stratified Training and Testing Splits ---
# We need 320 samples per class for training (1920 total)
# and 80 samples per class for testing (480 total).

train_split_df = pd.DataFrame()
test_split_df = pd.DataFrame()

# Group by 'cwe' and split each group
for cwe_type in expected_cwes:
    cwe_subset = full_df[full_df['cwe'] == cwe_type].reset_index(drop=True)

    # Ensure there are enough samples for the split
    if len(cwe_subset) < (320 + 80):
        print(f"Warning: Not enough samples for CWE type '{cwe_type}'. Expected at least 400, found {len(cwe_subset)}. This might cause issues.")
        # Handle cases where there might not be 400 samples per class if necessary
        # For now, we'll proceed, but it might result in fewer than 320/80 if data is short.

    # Take the first 320 for training, and next 80 for testing for each CWE type
    train_split_df = pd.concat([train_split_df, cwe_subset.iloc[:320]])
    test_split_df = pd.concat([test_split_df, cwe_subset.iloc[320:320+80]]) # Ensure it's 320+80 if some subsets are smaller

# Shuffle the splits to randomize the order within them, important for training/batching
train_split_df = train_split_df.sample(frac=1, random_state=42).reset_index(drop=True)
test_split_df = test_split_df.sample(frac=1, random_state=42).reset_index(drop=True)


print(f"\nTraining split size: {len(train_split_df)} samples")
print("Training split CWE distribution:")
print(train_split_df['cwe'].value_counts())

print(f"\nTesting split size: {len(test_split_df)} samples")
print("Testing split CWE distribution:")
print(test_split_df['cwe'].value_counts())

print("\nSample code from training split:", train_split_df['code'].iloc[0][:100]) # Truncate for display
print("Sample code from testing split:", test_split_df['code'].iloc[0][:100])

# Display head of splits (optional)
print("\nTrain Split Head:")
print(train_split_df.head())
print("\nTest Split Head:")
print(test_split_df.head())
# Out:
# Total samples in full dataset: 2400
# Validating full dataset...
#
# Full dataset CWE distribution:
# cwe
# CWE121    400
# CWE78     400
# CWE190    400
# CWE191    400
# CWE122    400
# none      400
# Name: count, dtype: int64
#
# Training split size: 1920 samples
# Training split CWE distribution:
# cwe
# CWE122    320
# none      320
# CWE191    320
# CWE121    320
# CWE190    320
# CWE78     320
# Name: count, dtype: int64
#
# Testing split size: 480 samples
# Testing split CWE distribution:
# cwe
# CWE190    80
# none      80
# CWE121    80
# CWE122    80
# CWE78     80
# CWE191    80
# Name: count, dtype: int64
#
# Sample code from training split: #include "std_testcase.h"
# #ifdef _WIN32
# #include <winsock2.h>
# #include <windows.h>
# #include <direct.
# Sample code from testing split: #include "std_testcase.h"
# unsigned int var;
# unsigned int var;
# unsigned int var;
# #ifndef OMITBAD
# void
#
# Train Split Head:
#                                                 file     cwe label  \
# 0  CWE122_Heap_Based_Buffer_Overflow__c_CWE129_co...  CWE122  good
# 1                                synthetic_none_21.c    none   NaN
# 2  CWE191_Integer_Underflow__int64_t_rand_postdec...  CWE191  good
# 3       CWE191_Integer_Underflow__int_rand_sub_67a.c  CWE191  good
# 4  CWE191_Integer_Underflow__int_listen_socket_mu...  CWE191  good
#
#                                                 code
# 0  #include "std_testcase.h"\n#ifdef _WIN32\n#inc...
# 1        void func() { int x = 5; printf("%d", x); }
# 2  #include "std_testcase.h"\n#ifndef OMITBAD\nvo...
# 3  #include "std_testcase.h"\ntypedef struct _CWE...
# 4  #include "std_testcase.h"\n#ifndef OMITBAD\nex...
#
# Test Split Head:
#                                                 file     cwe label  \
# 0  CWE190_Integer_Overflow__unsigned_int_rand_mul...  CWE190  good
# 1                               synthetic_none_334.c    none   NaN
# 2  CWE121_Stack_Based_Buffer_Overflow__CWE193_cha...  CWE121  good
# 3  CWE122_Heap_Based_Buffer_Overflow__sizeof_stru...  CWE122  good
# 4  CWE121_Stack_Based_Buffer_Overflow__CWE805_cha...  CWE121  good
#
#                                                 code
# 0  #include "std_testcase.h"\nunsigned int var;\n...
# 1  int main() { char str[] = "test"; puts(str); r...
# 2  #include "std_testcase.h"\n#ifndef _WIN32\n#in...
# 3  #include "std_testcase.h"\n#ifndef OMITBAD\nvo...
# 4  #include "std_testcase.h"\n#include <wchar.h>\...

# %%
# Cell 3: Define Prompt (Exact from Old Code)
# The prompt is critical for guiding the model's output to your desired JSON format.
prompt = (
    "You are a security analysis tool. Analyze the C source code for vulnerabilities and respond **only** with a JSON object containing 'reason' and 'answer' fields. Do not include any additional text, explanations, or markdown outside the JSON. Use this exact format:\n"
    "{ \"reason\": \"Explanation of vulnerability\", \"answer\": \"CWE121\" }\n"
    "The 'answer' field must be one of: 'CWE121', 'CWE78', 'CWE122', 'CWE190', 'CWE191', or 'none'. Match the 'answer' to the vulnerability type described in the 'reason'. Examples:\n"
    "- Code with `memcpy` without bounds check: { \"reason\": \"Stack-based buffer overflow due to unchecked memcpy\", \"answer\": \"CWE121\" }\n"
    "- Code with `system` using user input: { \"reason\": \"OS command injection via unsanitized input to system\", \"answer\": \"CWE78\" }\n"
    "- Code with `malloc` and overflow: { \"reason\": \"Heap-based buffer overflow due to improper malloc usage\", \"answer\": \"CWE122\" }\n"
    "- Code with large integer multiplication: { \"reason\": \"Integer overflow from unchecked multiplication\", \"answer\": \"CWE190\" }\n"
    "- Code with negative integer decrement: { \"reason\": \"Integer underflow from unchecked decrement\", \"answer\": \"CWE191\" }\n"
    "- Code with no obvious vulnerability: { \"reason\": \"No vulnerability detected\", \"answer\": \"none\" }\n"
    "Here is the code:\n\n"
)

# Apply the prompt to both training and testing splits
train_split_df['full_prompt'] = prompt + "\n\n" + train_split_df['code']
test_split_df['full_prompt'] = prompt + "\n\n" + test_split_df['code']

print("Prompt sample from training split (truncated):", train_split_df['full_prompt'].iloc[0][:500])
print("\nPrompt sample from testing split (truncated):", test_split_df['full_prompt'].iloc[0][:500])
# Out:
# Prompt sample from training split (truncated): You are a security analysis tool. Analyze the C source code for vulnerabilities and respond **only** with a JSON object containing 'reason' and 'answer' fields. Do not include any additional text, explanations, or markdown outside the JSON. Use this exact format:
# { "reason": "Explanation of vulnerability", "answer": "CWE121" }
# The 'answer' field must be one of: 'CWE121', 'CWE78', 'CWE122', 'CWE190', 'CWE191', or 'none'. Match the 'answer' to the vulnerability type described in the 'reason'. Exam
#
# Prompt sample from testing split (truncated): You are a security analysis tool. Analyze the C source code for vulnerabilities and respond **only** with a JSON object containing 'reason' and 'answer' fields. Do not include any additional text, explanations, or markdown outside the JSON. Use this exact format:
# { "reason": "Explanation of vulnerability", "answer": "CWE121" }
# The 'answer' field must be one of: 'CWE121', 'CWE78', 'CWE122', 'CWE190', 'CWE191', or 'none'. Match the 'answer' to the vulnerability type described in the 'reason'. Exam

# %%
# Cell 4: Create Backups directory and initialize response lists
from pathlib import Path
import json
import pandas as pd # Ensure pandas is imported

# Define paths for Colab environment
BACKUP_DIR = Path("/content/CodeSentinel/Backups")
RESULTS_DIR = Path("/content/CodeSentinel/Results/_2")

BACKUP_DIR.mkdir(parents=True, exist_ok=True)
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

# Define backup filenames for each split
MODEL_NAME = os.getenv('OLLAMA_MODEL_NAME').replace(':', '_').replace('/', '-') # Sanitize model name for filename
TRAIN_BACKUP_PATH = BACKUP_DIR / f"Result-{MODEL_NAME}-CWE-train.csv"
TEST_BACKUP_PATH = BACKUP_DIR / f"Result-{MODEL_NAME}-CWE-test.csv"

def save_responses(responses_list, path):
    """Saves a list of raw string responses to a CSV file."""
    print(f"Debug: Responses before saving to {path}:")
    cleaned_responses = []
    for idx, response in enumerate(responses_list):
        if pd.isna(response) or response is None:
            print(f"Response {idx} is invalid (NaN/None), replacing with fallback for saving.")
            response = json.dumps({"reason": "Invalid response", "answer": "none"})
        # Ensure it's a string representation of JSON
        if not isinstance(response, str):
            response = json.dumps(response) # Convert dicts back to string JSON if needed
        print(f"Response {idx}: {response[:100]}... (type: {type(response)})") # Truncate for print
        cleaned_responses.append(response)
    df = pd.DataFrame(cleaned_responses, columns=['raw_response_json_string'])
    df.to_csv(path, index=False)
    print(f"Responses saved to: {path}")

# Start fresh by resetting responses for both splits
training_responses = []
testing_responses = []
print("Response lists reset to empty for fresh start.")
# Out:
# Response lists reset to empty for fresh start.

# %%
# Cell 5: Run Inference Loops for Training and Testing Splits
import requests
import time
import json
import os # Make sure os is imported
from tqdm.notebook import tqdm # For nice progress bars in Colab
from sklearn.metrics import confusion_matrix, classification_report # For evaluation later

# Retrieve API details from environment variables
api_url_generate = f"{os.getenv('OLLAMA_API_BASE_URL')}/api/generate"
MODEL_NAME_FULL = os.getenv('OLLAMA_MODEL_NAME') # The full model name with colon

max_retries = 3
retry_delay = 5  # seconds
debug_mode = False # Set to True for very verbose logging per request (can slow down)

def process_dataframe_for_inference(df_to_process, response_list_target):
    """
    Processes a DataFrame, sends prompts to Ollama, and appends raw responses to a list.
    Handles retries and errors.
    """
    err_logs_local = []
    print(f"\nStarting inference for {len(df_to_process)} samples using model '{MODEL_NAME_FULL}'...")

    for index, row in tqdm(df_to_process.iterrows(), total=len(df_to_process), desc="Processing Samples"):
        attempts = 0
        success = False
        source_code = row['code'] # Use original code from row for prompt construction
        full_prompt_text = row['full_prompt'] # Use the pre-constructed full_prompt

        if debug_mode:
            print(f"\nASKED (Index {index}):")
            print(f"Source (truncated): {source_code[:200]}...")
            print(f"Full Prompt (truncated): {full_prompt_text[:300]}...")

        while attempts < max_retries and not success:
            try:
                if debug_mode:
                    print(f"Attempt {attempts + 1}: Sending request to {api_url_generate}...")
                start_time = time.time()
                payload = {
                    "model": MODEL_NAME_FULL,
                    "prompt": full_prompt_text,
                    "stream": False # We want the full response at once
                }

                if debug_mode:
                    print(f"Payload length: {len(payload['prompt'])} chars")

                response = requests.post(api_url_generate, json=payload, timeout=300) # Increased timeout to 300s (5 min) for large models/prompts
                response.raise_for_status() # Raise an error for bad status codes (4xx or 5xx)

                end_time = time.time()
                full_ollama_response = response.json()
                raw_content = full_ollama_response.get('response', '') # The actual text response from Ollama

                if debug_mode:
                    print(f"Request took {end_time - start_time:.2f} seconds")
                    print(f"Full Ollama JSON response: {json.dumps(full_ollama_response, indent=2)}")
                    print(f"Raw content from 'response' field: {raw_content[:200]}...")

                # Append the raw response string (or full JSON dict if preferred for later parsing)
                # Storing the full JSON dict ensures all metadata is preserved
                response_list_target.append(full_ollama_response)
                success = True

            except requests.RequestException as e:
                attempts += 1
                end_time = time.time()
                log_entry = {
                    "index": index,
                    "error_type": type(e).__name__,
                    "message": str(e),
                    "attempt": attempts,
                    "elapsed_time": end_time - start_time,
                    "response_status_code": getattr(response, 'status_code', 'N/A'),
                    "response_text_preview": getattr(response, 'text', 'No response')[:500]
                }
                err_logs_local.append(log_entry)
                print(f"ERROR at index {index}, attempt {attempts}/{max_retries} : {e}")
                print(f"Request failed after {end_time - start_time:.2f} seconds.")

                if attempts < max_retries:
                    print(f"Retrying in {retry_delay} seconds...")
                    time.sleep(retry_delay)
                else:
                    fallback_response_dict = {
                        "response": json.dumps({"reason": "Failed after max attempts", "answer": "none"}),
                        "status": "error",
                        "error_message": f"Max retries reached: {log_entry['message']}"
                    }
                    response_list_target.append(fallback_response_dict)
                    print(f"Max retries reached for index {index}, stored fallback response.")
            except Exception as e: # Catch any other unexpected errors
                attempts += 1
                end_time = time.time()
                log_entry = {
                    "index": index,
                    "error_type": type(e).__name__,
                    "message": str(e),
                    "attempt": attempts,
                    "elapsed_time": end_time - start_time,
                    "response_status_code": 'N/A', # No response object here
                    "response_text_preview": 'No response due to non-request error'
                }
                err_logs_local.append(log_entry)
                print(f"UNEXPECTED ERROR at index {index}, attempt {attempts}/{max_retries} : {e}")
                if attempts < max_retries:
                    print(f"Retrying in {retry_delay} seconds...")
                    time.sleep(retry_delay)
                else:
                    fallback_response_dict = {
                        "response": json.dumps({"reason": "Failed due to unexpected error", "answer": "none"}),
                        "status": "error",
                        "error_message": f"Unexpected error after max retries: {log_entry['message']}"
                    }
                    response_list_target.append(fallback_response_dict)
                    print(f"Max retries reached for index {index} due to unexpected error, stored fallback.")

    print(f"Inference loop finished. Total errors logged for this run: {len(err_logs_local)}")
    return err_logs_local

# Global error log list
all_err_logs = []

# --- Run inference for Training Split ---
print("--- Running Inference for Training Split ---")
train_err_logs = process_dataframe_for_inference(train_split_df, training_responses)
all_err_logs.extend(train_err_logs)
save_responses(training_responses, TRAIN_BACKUP_PATH)

# --- Run inference for Testing Split ---
print("\n--- Running Inference for Testing Split ---")
test_err_logs = process_dataframe_for_inference(test_split_df, testing_responses)
all_err_logs.extend(test_err_logs)
save_responses(testing_responses, TEST_BACKUP_PATH)

print("\nAll inference tasks complete.")
# Out:
# --- Running Inference for Training Split ---
#
# Starting inference for 1920 samples using model 'gemma:2b-instruct-q4_0'...
# Processing Samples:   0%|          | 0/1920 [00:00<?, ?it/s]
# Inference loop finished. Total errors logged for this run: 0
# Debug: Responses before saving to /content/CodeSentinel/Backups/Result-gemma_2b-instruct-q4_0-CWE-train.csv:
# Response 0: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:16:42.805596966Z", "response": "{\n... (type: <class 'str'>)
# Response 1: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:16:43.239350765Z", "response": "{ \... (type: <class 'str'>)
# Response 2: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:16:43.935418718Z", "response": "{\n... (type: <class 'str'>)
# Response 3: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:16:44.398160925Z", "response": "{ \... (type: <class 'str'>)
# Response 4: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:16:45.051277486Z", "response": "{\n... (type: <class 'str'>)
# Response 5: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:16:45.685937416Z", "response": "{ \... (type: <class 'str'>)
# Response 6: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:16:47.146861668Z", "response": "{\n... (type: <class 'str'>)
# Response 7: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:16:47.954191203Z", "response": "{\n... (type: <class 'str'>)
# Response 8: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:16:48.807861144Z", "response": "{\n... (type: <class 'str'>)
# Response 9: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:16:49.367992912Z", "response": "{ \... (type: <class 'str'>)
# Response 10: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:16:50.201387925Z", "response": "{\n... (type: <class 'str'>)
# Response 11: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:16:50.643413887Z", "response": "{\n... (type: <class 'str'>)
# Response 12: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:16:51.468086566Z", "response": "{\n... (type: <class 'str'>)
# Response 13: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:16:52.067624479Z", "response": "{\n... (type: <class 'str'>)
# Response 14: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:16:52.74877849Z", "response": "{\n ... (type: <class 'str'>)
# Response 15: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:16:53.438699088Z", "response": "{\n... (type: <class 'str'>)
# Response 16: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:16:53.684794751Z", "response": "{ \... (type: <class 'str'>)
# Response 17: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:16:54.402133346Z", "response": "{\n... (type: <class 'str'>)
# Response 18: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:16:54.891302783Z", "response": "{\n... (type: <class 'str'>)
# Response 19: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:16:55.410169467Z", "response": "{\n... (type: <class 'str'>)
# Response 20: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:16:56.017060354Z", "response": "{ \... (type: <class 'str'>)
# Response 21: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:16:56.412603567Z", "response": "{\n... (type: <class 'str'>)
# Response 22: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:16:57.267330736Z", "response": "{\n... (type: <class 'str'>)
# Response 23: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:16:57.688005835Z", "response": "{ \... (type: <class 'str'>)
# Response 24: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:16:58.536585128Z", "response": "{\n... (type: <class 'str'>)
# Response 25: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:16:59.221834297Z", "response": "{\n... (type: <class 'str'>)
# Response 26: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:16:59.47959333Z", "response": "{ \"... (type: <class 'str'>)
# Response 27: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:00.051133981Z", "response": "{\n... (type: <class 'str'>)
# Response 28: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:00.559740982Z", "response": "{\n... (type: <class 'str'>)
# Response 29: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:00.855165788Z", "response": "{ \... (type: <class 'str'>)
# Response 30: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:01.409901204Z", "response": "{\n... (type: <class 'str'>)
# Response 31: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:02.0312808Z", "response": "{ \"r... (type: <class 'str'>)
# Response 32: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:02.425428687Z", "response": "{\n... (type: <class 'str'>)
# Response 33: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:03.079792014Z", "response": "{\n... (type: <class 'str'>)
# Response 34: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:03.687464582Z", "response": "{\n... (type: <class 'str'>)
# Response 35: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:04.212933864Z", "response": "{\n... (type: <class 'str'>)
# Response 36: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:04.816298655Z", "response": "{ \... (type: <class 'str'>)
# Response 37: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:05.242916723Z", "response": "{ \... (type: <class 'str'>)
# Response 38: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:05.668844947Z", "response": "{\n... (type: <class 'str'>)
# Response 39: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:06.275988113Z", "response": "{\n... (type: <class 'str'>)
# Response 40: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:06.526146756Z", "response": "{ \... (type: <class 'str'>)
# Response 41: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:07.14003974Z", "response": "{\n ... (type: <class 'str'>)
# Response 42: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:07.575109463Z", "response": "{\n... (type: <class 'str'>)
# Response 43: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:08.000060436Z", "response": "{\n... (type: <class 'str'>)
# Response 44: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:08.252620607Z", "response": "{ \... (type: <class 'str'>)
# Response 45: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:08.742511198Z", "response": "{\n... (type: <class 'str'>)
# Response 46: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:09.596443955Z", "response": "{\n... (type: <class 'str'>)
# Response 47: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:09.991613785Z", "response": "{ \... (type: <class 'str'>)
# Response 48: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:10.517206699Z", "response": "{\n... (type: <class 'str'>)
# Response 49: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:11.198068433Z", "response": "{\n... (type: <class 'str'>)
# Response 50: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:11.569958687Z", "response": "{ \... (type: <class 'str'>)
# Response 51: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:12.386709928Z", "response": "{\n... (type: <class 'str'>)
# Response 52: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:12.680544781Z", "response": "{ \... (type: <class 'str'>)
# Response 53: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:13.147199245Z", "response": "{\n... (type: <class 'str'>)
# Response 54: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:13.64422928Z", "response": "{\n ... (type: <class 'str'>)
# Response 55: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:14.095975233Z", "response": "{\n... (type: <class 'str'>)
# Response 56: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:14.72287699Z", "response": "{\n ... (type: <class 'str'>)
# Response 57: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:15.253760477Z", "response": "{ \... (type: <class 'str'>)
# Response 58: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:15.773633615Z", "response": "{\n... (type: <class 'str'>)
# Response 59: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:16.271424344Z", "response": "{\n... (type: <class 'str'>)
# Response 60: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:16.579657744Z", "response": "{\n... (type: <class 'str'>)
# Response 61: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:17.526828271Z", "response": "{\n... (type: <class 'str'>)
# Response 62: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:18.007982904Z", "response": "{\n... (type: <class 'str'>)
# Response 63: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:18.362680423Z", "response": "{ \... (type: <class 'str'>)
# Response 64: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:18.98414051Z", "response": "{\n ... (type: <class 'str'>)
# Response 65: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:19.47352015Z", "response": "{ \"... (type: <class 'str'>)
# Response 66: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:20.114865289Z", "response": "{\n... (type: <class 'str'>)
# Response 67: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:20.369789022Z", "response": "{ \... (type: <class 'str'>)
# Response 68: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:20.82070701Z", "response": "{\n ... (type: <class 'str'>)
# Response 69: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:21.376040658Z", "response": "{\n... (type: <class 'str'>)
# Response 70: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:21.786505858Z", "response": "{\n... (type: <class 'str'>)
# Response 71: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:22.29340389Z", "response": "{\n ... (type: <class 'str'>)
# Response 72: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:22.908165962Z", "response": "{\n... (type: <class 'str'>)
# Response 73: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:23.422396045Z", "response": "{ \... (type: <class 'str'>)
# Response 74: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:23.95284244Z", "response": "{\n ... (type: <class 'str'>)
# Response 75: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:24.763726391Z", "response": "{\n... (type: <class 'str'>)
# Response 76: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:25.213382058Z", "response": "{ \... (type: <class 'str'>)
# Response 77: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:25.854409173Z", "response": "{\n... (type: <class 'str'>)
# Response 78: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:26.883480306Z", "response": "{\n... (type: <class 'str'>)
# Response 79: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:27.389792847Z", "response": "{ \... (type: <class 'str'>)
# Response 80: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:27.960323635Z", "response": "{\n... (type: <class 'str'>)
# Response 81: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:28.646080875Z", "response": "{\n... (type: <class 'str'>)
# Response 82: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:29.189713016Z", "response": "{\n... (type: <class 'str'>)
# Response 83: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:29.763442483Z", "response": "{\n... (type: <class 'str'>)
# Response 84: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:30.369692539Z", "response": "{\n... (type: <class 'str'>)
# Response 85: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:30.982190502Z", "response": "{\n... (type: <class 'str'>)
# Response 86: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:31.479263676Z", "response": "{\n... (type: <class 'str'>)
# Response 87: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:31.97799285Z", "response": "{\n ... (type: <class 'str'>)
# Response 88: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:32.8092221Z", "response": "{\n  ... (type: <class 'str'>)
# Response 89: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:33.589209343Z", "response": "{\n... (type: <class 'str'>)
# Response 90: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:34.111139778Z", "response": "{\n... (type: <class 'str'>)
# Response 91: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:34.584084105Z", "response": "{\n... (type: <class 'str'>)
# Response 92: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:34.831775722Z", "response": "{ \... (type: <class 'str'>)
# Response 93: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:35.210758923Z", "response": "{ \... (type: <class 'str'>)
# Response 94: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:35.754504826Z", "response": "{\n... (type: <class 'str'>)
# Response 95: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:36.22211129Z", "response": "{\n ... (type: <class 'str'>)
# Response 96: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:36.754944531Z", "response": "{\n... (type: <class 'str'>)
# Response 97: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:37.229965788Z", "response": "{\n... (type: <class 'str'>)
# Response 98: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:37.528967019Z", "response": "{\n... (type: <class 'str'>)
# Response 99: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:37.909783471Z", "response": "{ \... (type: <class 'str'>)
# Response 100: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:38.320525447Z", "response": "{ \... (type: <class 'str'>)
# Response 101: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:39.224313981Z", "response": "{\n... (type: <class 'str'>)
# Response 102: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:39.743135721Z", "response": "{\n... (type: <class 'str'>)
# Response 103: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:40.220159131Z", "response": "{\n... (type: <class 'str'>)
# Response 104: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:40.835697177Z", "response": "{\n... (type: <class 'str'>)
# Response 105: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:41.084671058Z", "response": "{ \... (type: <class 'str'>)
# Response 106: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:41.330356679Z", "response": "{ \... (type: <class 'str'>)
# Response 107: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:42.149937043Z", "response": "{\n... (type: <class 'str'>)
# Response 108: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:42.996002684Z", "response": "{\n... (type: <class 'str'>)
# Response 109: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:43.462921146Z", "response": "{\n... (type: <class 'str'>)
# Response 110: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:44.178500296Z", "response": "{\n... (type: <class 'str'>)
# Response 111: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:44.5605151Z", "response": "{ \"r... (type: <class 'str'>)
# Response 112: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:45.082952969Z", "response": "{\n... (type: <class 'str'>)
# Response 113: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:45.898918345Z", "response": "{\n... (type: <class 'str'>)
# Response 114: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:46.356163035Z", "response": "{ \... (type: <class 'str'>)
# Response 115: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:46.749937746Z", "response": "{ \... (type: <class 'str'>)
# Response 116: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:47.316905701Z", "response": "{\n... (type: <class 'str'>)
# Response 117: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:47.727630662Z", "response": "{\n... (type: <class 'str'>)
# Response 118: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:48.151940164Z", "response": "{\n... (type: <class 'str'>)
# Response 119: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:48.634124029Z", "response": "{\n... (type: <class 'str'>)
# Response 120: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:49.147438314Z", "response": "{ \... (type: <class 'str'>)
# Response 121: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:49.709698278Z", "response": "{\n... (type: <class 'str'>)
# Response 122: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:49.953246818Z", "response": "{ \... (type: <class 'str'>)
# Response 123: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:50.628946473Z", "response": "{\n... (type: <class 'str'>)
# Response 124: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:51.263387859Z", "response": "{\n... (type: <class 'str'>)
# Response 125: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:52.023408048Z", "response": "{\n... (type: <class 'str'>)
# Response 126: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:52.629632301Z", "response": "{ \... (type: <class 'str'>)
# Response 127: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:53.018629627Z", "response": "{ \... (type: <class 'str'>)
# Response 128: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:53.650858825Z", "response": "{\n... (type: <class 'str'>)
# Response 129: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:54.114821219Z", "response": "{ \... (type: <class 'str'>)
# Response 130: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:54.579354543Z", "response": "{\n... (type: <class 'str'>)
# Response 131: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:55.062068806Z", "response": "{\n... (type: <class 'str'>)
# Response 132: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:55.756519943Z", "response": "{\n... (type: <class 'str'>)
# Response 133: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:56.000663636Z", "response": "{ \... (type: <class 'str'>)
# Response 134: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:56.334500501Z", "response": "{\n... (type: <class 'str'>)
# Response 135: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:57.142268507Z", "response": "{\n... (type: <class 'str'>)
# Response 136: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:57.600295317Z", "response": "{\n... (type: <class 'str'>)
# Response 137: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:57.84829081Z", "response": "{ \"... (type: <class 'str'>)
# Response 138: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:58.43449227Z", "response": "{\n ... (type: <class 'str'>)
# Response 139: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:59.130467161Z", "response": "{\n... (type: <class 'str'>)
# Response 140: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:17:59.701078493Z", "response": "{\n... (type: <class 'str'>)
# Response 141: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:00.321035273Z", "response": "{\n... (type: <class 'str'>)
# Response 142: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:01.109129215Z", "response": "{\n... (type: <class 'str'>)
# Response 143: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:01.509255078Z", "response": "{\n... (type: <class 'str'>)
# Response 144: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:02.294848485Z", "response": "{\n... (type: <class 'str'>)
# Response 145: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:02.882587182Z", "response": "{\n... (type: <class 'str'>)
# Response 146: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:03.49746647Z", "response": "{\n ... (type: <class 'str'>)
# Response 147: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:04.239628924Z", "response": "{\n... (type: <class 'str'>)
# Response 148: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:04.665076558Z", "response": "{\n... (type: <class 'str'>)
# Response 149: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:05.237038682Z", "response": "{\n... (type: <class 'str'>)
# Response 150: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:05.858809243Z", "response": "{ \... (type: <class 'str'>)
# Response 151: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:06.145619627Z", "response": "{ \... (type: <class 'str'>)
# Response 152: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:06.906924508Z", "response": "{\n... (type: <class 'str'>)
# Response 153: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:07.157234499Z", "response": "{ \... (type: <class 'str'>)
# Response 154: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:07.721023371Z", "response": "{\n... (type: <class 'str'>)
# Response 155: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:08.423109066Z", "response": "{\n... (type: <class 'str'>)
# Response 156: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:08.855397107Z", "response": "{ \... (type: <class 'str'>)
# Response 157: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:09.355288014Z", "response": "{\n... (type: <class 'str'>)
# Response 158: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:09.761531034Z", "response": "{\n... (type: <class 'str'>)
# Response 159: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:10.26081177Z", "response": "{\n ... (type: <class 'str'>)
# Response 160: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:10.735863351Z", "response": "{\n... (type: <class 'str'>)
# Response 161: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:11.350163406Z", "response": "{\n... (type: <class 'str'>)
# Response 162: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:12.005010031Z", "response": "{\n... (type: <class 'str'>)
# Response 163: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:12.345298534Z", "response": "{ \... (type: <class 'str'>)
# Response 164: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:12.891514818Z", "response": "{\n... (type: <class 'str'>)
# Response 165: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:13.450385739Z", "response": "{ \... (type: <class 'str'>)
# Response 166: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:13.936659732Z", "response": "{\n... (type: <class 'str'>)
# Response 167: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:14.180980148Z", "response": "{ \... (type: <class 'str'>)
# Response 168: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:14.424780497Z", "response": "{ \... (type: <class 'str'>)
# Response 169: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:15.696825801Z", "response": "{\n... (type: <class 'str'>)
# Response 170: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:16.3616761Z", "response": "{\n \... (type: <class 'str'>)
# Response 171: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:16.951290929Z", "response": "{ \... (type: <class 'str'>)
# Response 172: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:17.563048669Z", "response": "{\n... (type: <class 'str'>)
# Response 173: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:18.053951524Z", "response": "{ \... (type: <class 'str'>)
# Response 174: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:18.424721115Z", "response": "{ \... (type: <class 'str'>)
# Response 175: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:18.706195971Z", "response": "{ \... (type: <class 'str'>)
# Response 176: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:19.216473867Z", "response": "{ \... (type: <class 'str'>)
# Response 177: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:19.752024643Z", "response": "{\n... (type: <class 'str'>)
# Response 178: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:20.230981291Z", "response": "{\n... (type: <class 'str'>)
# Response 179: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:20.696012071Z", "response": "{\n... (type: <class 'str'>)
# Response 180: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:20.940150378Z", "response": "{ \... (type: <class 'str'>)
# Response 181: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:21.606947438Z", "response": "{\n... (type: <class 'str'>)
# Response 182: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:22.117398632Z", "response": "{ \... (type: <class 'str'>)
# Response 183: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:22.993299463Z", "response": "{\n... (type: <class 'str'>)
# Response 184: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:23.439411994Z", "response": "{\n... (type: <class 'str'>)
# Response 185: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:24.099116824Z", "response": "{\n... (type: <class 'str'>)
# Response 186: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:24.612315984Z", "response": "{\n... (type: <class 'str'>)
# Response 187: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:25.103016259Z", "response": "{\n... (type: <class 'str'>)
# Response 188: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:25.504305336Z", "response": "{\n... (type: <class 'str'>)
# Response 189: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:26.109896349Z", "response": "{ \... (type: <class 'str'>)
# Response 190: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:26.668008404Z", "response": "{\n... (type: <class 'str'>)
# Response 191: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:27.210625595Z", "response": "{\n... (type: <class 'str'>)
# Response 192: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:27.575526194Z", "response": "{ \... (type: <class 'str'>)
# Response 193: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:28.121125723Z", "response": "{\n... (type: <class 'str'>)
# Response 194: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:28.613089968Z", "response": "{ \... (type: <class 'str'>)
# Response 195: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:29.057021762Z", "response": "{ \... (type: <class 'str'>)
# Response 196: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:29.946436869Z", "response": "{\n... (type: <class 'str'>)
# Response 197: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:30.59502332Z", "response": "{\n ... (type: <class 'str'>)
# Response 198: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:31.177861175Z", "response": "{\n... (type: <class 'str'>)
# Response 199: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:31.73817565Z", "response": "{\n ... (type: <class 'str'>)
# Response 200: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:32.207180655Z", "response": "{\n... (type: <class 'str'>)
# Response 201: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:32.775437217Z", "response": "{\n... (type: <class 'str'>)
# Response 202: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:33.357290101Z", "response": "{ \... (type: <class 'str'>)
# Response 203: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:33.795340023Z", "response": "{ \... (type: <class 'str'>)
# Response 204: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:34.183371766Z", "response": "{\n... (type: <class 'str'>)
# Response 205: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:34.74730853Z", "response": "{\n ... (type: <class 'str'>)
# Response 206: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:35.214229912Z", "response": "{ \... (type: <class 'str'>)
# Response 207: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:36.191579712Z", "response": "{\n... (type: <class 'str'>)
# Response 208: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:36.893949945Z", "response": "{\n... (type: <class 'str'>)
# Response 209: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:37.554658546Z", "response": "{\n... (type: <class 'str'>)
# Response 210: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:38.083044154Z", "response": "{\n... (type: <class 'str'>)
# Response 211: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:38.52630907Z", "response": "{\n ... (type: <class 'str'>)
# Response 212: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:39.048604254Z", "response": "{\n... (type: <class 'str'>)
# Response 213: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:39.826021741Z", "response": "{\n... (type: <class 'str'>)
# Response 214: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:40.464750237Z", "response": "{\n... (type: <class 'str'>)
# Response 215: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:40.8757121Z", "response": "{\n  ... (type: <class 'str'>)
# Response 216: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:41.33391564Z", "response": "{\n ... (type: <class 'str'>)
# Response 217: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:41.894106779Z", "response": "{ \... (type: <class 'str'>)
# Response 218: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:42.413311922Z", "response": "{\n... (type: <class 'str'>)
# Response 219: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:42.854353917Z", "response": "{ \... (type: <class 'str'>)
# Response 220: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:43.366094177Z", "response": "{\n... (type: <class 'str'>)
# Response 221: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:43.896860815Z", "response": "{\n... (type: <class 'str'>)
# Response 222: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:44.299410184Z", "response": "{\n... (type: <class 'str'>)
# Response 223: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:44.595600827Z", "response": "{ \... (type: <class 'str'>)
# Response 224: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:45.315565364Z", "response": "{\n... (type: <class 'str'>)
# Response 225: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:45.871718749Z", "response": "{\n... (type: <class 'str'>)
# Response 226: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:46.119548755Z", "response": "{ \... (type: <class 'str'>)
# Response 227: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:46.731560389Z", "response": "{\n... (type: <class 'str'>)
# Response 228: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:47.206010086Z", "response": "{\n... (type: <class 'str'>)
# Response 229: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:47.766139567Z", "response": "{ \... (type: <class 'str'>)
# Response 230: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:48.186394046Z", "response": "{ \... (type: <class 'str'>)
# Response 231: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:48.885168025Z", "response": "{\n... (type: <class 'str'>)
# Response 232: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:49.131672421Z", "response": "{ \... (type: <class 'str'>)
# Response 233: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:49.682963232Z", "response": "{ \... (type: <class 'str'>)
# Response 234: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:50.116665784Z", "response": "{ \... (type: <class 'str'>)
# Response 235: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:50.672228096Z", "response": "{\n... (type: <class 'str'>)
# Response 236: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:51.098385396Z", "response": "{\n... (type: <class 'str'>)
# Response 237: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:51.602958527Z", "response": "{\n... (type: <class 'str'>)
# Response 238: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:52.266800275Z", "response": "{\n... (type: <class 'str'>)
# Response 239: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:52.642244976Z", "response": "{ \... (type: <class 'str'>)
# Response 240: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:53.24170314Z", "response": "{\n ... (type: <class 'str'>)
# Response 241: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:53.721088396Z", "response": "{\n... (type: <class 'str'>)
# Response 242: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:54.374444071Z", "response": "{ \... (type: <class 'str'>)
# Response 243: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:54.787370409Z", "response": "{\n... (type: <class 'str'>)
# Response 244: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:55.496435795Z", "response": "{\n... (type: <class 'str'>)
# Response 245: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:55.975063695Z", "response": "{\n... (type: <class 'str'>)
# Response 246: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:56.462685631Z", "response": "{ \... (type: <class 'str'>)
# Response 247: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:56.990541698Z", "response": "{\n... (type: <class 'str'>)
# Response 248: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:57.705662038Z", "response": "{\n... (type: <class 'str'>)
# Response 249: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:58.303178951Z", "response": "{\n... (type: <class 'str'>)
# Response 250: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:58.879778501Z", "response": "{\n... (type: <class 'str'>)
# Response 251: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:59.326205326Z", "response": "{ \... (type: <class 'str'>)
# Response 252: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:18:59.97669585Z", "response": "{\n ... (type: <class 'str'>)
# Response 253: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:00.357436161Z", "response": "{ \... (type: <class 'str'>)
# Response 254: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:00.831931311Z", "response": "{\n... (type: <class 'str'>)
# Response 255: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:01.380948298Z", "response": "{\n... (type: <class 'str'>)
# Response 256: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:01.922214764Z", "response": "{\n... (type: <class 'str'>)
# Response 257: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:02.511542238Z", "response": "{\n... (type: <class 'str'>)
# Response 258: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:03.225646605Z", "response": "{\n... (type: <class 'str'>)
# Response 259: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:03.75558396Z", "response": "{\n ... (type: <class 'str'>)
# Response 260: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:04.108349497Z", "response": "{ \... (type: <class 'str'>)
# Response 261: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:04.489958686Z", "response": "{\n... (type: <class 'str'>)
# Response 262: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:04.888936392Z", "response": "{\n... (type: <class 'str'>)
# Response 263: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:05.561513861Z", "response": "{\n... (type: <class 'str'>)
# Response 264: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:06.077331789Z", "response": "{\n... (type: <class 'str'>)
# Response 265: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:06.856028685Z", "response": "{\n... (type: <class 'str'>)
# Response 266: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:07.62875297Z", "response": "{\n ... (type: <class 'str'>)
# Response 267: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:08.685894162Z", "response": "{\n... (type: <class 'str'>)
# Response 268: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:09.360570506Z", "response": "{\n... (type: <class 'str'>)
# Response 269: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:09.880641797Z", "response": "{ \... (type: <class 'str'>)
# Response 270: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:10.513340384Z", "response": "{\n... (type: <class 'str'>)
# Response 271: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:11.109087861Z", "response": "{\n... (type: <class 'str'>)
# Response 272: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:11.664977133Z", "response": "{ \... (type: <class 'str'>)
# Response 273: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:12.215610083Z", "response": "{\n... (type: <class 'str'>)
# Response 274: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:12.770932558Z", "response": "{\n... (type: <class 'str'>)
# Response 275: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:13.339394289Z", "response": "{ \... (type: <class 'str'>)
# Response 276: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:13.723212441Z", "response": "{\n... (type: <class 'str'>)
# Response 277: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:14.157428999Z", "response": "{\n... (type: <class 'str'>)
# Response 278: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:14.590642544Z", "response": "{\n... (type: <class 'str'>)
# Response 279: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:15.263424366Z", "response": "{\n... (type: <class 'str'>)
# Response 280: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:15.710538672Z", "response": "{\n... (type: <class 'str'>)
# Response 281: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:15.961176086Z", "response": "{ \... (type: <class 'str'>)
# Response 282: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:16.455225021Z", "response": "{\n... (type: <class 'str'>)
# Response 283: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:16.700684226Z", "response": "{ \... (type: <class 'str'>)
# Response 284: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:17.219940796Z", "response": "{\n... (type: <class 'str'>)
# Response 285: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:17.880917709Z", "response": "{\n... (type: <class 'str'>)
# Response 286: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:18.126129469Z", "response": "{ \... (type: <class 'str'>)
# Response 287: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:18.542598022Z", "response": "{\n... (type: <class 'str'>)
# Response 288: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:19.009157265Z", "response": "{\n... (type: <class 'str'>)
# Response 289: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:19.474268691Z", "response": "{ \... (type: <class 'str'>)
# Response 290: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:19.919794815Z", "response": "{ \... (type: <class 'str'>)
# Response 291: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:20.654609569Z", "response": "{\n... (type: <class 'str'>)
# Response 292: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:21.235632343Z", "response": "{\n... (type: <class 'str'>)
# Response 293: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:21.699860415Z", "response": "{\n... (type: <class 'str'>)
# Response 294: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:22.635190562Z", "response": "{\n... (type: <class 'str'>)
# Response 295: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:22.927057908Z", "response": "{ \... (type: <class 'str'>)
# Response 296: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:23.457434378Z", "response": "{\n... (type: <class 'str'>)
# Response 297: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:24.061042368Z", "response": "{\n... (type: <class 'str'>)
# Response 298: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:24.537678685Z", "response": "{ \... (type: <class 'str'>)
# Response 299: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:25.118235022Z", "response": "{\n... (type: <class 'str'>)
# Response 300: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:25.46840173Z", "response": "{\n ... (type: <class 'str'>)
# Response 301: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:26.002993995Z", "response": "{\n... (type: <class 'str'>)
# Response 302: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:26.495325535Z", "response": "{\n... (type: <class 'str'>)
# Response 303: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:27.019420341Z", "response": "{\n... (type: <class 'str'>)
# Response 304: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:27.424853322Z", "response": "{\n... (type: <class 'str'>)
# Response 305: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:27.875852538Z", "response": "{ \... (type: <class 'str'>)
# Response 306: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:28.523239662Z", "response": "{\n... (type: <class 'str'>)
# Response 307: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:28.916750514Z", "response": "{\n... (type: <class 'str'>)
# Response 308: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:29.331156547Z", "response": "{ \... (type: <class 'str'>)
# Response 309: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:29.65781508Z", "response": "{\n ... (type: <class 'str'>)
# Response 310: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:30.063735979Z", "response": "{\n... (type: <class 'str'>)
# Response 311: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:30.643388711Z", "response": "{\n... (type: <class 'str'>)
# Response 312: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:31.045612427Z", "response": "{\n... (type: <class 'str'>)
# Response 313: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:31.361997015Z", "response": "{ \... (type: <class 'str'>)
# Response 314: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:31.990046098Z", "response": "{\n... (type: <class 'str'>)
# Response 315: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:32.391517936Z", "response": "{\n... (type: <class 'str'>)
# Response 316: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:32.705219292Z", "response": "{ \... (type: <class 'str'>)
# Response 317: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:32.948883817Z", "response": "{ \... (type: <class 'str'>)
# Response 318: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:33.365516297Z", "response": "{\n... (type: <class 'str'>)
# Response 319: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:33.838888027Z", "response": "{\n... (type: <class 'str'>)
# Response 320: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:34.080416895Z", "response": "{ \... (type: <class 'str'>)
# Response 321: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:34.499665295Z", "response": "{ \... (type: <class 'str'>)
# Response 322: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:35.089154836Z", "response": "{\n... (type: <class 'str'>)
# Response 323: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:35.621894408Z", "response": "{\n... (type: <class 'str'>)
# Response 324: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:36.221343513Z", "response": "{\n... (type: <class 'str'>)
# Response 325: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:36.787199936Z", "response": "{\n... (type: <class 'str'>)
# Response 326: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:37.235404308Z", "response": "{\n... (type: <class 'str'>)
# Response 327: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:37.496821034Z", "response": "{ \... (type: <class 'str'>)
# Response 328: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:37.74539561Z", "response": "{ \"... (type: <class 'str'>)
# Response 329: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:38.161222611Z", "response": "{ \... (type: <class 'str'>)
# Response 330: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:38.405284846Z", "response": "{ \... (type: <class 'str'>)
# Response 331: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:38.653210037Z", "response": "{ \... (type: <class 'str'>)
# Response 332: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:39.009618418Z", "response": "{\n... (type: <class 'str'>)
# Response 333: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:39.59557376Z", "response": "{\n ... (type: <class 'str'>)
# Response 334: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:40.141490607Z", "response": "{\n... (type: <class 'str'>)
# Response 335: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:40.386005077Z", "response": "{ \... (type: <class 'str'>)
# Response 336: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:40.875416589Z", "response": "{\n... (type: <class 'str'>)
# Response 337: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:41.494308722Z", "response": "{\n... (type: <class 'str'>)
# Response 338: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:41.934135605Z", "response": "{\n... (type: <class 'str'>)
# Response 339: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:42.353480144Z", "response": "{\n... (type: <class 'str'>)
# Response 340: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:19:42.94836702Z", "response": "{\n ... (type: <class 'str'>)
# ...
# Response 367: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:02.729609612Z", "response": "{ \... (type: <class 'str'>)
# Response 368: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:03.042481849Z", "response": "{ \... (type: <class 'str'>)
# Response 369: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:03.597188911Z", "response": "{\n... (type: <class 'str'>)
# Response 370: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:04.111800337Z", "response": "{\n... (type: <class 'str'>)
# Response 371: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:04.412037909Z", "response": "{ \... (type: <class 'str'>)
# Response 372: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:05.07138064Z", "response": "{\n ... (type: <class 'str'>)
# Response 373: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:05.639229166Z", "response": "{ \... (type: <class 'str'>)
# Response 374: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:06.359094084Z", "response": "{\n... (type: <class 'str'>)
# Response 375: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:06.989266621Z", "response": "{ \... (type: <class 'str'>)
# Response 376: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:07.50297239Z", "response": "{\n ... (type: <class 'str'>)
# Response 377: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:07.799257513Z", "response": "{ \... (type: <class 'str'>)
# Response 378: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:08.089929378Z", "response": "{ \... (type: <class 'str'>)
# Response 379: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:08.696858626Z", "response": "{\n... (type: <class 'str'>)
# Response 380: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:09.242952619Z", "response": "{\n... (type: <class 'str'>)
# Response 381: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:09.496861098Z", "response": "{ \... (type: <class 'str'>)
# Response 382: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:09.750243316Z", "response": "{ \... (type: <class 'str'>)
# Response 383: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:10.346892924Z", "response": "{\n... (type: <class 'str'>)
# Response 384: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:10.947331603Z", "response": "{\n... (type: <class 'str'>)
# Response 385: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:11.648482756Z", "response": "{\n... (type: <class 'str'>)
# Response 386: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:12.280341727Z", "response": "{\n... (type: <class 'str'>)
# Response 387: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:12.746512138Z", "response": "{\n... (type: <class 'str'>)
# Response 388: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:13.000565485Z", "response": "{ \... (type: <class 'str'>)
# Response 389: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:13.518920542Z", "response": "{\n... (type: <class 'str'>)
# Response 390: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:13.770554576Z", "response": "{ \... (type: <class 'str'>)
# Response 391: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:14.019677065Z", "response": "{ \... (type: <class 'str'>)
# Response 392: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:14.479660321Z", "response": "{ \... (type: <class 'str'>)
# Response 393: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:14.86163442Z", "response": "{\n ... (type: <class 'str'>)
# Response 394: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:15.37933501Z", "response": "{\n ... (type: <class 'str'>)
# Response 395: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:16.198114785Z", "response": "{\n... (type: <class 'str'>)
# Response 396: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:17.006862774Z", "response": "{\n... (type: <class 'str'>)
# Response 397: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:17.447317853Z", "response": "{ \... (type: <class 'str'>)
# Response 398: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:18.616876215Z", "response": "{\n... (type: <class 'str'>)
# Response 399: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:19.225490454Z", "response": "{\n... (type: <class 'str'>)
# Response 400: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:19.856339191Z", "response": "{\n... (type: <class 'str'>)
# Response 401: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:20.513811348Z", "response": "{\n... (type: <class 'str'>)
# Response 402: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:21.327949201Z", "response": "{\n... (type: <class 'str'>)
# Response 403: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:21.820126007Z", "response": "{\n... (type: <class 'str'>)
# Response 404: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:22.407861576Z", "response": "{\n... (type: <class 'str'>)
# Response 405: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:22.970463686Z", "response": "{\n... (type: <class 'str'>)
# Response 406: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:23.226984254Z", "response": "{ \... (type: <class 'str'>)
# Response 407: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:23.593631369Z", "response": "{ \... (type: <class 'str'>)
# Response 408: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:24.285009886Z", "response": "{\n... (type: <class 'str'>)
# Response 409: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:25.296615384Z", "response": "{\n... (type: <class 'str'>)
# Response 410: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:25.910813968Z", "response": "{\n... (type: <class 'str'>)
# Response 411: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:26.402940056Z", "response": "{\n... (type: <class 'str'>)
# Response 412: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:27.000031185Z", "response": "{\n... (type: <class 'str'>)
# Response 413: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:27.700412446Z", "response": "{\n... (type: <class 'str'>)
# Response 414: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:28.164670653Z", "response": "{\n... (type: <class 'str'>)
# Response 415: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:28.717533668Z", "response": "{\n... (type: <class 'str'>)
# Response 416: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:28.966043496Z", "response": "{ \... (type: <class 'str'>)
# Response 417: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:29.470761266Z", "response": "{\n... (type: <class 'str'>)
# Response 418: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:30.116467782Z", "response": "{\n... (type: <class 'str'>)
# Response 419: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:30.663381477Z", "response": "{\n... (type: <class 'str'>)
# Response 420: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:31.104063487Z", "response": "{ \... (type: <class 'str'>)
# Response 421: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:31.673762538Z", "response": "{ \... (type: <class 'str'>)
# Response 422: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:32.125566405Z", "response": "{ \... (type: <class 'str'>)
# Response 423: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:32.82491069Z", "response": "{\n ... (type: <class 'str'>)
# Response 424: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:33.399196433Z", "response": "{\n... (type: <class 'str'>)
# Response 425: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:33.994998047Z", "response": "{\n... (type: <class 'str'>)
# Response 426: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:34.592900859Z", "response": "{\n... (type: <class 'str'>)
# Response 427: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:35.179281748Z", "response": "{\n... (type: <class 'str'>)
# Response 428: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:35.430064551Z", "response": "{ \... (type: <class 'str'>)
# Response 429: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:35.839201928Z", "response": "{\n... (type: <class 'str'>)
# Response 430: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:36.254277705Z", "response": "{\n... (type: <class 'str'>)
# Response 431: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:36.503954847Z", "response": "{ \... (type: <class 'str'>)
# Response 432: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:36.948154221Z", "response": "{\n... (type: <class 'str'>)
# Response 433: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:37.392877053Z", "response": "{\n... (type: <class 'str'>)
# Response 434: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:38.071255099Z", "response": "{\n... (type: <class 'str'>)
# Response 435: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:38.636463634Z", "response": "{\n... (type: <class 'str'>)
# Response 436: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:39.250879795Z", "response": "{ \... (type: <class 'str'>)
# Response 437: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:39.958635147Z", "response": "{\n... (type: <class 'str'>)
# Response 438: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:40.468086057Z", "response": "{\n... (type: <class 'str'>)
# Response 439: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:40.774607394Z", "response": "{ \... (type: <class 'str'>)
# Response 440: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:41.259270015Z", "response": "{\n... (type: <class 'str'>)
# Response 441: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:42.33523775Z", "response": "{\n ... (type: <class 'str'>)
# Response 442: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:42.66663694Z", "response": "{\n ... (type: <class 'str'>)
# Response 443: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:43.328490551Z", "response": "{\n... (type: <class 'str'>)
# Response 444: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:43.865814697Z", "response": "{\n... (type: <class 'str'>)
# Response 445: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:44.331698813Z", "response": "{ \... (type: <class 'str'>)
# Response 446: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:44.802770611Z", "response": "{ \... (type: <class 'str'>)
# Response 447: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:45.370680191Z", "response": "{\n... (type: <class 'str'>)
# Response 448: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:46.331080038Z", "response": "{\n... (type: <class 'str'>)
# Response 449: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:47.249788001Z", "response": "{\n... (type: <class 'str'>)
# Response 450: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:47.546932223Z", "response": "{ \... (type: <class 'str'>)
# Response 451: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:47.801212011Z", "response": "{ \... (type: <class 'str'>)
# Response 452: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:48.60268554Z", "response": "{\n ... (type: <class 'str'>)
# Response 453: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:49.09102206Z", "response": "{\n ... (type: <class 'str'>)
# Response 454: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:49.641066094Z", "response": "{\n... (type: <class 'str'>)
# Response 455: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:49.890826552Z", "response": "{ \... (type: <class 'str'>)
# Response 456: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:50.446579927Z", "response": "{ \... (type: <class 'str'>)
# Response 457: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:50.888439781Z", "response": "{ \... (type: <class 'str'>)
# Response 458: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:51.314672087Z", "response": "{ \... (type: <class 'str'>)
# Response 459: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:51.738656928Z", "response": "{\n... (type: <class 'str'>)
# Response 460: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:52.199331951Z", "response": "{\n... (type: <class 'str'>)
# Response 461: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:52.72194328Z", "response": "{\n ... (type: <class 'str'>)
# Response 462: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:53.377242149Z", "response": "{\n... (type: <class 'str'>)
# Response 463: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:53.853070516Z", "response": "{\n... (type: <class 'str'>)
# Response 464: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:54.39984386Z", "response": "{\n ... (type: <class 'str'>)
# Response 465: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:55.080261455Z", "response": "{\n... (type: <class 'str'>)
# Response 466: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:55.332746418Z", "response": "{ \... (type: <class 'str'>)
# Response 467: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:55.929547438Z", "response": "{\n... (type: <class 'str'>)
# Response 468: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:56.386813465Z", "response": "{\n... (type: <class 'str'>)
# Response 469: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:56.809254914Z", "response": "{\n... (type: <class 'str'>)
# Response 470: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:57.451956169Z", "response": "{\n... (type: <class 'str'>)
# Response 471: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:57.803988432Z", "response": "{ \... (type: <class 'str'>)
# Response 472: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:58.425142339Z", "response": "{\n... (type: <class 'str'>)
# Response 473: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:59.15233489Z", "response": "{ \"... (type: <class 'str'>)
# Response 474: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:37:59.864016725Z", "response": "{\n... (type: <class 'str'>)
# Response 475: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:38:00.433857591Z", "response": "{ \... (type: <class 'str'>)
# Response 476: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:38:00.973478479Z", "response": "{\n... (type: <class 'str'>)
# Response 477: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:38:01.402777679Z", "response": "{\n... (type: <class 'str'>)
# Response 478: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:38:01.660565097Z", "response": "{ \... (type: <class 'str'>)
# Response 479: {"model": "gemma:2b-instruct-q4_0", "created_at": "2025-06-12T10:38:02.212740372Z", "response": "{\n... (type: <class 'str'>)
# Responses saved to: /content/CodeSentinel/Backups/Result-gemma_2b-instruct-q4_0-CWE-test.csv
#
# All inference tasks complete.

# %%
# Cell 6: Parse and Evaluate Results (Fixed Multi-Class for Both Splits)
import re
import json
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np # For formatting confusion matrix

# Function to extract JSON from Ollama's full response object
def extract_json_from_ollama_response(ollama_response_dict):
    """
    Extracts the JSON object from Ollama's 'response' field, handling potential malformed JSON.
    Expected input: a dictionary from response.json()
    Expected output: a dictionary {"reason": ..., "answer": ...} or a fallback.
    """
    raw_response_text = ollama_response_dict.get('response', '')
    if not raw_response_text:
        return {"reason": "Empty or missing 'response' field from Ollama", "answer": "none"}

    try:
        # Find the first and last curly braces to extract the JSON string
        start = raw_response_text.find('{')
        end = raw_response_text.rfind('}') + 1

        if start != -1 and end != -1 and start < end:
            json_string = raw_response_text[start:end]
            return json.loads(json_string)
        else:
            return {"reason": f"No valid JSON found in response: '{raw_response_text}'", "answer": "none"}
    except json.JSONDecodeError as e:
        # Attempt to fix common JSON issues (e.g., single quotes)
        fixed_text = raw_response_text.replace("'", '"')
        try:
            return json.loads(fixed_text)
        except json.JSONDecodeError:
            return {"reason": f"Failed to parse JSON: {e} | Raw: '{raw_response_text}'", "answer": "none"}
    except Exception as e:
        return {"reason": f"Unexpected error during JSON extraction: {e} | Raw: '{raw_response_text}'", "answer": "none"}

def evaluate_results(df_original, responses_list, data_split_name):
    """
    Processes responses, calculates metrics, and prints evaluation report for a given data split.
    """
    print(f"\n--- Evaluating Results for {data_split_name} Split ({len(responses_list)} samples) ---")

    if not responses_list:
        print(f"No responses to evaluate for {data_split_name} split.")
        return

    # Create a DataFrame for model answers
    # Convert each item in responses_list (which are full Ollama response dicts) to the extracted JSON
    model_answers_dicts = [extract_json_from_ollama_response(res_dict) for res_dict in responses_list]
    model_answers_df = pd.DataFrame(model_answers_dicts)

    # Ensure model_answer and model_reason columns exist, providing defaults
    model_answers_df['model_answer'] = model_answers_df['answer'].fillna('none')
    model_answers_df['model_reason'] = model_answers_df['reason'].fillna('No reason provided')

    # Join with the original DataFrame subset to get true labels and other info
    # Ensure indices align correctly.
    # If the df_original was reset_index, then .iloc will correctly correspond.
    combined_df = df_original.reset_index(drop=True).copy()
    combined_df['model_answer'] = model_answers_df['model_answer']
    combined_df['model_reason'] = model_answers_df['model_reason']

    # Compute verdict
    combined_df['verdict'] = combined_df['cwe'] == combined_df['model_answer']

    # Compute multi-class metrics
    true_labels = combined_df['cwe']
    pred_labels = combined_df['model_answer']

    # Define all possible labels explicitly for consistent report and matrix
    all_labels = sorted(list(set(true_labels.unique()).union(set(pred_labels.unique()))))
    # If using specific set of labels for report consistency:
    # all_labels = ['CWE121', 'CWE78', 'CWE122', 'CWE190', 'CWE191', 'none']


    # AUC (Accuracy for multi-class, or one-vs-rest AUC if binary focus)
    # For multi-class classification, overall accuracy is often used.
    accuracy = combined_df['verdict'].mean()
    print(f"Accuracy ({data_split_name}): {accuracy:.3f}")


    # Confusion Matrix
    cm = confusion_matrix(true_labels, pred_labels, labels=all_labels)
    print(f"\nConfusion Matrix ({data_split_name}):")
    print("Labels order:", all_labels)
    print(cm)
    # For better display, you can use pd.DataFrame(cm, index=all_labels, columns=all_labels)


    # Classification Report
    report = classification_report(true_labels, pred_labels, labels=all_labels, zero_division=0)
    print(f"\nClassification Report ({data_split_name}):")
    print(report)

    # Save filtered results
    output_filename_base = f"Result-{MODEL_NAME}-{data_split_name}-CWE.csv"
    output_path = RESULTS_DIR / output_filename_base
    filtered_df_output = combined_df[['cwe', 'model_answer', 'verdict', 'model_reason', 'file', 'code']]
    filtered_df_output.to_csv(output_path, index=False)
    print(f"Filtered results saved to '{output_path}'")

# --- Perform evaluation for each split ---
evaluate_results(train_split_df, training_responses, "Training")
evaluate_results(test_split_df, testing_responses, "Testing")


if all_err_logs:
    print("\n--- Consolidated Error Log ---")
    for log_entry in all_err_logs:
        print(f"Index: {log_entry['index']}, Error Type: {log_entry['error_type']}, Message: {log_entry['message']}")
        if log_entry.get('response_status_code') != 'N/A':
            print(f"  Status: {log_entry['response_status_code']}, Preview: {log_entry['response_text_preview']}")
else:
    print("\nNo errors logged during inference.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2990123562> in <cell line: 0>()
#     158
#     159 # --- Perform evaluation for each split ---
# --> 160 evaluate_results(train_split_df, training_responses, "Training")
#     161 evaluate_results(test_split_df, testing_responses, "Testing")
#     162
#
# NameError: name 'train_split_df' is not defined

# %% [markdown]
# ## --- Evaluating Results for Training Split (1920 samples) ---
# Accuracy (Training): **0.426**
#
# ### Confusion Matrix (Training):
# Labels order: ['CWE121', 'CWE122', 'CWE190', 'CWE191', 'CWE78', 'none']
# ```text
# [[162 131   9   1   5  12]
#  [123 165   7   1   6  18]
#  [149  49  71   3  24  24]
#  [128  30  94  17  17  34]
#  [ 40  28  55   0 176  21]
#  [ 83   0   9   2   0 226]]
# ```
#
# ### Classification Report (Training):
# ```text
#               precision    recall  f1-score   support
#
#       CWE121       0.24      0.51      0.32       320
#       CWE122       0.41      0.52      0.46       320
#       CWE190       0.29      0.22      0.25       320
#       CWE191       0.71      0.05      0.10       320
#        CWE78       0.77      0.55      0.64       320
#         none       0.67      0.71      0.69       320
#
#     accuracy                           0.43      1920
#    macro avg       0.52      0.43      0.41      1920
# weighted avg       0.52      0.43      0.41      1920
# ```
# ## --- Evaluating Results for Testing Split (480 samples) ---
# Accuracy (Testing): **0.412**
#
# ### Confusion Matrix (Testing):
# Labels order: ['CWE121', 'CWE122', 'CWE190', 'CWE191', 'CWE78', 'none']
# ```text
# [[35 42  0  0  2  1]
#  [35 36  1  0  1  7]
#  [39  8 17  1  6  9]
#  [27  8 32  6  3  4]
#  [ 8  6 12  1 51  2]
#  [22  0  3  1  1 53]]
# ```
#
# ### Classification Report (Training):
# ```text
#               precision    recall  f1-score   support
#
#       CWE121       0.21      0.44      0.28        80
#       CWE122       0.36      0.45      0.40        80
#       CWE190       0.26      0.21      0.23        80
#       CWE191       0.67      0.07      0.13        80
#        CWE78       0.80      0.64      0.71        80
#         none       0.70      0.66      0.68        80
#
#     accuracy                           0.41       480
#    macro avg       0.50      0.41      0.41       480
# weighted avg       0.50      0.41      0.41       480
# ```
#
# ---
