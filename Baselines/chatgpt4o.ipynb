# %%
# --- Google Colab Setup (Cell 0) ---
# This cell installs Ollama, starts the server, and pulls the specific model.

print("Installing necessary Python packages...")
# Remove pandas/numpy/matplotlib/requests/scikit-learn from !pip as they are usually pre-installed
# Adding explicitly to ensure if not present (though they generally are)
# !pip install pandas numpy scikit-learn requests

print("Installing Ollama...")
# Download and execute the Ollama installation script
# !curl -fsSL https://ollama.com/install.sh | sh

import subprocess
import time
import os
import socket
from pathlib import Path

# Set environment variable for Ollama to listen on all interfaces within the Colab VM
# This allows other Colab cells to connect to the Ollama server.
os.environ['OLLAMA_HOST'] = '0.0.0.0'
OLLAMA_PORT = 11434 # Ollama's default API port

print("Ensuring no previous Ollama processes are running...")
# Kill any existing Ollama processes to ensure a clean start
# !pkill ollama || true

print(f"Starting Ollama server on port {OLLAMA_PORT} in background...")
# Start the Ollama server as a background process
ollama_process = subprocess.Popen(["ollama", "serve"],
                                  stdout=subprocess.DEVNULL, # Redirect stdout to /dev/null
                                  stderr=subprocess.DEVNULL, # Redirect stderr to /dev/null
                                  preexec_fn=os.setsid) # Detach from the current process group
print(f"Ollama server process started with PID: {ollama_process.pid}")

print(f"Waiting for Ollama server to become available on port {OLLAMA_PORT}...")
max_wait_time = 90 # seconds (increased for model loading)
start_time = time.time()
server_ready = False

# Loop to check if the Ollama server is responsive
while time.time() - start_time < max_wait_time:
    try:
        # Attempt to create a socket connection to the Ollama server
        with socket.create_connection(('127.0.0.1', OLLAMA_PORT), timeout=1):
            server_ready = True
            break
    except (ConnectionRefusedError, socket.timeout):
        # If connection is refused or times out, check if the Ollama process is still running
        if ollama_process.poll() is not None:
            print(f"Ollama server process died unexpectedly (exit code: {ollama_process.poll()}).")
            print("Please check previous logs for errors or try restarting the runtime.")
            server_ready = False
            break
        print(f"  Still waiting for Ollama... ({int(time.time() - start_time)}s elapsed)")
        time.sleep(5) # Wait 5 seconds before retrying
    except Exception as e:
        print(f"An unexpected error occurred during Ollama startup check: {e}")
        server_ready = False
        break

if not server_ready:
    print(f"Ollama server did not become available on port {OLLAMA_PORT} within {max_wait_time} seconds. Aborting setup.")
    if ollama_process.poll() is None: # If the process is still running, try to terminate it
        ollama_process.terminate()
        print("Attempted to terminate non-responsive Ollama process.")
    raise RuntimeError("Ollama server failed to start or become ready.")
else:
    print(f"Ollama server is now available on port {OLLAMA_PORT}.")

# --- Pull the specific model for this notebook ---
MODEL_NAME = "chevalblanc/gpt-4o-mini:latest" # <--- MODEL TO PULL FOR THIS NOTEBOOK
print(f"\nPulling {MODEL_NAME} model...")
# Run the ollama pull command
pull_process = subprocess.run(["ollama", "pull", MODEL_NAME], capture_output=True, text=True)
print(pull_process.stdout)
if pull_process.stderr:
    print("Ollama pull stderr:", pull_process.stderr)
    if "Error" in pull_process.stderr or "failed" in pull_process.stderr.lower():
        raise RuntimeError(f"Failed to pull Ollama model: {pull_process.stderr}")
print(f"{MODEL_NAME} pull complete.")

# Check if model is available (list all downloaded models)
list_process = subprocess.run(["ollama", "list"], capture_output=True, text=True)
print(f"\nAvailable Ollama models after pulling {MODEL_NAME}:")
print(list_process.stdout)
if list_process.stderr:
    print("Ollama list stderr:", list_process.stderr)

# Verify GPU availability with nvidia-smi
print("\nChecking GPU availability with nvidia-smi...")
# !nvidia-smi

# Set the base URL and model name as environment variables for use in subsequent cells
OLLAMA_API_BASE_URL = f"http://127.0.0.1:{OLLAMA_PORT}"
print(f"Set Ollama API base URL for direct requests to: {OLLAMA_API_BASE_URL}")
# %env OLLAMA_MODEL_NAME=$MODEL_NAME
# %env OLLAMA_API_BASE_URL=$OLLAMA_API_BASE_URL
# Out:
# Installing necessary Python packages...
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Installing Ollama...
# >>> Cleaning up old version at /usr/local/lib/ollama
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ######################################################################## 100.0%
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
# Ensuring no previous Ollama processes are running...
# Starting Ollama server on port 11434 in background...
# Ollama server process started with PID: 4097
# Waiting for Ollama server to become available on port 11434...
#   Still waiting for Ollama... (0s elapsed)
# Ollama server is now available on port 11434.
#
# Pulling chevalblanc/gpt-4o-mini:latest model...
#
# Ollama pull stderr: pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest
# pulling 5f93a5c114e3: 100% ▕██████████████████▏ 6.3 GB
# pulling f8a805e9e620: 100% ▕██████████████████▏ 1.0 GB
# pulling 43070e2d4e53: 100% ▕██████████████████▏  11 KB
# pulling 79cd76eb21f8: 100% ▕██████████████████▏  251 B
# pulling cf09e81a13b6: 100% ▕██████████████████▏  528 B
# pulling f02dd72bb242: 100% ▕██████████████████▏   59 B
# pulling 66765c3d3935: 100% ▕██████████████████▏  640 B
# verifying sha256 digest
# writing manifest
# success
#
# chevalblanc/gpt-4o-mini:latest pull complete.
#
# Available Ollama models after pulling chevalblanc/gpt-4o-mini:latest:
# NAME                              ID              SIZE      MODIFIED
# chevalblanc/gpt-4o-mini:latest    4bd980651926    7.3 GB    Less than a second ago
#
#
# Checking GPU availability with nvidia-smi...
# Thu Jun 12 10:17:07 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   62C    P8             12W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Set Ollama API base URL for direct requests to: http://127.0.0.1:11434
# env: OLLAMA_MODEL_NAME=chevalblanc/gpt-4o-mini:latest
# env: OLLAMA_API_BASE_URL=http://127.0.0.1:11434

# %%
# Cell 1: Initialize Client & Confirm Server is Running
import os
import json
import pandas as pd
import numpy as np # Used later for classification_report
import matplotlib.pyplot as plt # Used later for plotting
import requests
import time
import socket
import re

# Use the API base URL from the environment variable set in Cell 0
base_url = os.getenv('OLLAMA_API_BASE_URL')
api_url_generate = f"{base_url}/api/generate" # Direct generate endpoint
api_url_show = f"{base_url}/api/show" # To check model details

print(f"Using Ollama API at: {base_url}")
print(f"Model to use: {os.getenv('OLLAMA_MODEL_NAME')}")


# Confirm server is running and model is accessible (more robust check)
def check_ollama_and_model(base_url, model_name):
    try:
        # Check if Ollama server is generally responsive
        response = requests.get(f"{base_url}/api/tags", timeout=10)
        response.raise_for_status() # Raise an exception for bad status codes
        print("Ollama server is responsive.")

        # Check if the specific model is loaded
        payload = {"name": model_name}
        response = requests.post(api_url_show, json=payload, timeout=10)
        response.raise_for_status()
        print(f"Model '{model_name}' is loaded and accessible.")
        return True
    except requests.exceptions.ConnectionError as e:
        print(f"Error: Could not connect to Ollama server at {base_url}. Please ensure it's running.")
        print(f"Details: {e}")
        return False
    except requests.exceptions.Timeout:
        print(f"Error: Request to Ollama server timed out.")
        return False
    except requests.exceptions.RequestException as e:
        print(f"Error checking Ollama or model: {e}")
        if response:
            print(f"Response status: {response.status_code}")
            print(f"Response body: {response.text}")
        return False

if not check_ollama_and_model(base_url, os.getenv('OLLAMA_MODEL_NAME')):
    raise RuntimeError("Ollama server or model not ready. Please check Cell 0 execution.")
else:
    print("Ollama server and model are ready for use.")

# Note: The OpenAI client (from `openai` library) is not directly used here
# because we're interacting with Ollama's native API via `requests` as set up.
# If you explicitly need `openai` client for `ollama` (e.g., using `ollama run --port 8000`),
# then ensure `base_url` points to that port and the `client` object is initialized.
# Out:
# Using Ollama API at: http://127.0.0.1:11434
# Model to use: chevalblanc/gpt-4o-mini:latest
# Ollama server is responsive.
# Model 'chevalblanc/gpt-4o-mini:latest' is loaded and accessible.
# Ollama server and model are ready for use.

# %%
# Cell 2: Load Full Prepared Dataset (2400 Samples) and create stratified splits
import pandas as pd
from sklearn.model_selection import train_test_split # We can use this or manual group by

# Load the already-prepared dataset. Adjust path if your file is in Google Drive.
full_df = pd.read_csv('/content/cwe_top5_sampled_with_juliet_none.csv')
total_samples = len(full_df)
print(f"Total samples in full dataset: {total_samples}")

# Validate dataset
print("Validating full dataset...")
expected_cwes = {'CWE121', 'CWE78', 'CWE122', 'CWE190', 'CWE191', 'none'}
assert set(full_df['cwe'].unique()) == expected_cwes, "Unexpected CWE values found!"
assert full_df['code'].notna().all(), "Missing code values found!"

print("\nFull dataset CWE distribution:")
print(full_df['cwe'].value_counts())

# --- Create Stratified Training and Testing Splits ---
# We need 320 samples per class for training (1920 total)
# and 80 samples per class for testing (480 total).

train_split_df = pd.DataFrame()
test_split_df = pd.DataFrame()

# Group by 'cwe' and split each group
for cwe_type in expected_cwes:
    cwe_subset = full_df[full_df['cwe'] == cwe_type].reset_index(drop=True)

    # Ensure there are enough samples for the split
    if len(cwe_subset) < (320 + 80):
        print(f"Warning: Not enough samples for CWE type '{cwe_type}'. Expected at least 400, found {len(cwe_subset)}. This might cause issues.")
        # Handle cases where there might not be 400 samples per class if necessary
        # For now, we'll proceed, but it might result in fewer than 320/80 if data is short.

    # Take the first 320 for training, and next 80 for testing for each CWE type
    train_split_df = pd.concat([train_split_df, cwe_subset.iloc[:320]])
    test_split_df = pd.concat([test_split_df, cwe_subset.iloc[320:320+80]]) # Ensure it's 320+80 if some subsets are smaller

# Shuffle the splits to randomize the order within them, important for training/batching
train_split_df = train_split_df.sample(frac=1, random_state=42).reset_index(drop=True)
test_split_df = test_split_df.sample(frac=1, random_state=42).reset_index(drop=True)


print(f"\nTraining split size: {len(train_split_df)} samples")
print("Training split CWE distribution:")
print(train_split_df['cwe'].value_counts())

print(f"\nTesting split size: {len(test_split_df)} samples")
print("Testing split CWE distribution:")
print(test_split_df['cwe'].value_counts())

print("\nSample code from training split:", train_split_df['code'].iloc[0][:100]) # Truncate for display
print("Sample code from testing split:", test_split_df['code'].iloc[0][:100])

# Display head of splits (optional)
print("\nTrain Split Head:")
print(train_split_df.head())
print("\nTest Split Head:")
print(test_split_df.head())
# Out:
# Total samples in full dataset: 2400
# Validating full dataset...
#
# Full dataset CWE distribution:
# cwe
# CWE121    400
# CWE78     400
# CWE190    400
# CWE191    400
# CWE122    400
# none      400
# Name: count, dtype: int64
#
# Training split size: 1920 samples
# Training split CWE distribution:
# cwe
# CWE121    320
# CWE78     320
# CWE122    320
# none      320
# CWE190    320
# CWE191    320
# Name: count, dtype: int64
#
# Testing split size: 480 samples
# Testing split CWE distribution:
# cwe
# CWE190    80
# CWE78     80
# none      80
# CWE121    80
# CWE191    80
# CWE122    80
# Name: count, dtype: int64
#
# Sample code from training split: #include "std_testcase.h"
# #ifndef OMITBAD
# void var()
# {
#     int data;
#     data = -1;
#     if(GLOBAL_CO
# Sample code from testing split: #include "std_testcase.h"
# unsigned int var;
# unsigned int var;
# unsigned int var;
# #ifndef OMITBAD
# void
#
# Train Split Head:
#                                                 file     cwe label  \
# 0  CWE121_Stack_Based_Buffer_Overflow__CWE129_lar...  CWE121   bad
# 1  CWE78_OS_Command_Injection__char_connect_socke...   CWE78   bad
# 2  CWE122_Heap_Based_Buffer_Overflow__c_CWE806_wc...  CWE122  good
# 3  CWE122_Heap_Based_Buffer_Overflow__c_CWE129_co...  CWE122  good
# 4  CWE122_Heap_Based_Buffer_Overflow__c_CWE806_ch...  CWE122  good
#
#                                                 code
# 0  #include "std_testcase.h"\n#ifndef OMITBAD\nvo...
# 1  #include "std_testcase.h"\n#include <wchar.h>\...
# 2  #include "std_testcase.h"\n#include <wchar.h>\...
# 3  #include "std_testcase.h"\n#ifdef _WIN32\n#inc...
# 4  #include "std_testcase.h"\n#include <wchar.h>\...
#
# Test Split Head:
#                                                 file     cwe label  \
# 0  CWE190_Integer_Overflow__unsigned_int_rand_mul...  CWE190  good
# 1  CWE78_OS_Command_Injection__wchar_t_file_w32_s...   CWE78  good
# 2                               synthetic_none_394.c    none   NaN
# 3  CWE121_Stack_Based_Buffer_Overflow__CWE805_int...  CWE121  good
# 4                               synthetic_none_399.c    none   NaN
#
#                                                 code
# 0  #include "std_testcase.h"\nunsigned int var;\n...
# 1  #include "std_testcase.h"\n#include <wchar.h>\...
# 2  int main() { char str[] = "test"; puts(str); r...
# 3  #include "std_testcase.h"\n#ifndef OMITBAD\nvo...
# 4  int main() { char str[] = "test"; puts(str); r...

# %%
# Cell 3: Define Prompt (Exact from Old Code)
# The prompt is critical for guiding the model's output to your desired JSON format.
prompt = (
    "You are a security analysis tool. Analyze the C source code for vulnerabilities and respond **only** with a JSON object containing 'reason' and 'answer' fields. Do not include any additional text, explanations, or markdown outside the JSON. Use this exact format:\n"
    "{ \"reason\": \"Explanation of vulnerability\", \"answer\": \"CWE121\" }\n"
    "The 'answer' field must be one of: 'CWE121', 'CWE78', 'CWE122', 'CWE190', 'CWE191', or 'none'. Match the 'answer' to the vulnerability type described in the 'reason'. Examples:\n"
    "- Code with `memcpy` without bounds check: { \"reason\": \"Stack-based buffer overflow due to unchecked memcpy\", \"answer\": \"CWE121\" }\n"
    "- Code with `system` using user input: { \"reason\": \"OS command injection via unsanitized input to system\", \"answer\": \"CWE78\" }\n"
    "- Code with `malloc` and overflow: { \"reason\": \"Heap-based buffer overflow due to improper malloc usage\", \"answer\": \"CWE122\" }\n"
    "- Code with large integer multiplication: { \"reason\": \"Integer overflow from unchecked multiplication\", \"answer\": \"CWE190\" }\n"
    "- Code with negative integer decrement: { \"reason\": \"Integer underflow from unchecked decrement\", \"answer\": \"CWE191\" }\n"
    "- Code with no obvious vulnerability: { \"reason\": \"No vulnerability detected\", \"answer\": \"none\" }\n"
    "Here is the code:\n\n"
)

# Apply the prompt to both training and testing splits
train_split_df['full_prompt'] = prompt + "\n\n" + train_split_df['code']
test_split_df['full_prompt'] = prompt + "\n\n" + test_split_df['code']

print("Prompt sample from training split (truncated):", train_split_df['full_prompt'].iloc[0][:500])
print("\nPrompt sample from testing split (truncated):", test_split_df['full_prompt'].iloc[0][:500])
# Out:
# Prompt sample from training split (truncated): You are a security analysis tool. Analyze the C source code for vulnerabilities and respond **only** with a JSON object containing 'reason' and 'answer' fields. Do not include any additional text, explanations, or markdown outside the JSON. Use this exact format:
# { "reason": "Explanation of vulnerability", "answer": "CWE121" }
# The 'answer' field must be one of: 'CWE121', 'CWE78', 'CWE122', 'CWE190', 'CWE191', or 'none'. Match the 'answer' to the vulnerability type described in the 'reason'. Exam
#
# Prompt sample from testing split (truncated): You are a security analysis tool. Analyze the C source code for vulnerabilities and respond **only** with a JSON object containing 'reason' and 'answer' fields. Do not include any additional text, explanations, or markdown outside the JSON. Use this exact format:
# { "reason": "Explanation of vulnerability", "answer": "CWE121" }
# The 'answer' field must be one of: 'CWE121', 'CWE78', 'CWE122', 'CWE190', 'CWE191', or 'none'. Match the 'answer' to the vulnerability type described in the 'reason'. Exam

# %%
# Cell 4: Create Backups directory and initialize response lists
from pathlib import Path
import json
import pandas as pd # Ensure pandas is imported

# Define paths for Colab environment
BACKUP_DIR = Path("/content/CodeSentinel/Backups")
RESULTS_DIR = Path("/content/CodeSentinel/Results/_2")

BACKUP_DIR.mkdir(parents=True, exist_ok=True)
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

# Define backup filenames for each split
MODEL_NAME = os.getenv('OLLAMA_MODEL_NAME').replace(':', '_').replace('/', '-') # Sanitize model name for filename
TRAIN_BACKUP_PATH = BACKUP_DIR / f"Result-{MODEL_NAME}-CWE-train.csv"
TEST_BACKUP_PATH = BACKUP_DIR / f"Result-{MODEL_NAME}-CWE-test.csv"

def save_responses(responses_list, path):
    """Saves a list of raw string responses to a CSV file."""
    print(f"Debug: Responses before saving to {path}:")
    cleaned_responses = []
    for idx, response in enumerate(responses_list):
        if pd.isna(response) or response is None:
            print(f"Response {idx} is invalid (NaN/None), replacing with fallback for saving.")
            response = json.dumps({"reason": "Invalid response", "answer": "none"})
        # Ensure it's a string representation of JSON
        if not isinstance(response, str):
            response = json.dumps(response) # Convert dicts back to string JSON if needed
        print(f"Response {idx}: {response[:100]}... (type: {type(response)})") # Truncate for print
        cleaned_responses.append(response)
    df = pd.DataFrame(cleaned_responses, columns=['raw_response_json_string'])
    df.to_csv(path, index=False)
    print(f"Responses saved to: {path}")

# Start fresh by resetting responses for both splits
training_responses = []
testing_responses = []
print("Response lists reset to empty for fresh start.")
# Out:
# Response lists reset to empty for fresh start.

# %%
# Cell 5: Run Inference Loops for Training and Testing Splits
import requests
import time
import json
import os # Make sure os is imported
from tqdm.notebook import tqdm # For nice progress bars in Colab
from sklearn.metrics import confusion_matrix, classification_report # For evaluation later

# Retrieve API details from environment variables
api_url_generate = f"{os.getenv('OLLAMA_API_BASE_URL')}/api/generate"
MODEL_NAME_FULL = os.getenv('OLLAMA_MODEL_NAME') # The full model name with colon

max_retries = 3
retry_delay = 5  # seconds
debug_mode = False # Set to True for very verbose logging per request (can slow down)

def process_dataframe_for_inference(df_to_process, response_list_target):
    """
    Processes a DataFrame, sends prompts to Ollama, and appends raw responses to a list.
    Handles retries and errors.
    """
    err_logs_local = []
    print(f"\nStarting inference for {len(df_to_process)} samples using model '{MODEL_NAME_FULL}'...")

    for index, row in tqdm(df_to_process.iterrows(), total=len(df_to_process), desc="Processing Samples"):
        attempts = 0
        success = False
        source_code = row['code'] # Use original code from row for prompt construction
        full_prompt_text = row['full_prompt'] # Use the pre-constructed full_prompt

        if debug_mode:
            print(f"\nASKED (Index {index}):")
            print(f"Source (truncated): {source_code[:200]}...")
            print(f"Full Prompt (truncated): {full_prompt_text[:300]}...")

        while attempts < max_retries and not success:
            try:
                if debug_mode:
                    print(f"Attempt {attempts + 1}: Sending request to {api_url_generate}...")
                start_time = time.time()
                payload = {
                    "model": MODEL_NAME_FULL,
                    "prompt": full_prompt_text,
                    "stream": False # We want the full response at once
                }

                if debug_mode:
                    print(f"Payload length: {len(payload['prompt'])} chars")

                response = requests.post(api_url_generate, json=payload, timeout=300) # Increased timeout to 300s (5 min) for large models/prompts
                response.raise_for_status() # Raise an error for bad status codes (4xx or 5xx)

                end_time = time.time()
                full_ollama_response = response.json()
                raw_content = full_ollama_response.get('response', '') # The actual text response from Ollama

                if debug_mode:
                    print(f"Request took {end_time - start_time:.2f} seconds")
                    print(f"Full Ollama JSON response: {json.dumps(full_ollama_response, indent=2)}")
                    print(f"Raw content from 'response' field: {raw_content[:200]}...")

                # Append the raw response string (or full JSON dict if preferred for later parsing)
                # Storing the full JSON dict ensures all metadata is preserved
                response_list_target.append(full_ollama_response)
                success = True

            except requests.RequestException as e:
                attempts += 1
                end_time = time.time()
                log_entry = {
                    "index": index,
                    "error_type": type(e).__name__,
                    "message": str(e),
                    "attempt": attempts,
                    "elapsed_time": end_time - start_time,
                    "response_status_code": getattr(response, 'status_code', 'N/A'),
                    "response_text_preview": getattr(response, 'text', 'No response')[:500]
                }
                err_logs_local.append(log_entry)
                print(f"ERROR at index {index}, attempt {attempts}/{max_retries} : {e}")
                print(f"Request failed after {end_time - start_time:.2f} seconds.")

                if attempts < max_retries:
                    print(f"Retrying in {retry_delay} seconds...")
                    time.sleep(retry_delay)
                else:
                    fallback_response_dict = {
                        "response": json.dumps({"reason": "Failed after max attempts", "answer": "none"}),
                        "status": "error",
                        "error_message": f"Max retries reached: {log_entry['message']}"
                    }
                    response_list_target.append(fallback_response_dict)
                    print(f"Max retries reached for index {index}, stored fallback response.")
            except Exception as e: # Catch any other unexpected errors
                attempts += 1
                end_time = time.time()
                log_entry = {
                    "index": index,
                    "error_type": type(e).__name__,
                    "message": str(e),
                    "attempt": attempts,
                    "elapsed_time": end_time - start_time,
                    "response_status_code": 'N/A', # No response object here
                    "response_text_preview": 'No response due to non-request error'
                }
                err_logs_local.append(log_entry)
                print(f"UNEXPECTED ERROR at index {index}, attempt {attempts}/{max_retries} : {e}")
                if attempts < max_retries:
                    print(f"Retrying in {retry_delay} seconds...")
                    time.sleep(retry_delay)
                else:
                    fallback_response_dict = {
                        "response": json.dumps({"reason": "Failed due to unexpected error", "answer": "none"}),
                        "status": "error",
                        "error_message": f"Unexpected error after max retries: {log_entry['message']}"
                    }
                    response_list_target.append(fallback_response_dict)
                    print(f"Max retries reached for index {index} due to unexpected error, stored fallback.")

    print(f"Inference loop finished. Total errors logged for this run: {len(err_logs_local)}")
    return err_logs_local

# Global error log list
all_err_logs = []

# --- Run inference for Training Split ---
print("--- Running Inference for Training Split ---")
train_err_logs = process_dataframe_for_inference(train_split_df, training_responses)
all_err_logs.extend(train_err_logs)
save_responses(training_responses, TRAIN_BACKUP_PATH)

# --- Run inference for Testing Split ---
print("\n--- Running Inference for Testing Split ---")
test_err_logs = process_dataframe_for_inference(test_split_df, testing_responses)
all_err_logs.extend(test_err_logs)
save_responses(testing_responses, TEST_BACKUP_PATH)

print("\nAll inference tasks complete.")
# Out:
# --- Running Inference for Training Split ---
#
# Starting inference for 1920 samples using model 'chevalblanc/gpt-4o-mini:latest'...
# Processing Samples:   0%|          | 0/1920 [00:00<?, ?it/s]
# Inference loop finished. Total errors logged for this run: 0
# Debug: Responses before saving to /content/CodeSentinel/Backups/Result-chevalblanc-gpt-4o-mini_latest-CWE-train.csv:
# Response 0: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:17:29.512327874Z", "respons... (type: <class 'str'>)
# Response 1: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:17:31.574245669Z", "respons... (type: <class 'str'>)
# Response 2: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:17:33.228839959Z", "respons... (type: <class 'str'>)
# Response 3: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:17:34.988382488Z", "respons... (type: <class 'str'>)
# Response 4: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:17:36.201561514Z", "respons... (type: <class 'str'>)
# Response 5: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:17:37.677946471Z", "respons... (type: <class 'str'>)
# Response 6: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:17:38.613578734Z", "respons... (type: <class 'str'>)
# Response 7: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:17:40.049893749Z", "respons... (type: <class 'str'>)
# Response 8: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:17:41.747845419Z", "respons... (type: <class 'str'>)
# Response 9: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:17:43.580684796Z", "respons... (type: <class 'str'>)
# Response 10: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:17:45.003347132Z", "respons... (type: <class 'str'>)
# Response 11: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:17:46.314024747Z", "respons... (type: <class 'str'>)
# Response 12: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:17:47.717599581Z", "respons... (type: <class 'str'>)
# Response 13: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:17:49.575355721Z", "respons... (type: <class 'str'>)
# Response 14: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:17:50.462293638Z", "respons... (type: <class 'str'>)
# Response 15: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:17:52.307497169Z", "respons... (type: <class 'str'>)
# Response 16: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:17:56.149708669Z", "respons... (type: <class 'str'>)
# Response 17: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:17:58.853028833Z", "respons... (type: <class 'str'>)
# Response 18: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:18:00.290241165Z", "respons... (type: <class 'str'>)
# Response 19: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:18:01.235238379Z", "respons... (type: <class 'str'>)
# Response 20: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:18:04.297080289Z", "respons... (type: <class 'str'>)
# Response 21: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:18:06.242176252Z", "respons... (type: <class 'str'>)
# Response 22: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:18:07.648080581Z", "respons... (type: <class 'str'>)
# Response 23: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:18:09.137607967Z", "respons... (type: <class 'str'>)
# Response 24: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:18:11.698741528Z", "respons... (type: <class 'str'>)
# Response 25: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:18:13.246540144Z", "respons... (type: <class 'str'>)
# Response 26: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:18:16.131661834Z", "respons... (type: <class 'str'>)
# Response 27: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:18:17.61341727Z", "response... (type: <class 'str'>)
# Response 28: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:18:23.842123712Z", "respons... (type: <class 'str'>)
# Response 29: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:18:25.525562339Z", "respons... (type: <class 'str'>)
# Response 30: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:18:27.024938937Z", "respons... (type: <class 'str'>)
# Response 31: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:18:30.376138303Z", "respons... (type: <class 'str'>)
# Response 32: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:18:37.850410039Z", "respons... (type: <class 'str'>)
# Response 33: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:18:39.058710548Z", "respons... (type: <class 'str'>)
# Response 34: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:18:40.779574387Z", "respons... (type: <class 'str'>)
# Response 35: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:18:41.555820954Z", "respons... (type: <class 'str'>)
# Response 36: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:18:48.778365715Z", "respons... (type: <class 'str'>)
# Response 37: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:18:50.484378837Z", "respons... (type: <class 'str'>)
# Response 38: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:18:51.286040638Z", "respons... (type: <class 'str'>)
# Response 39: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:18:52.62204943Z", "response... (type: <class 'str'>)
# Response 40: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:18:54.4955844Z", "response"... (type: <class 'str'>)
# Response 41: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:18:55.545514244Z", "respons... (type: <class 'str'>)
# Response 42: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:18:57.297088471Z", "respons... (type: <class 'str'>)
# Response 43: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:18:58.050369723Z", "respons... (type: <class 'str'>)
# Response 44: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:00.81405213Z", "response... (type: <class 'str'>)
# Response 45: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:07.842524206Z", "respons... (type: <class 'str'>)
# Response 46: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:09.187236001Z", "respons... (type: <class 'str'>)
# Response 47: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:10.200008495Z", "respons... (type: <class 'str'>)
# Response 48: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:10.937129196Z", "respons... (type: <class 'str'>)
# Response 49: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:12.850511618Z", "respons... (type: <class 'str'>)
# Response 50: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:15.220163129Z", "respons... (type: <class 'str'>)
# Response 51: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:16.960283908Z", "respons... (type: <class 'str'>)
# Response 52: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:18.711594615Z", "respons... (type: <class 'str'>)
# Response 53: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:20.080644422Z", "respons... (type: <class 'str'>)
# Response 54: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:20.929520379Z", "respons... (type: <class 'str'>)
# Response 55: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:22.378082848Z", "respons... (type: <class 'str'>)
# Response 56: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:24.883988561Z", "respons... (type: <class 'str'>)
# Response 57: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:26.464372061Z", "respons... (type: <class 'str'>)
# Response 58: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:27.982597241Z", "respons... (type: <class 'str'>)
# Response 59: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:30.13833513Z", "response... (type: <class 'str'>)
# Response 60: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:32.455853801Z", "respons... (type: <class 'str'>)
# Response 61: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:35.794791006Z", "respons... (type: <class 'str'>)
# Response 62: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:37.035939207Z", "respons... (type: <class 'str'>)
# Response 63: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:38.577703981Z", "respons... (type: <class 'str'>)
# Response 64: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:41.429789998Z", "respons... (type: <class 'str'>)
# Response 65: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:43.039851545Z", "respons... (type: <class 'str'>)
# Response 66: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:46.638207551Z", "respons... (type: <class 'str'>)
# Response 67: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:49.816909462Z", "respons... (type: <class 'str'>)
# Response 68: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:50.636725033Z", "respons... (type: <class 'str'>)
# Response 69: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:51.649135721Z", "respons... (type: <class 'str'>)
# Response 70: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:54.099441407Z", "respons... (type: <class 'str'>)
# Response 71: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:54.887390954Z", "respons... (type: <class 'str'>)
# Response 72: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:56.239460486Z", "respons... (type: <class 'str'>)
# Response 73: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:58.302570825Z", "respons... (type: <class 'str'>)
# Response 74: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:19:59.133553489Z", "respons... (type: <class 'str'>)
# Response 75: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:00.889495865Z", "respons... (type: <class 'str'>)
# Response 76: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:02.320885489Z", "respons... (type: <class 'str'>)
# Response 77: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:03.544295232Z", "respons... (type: <class 'str'>)
# Response 78: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:11.227386794Z", "respons... (type: <class 'str'>)
# Response 79: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:12.970744959Z", "respons... (type: <class 'str'>)
# Response 80: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:13.754186106Z", "respons... (type: <class 'str'>)
# Response 81: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:15.506658976Z", "respons... (type: <class 'str'>)
# Response 82: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:16.800903555Z", "respons... (type: <class 'str'>)
# Response 83: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:18.115292275Z", "respons... (type: <class 'str'>)
# Response 84: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:20.781818471Z", "respons... (type: <class 'str'>)
# Response 85: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:21.623439822Z", "respons... (type: <class 'str'>)
# Response 86: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:23.722023287Z", "respons... (type: <class 'str'>)
# Response 87: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:24.994136366Z", "respons... (type: <class 'str'>)
# Response 88: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:26.475595651Z", "respons... (type: <class 'str'>)
# Response 89: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:28.121763226Z", "respons... (type: <class 'str'>)
# Response 90: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:29.105991609Z", "respons... (type: <class 'str'>)
# Response 91: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:30.074546344Z", "respons... (type: <class 'str'>)
# Response 92: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:31.528893999Z", "respons... (type: <class 'str'>)
# Response 93: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:33.055637924Z", "respons... (type: <class 'str'>)
# Response 94: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:34.626380032Z", "respons... (type: <class 'str'>)
# Response 95: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:37.107191749Z", "respons... (type: <class 'str'>)
# Response 96: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:38.66692441Z", "response... (type: <class 'str'>)
# Response 97: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:40.0411842Z", "response"... (type: <class 'str'>)
# Response 98: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:41.845317543Z", "respons... (type: <class 'str'>)
# Response 99: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:43.66176617Z", "response... (type: <class 'str'>)
# Response 100: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:44.573864616Z", "respons... (type: <class 'str'>)
# Response 101: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:46.946470594Z", "respons... (type: <class 'str'>)
# Response 102: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:47.947422843Z", "respons... (type: <class 'str'>)
# Response 103: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:50.266445195Z", "respons... (type: <class 'str'>)
# Response 104: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:52.081405775Z", "respons... (type: <class 'str'>)
# Response 105: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:20:59.909913098Z", "respons... (type: <class 'str'>)
# Response 106: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:21:01.749931022Z", "respons... (type: <class 'str'>)
# Response 107: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:21:03.911757046Z", "respons... (type: <class 'str'>)
# Response 108: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:21:05.678277205Z", "respons... (type: <class 'str'>)
# Response 109: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:21:07.21948818Z", "response... (type: <class 'str'>)
# Response 110: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:21:09.122610838Z", "respons... (type: <class 'str'>)
# Response 111: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:21:14.030525467Z", "respons... (type: <class 'str'>)
# Response 112: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:21:15.191932228Z", "respons... (type: <class 'str'>)
# Response 113: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:21:17.282466496Z", "respons... (type: <class 'str'>)
# Response 114: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:21:20.641652307Z", "respons... (type: <class 'str'>)
# Response 115: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:21:27.726554626Z", "respons... (type: <class 'str'>)
# Response 116: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:21:29.063724281Z", "respons... (type: <class 'str'>)
# Response 117: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:21:29.850887426Z", "respons... (type: <class 'str'>)
# Response 118: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:21:31.237175898Z", "respons... (type: <class 'str'>)
# Response 119: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:21:32.914713132Z", "respons... (type: <class 'str'>)
# Response 120: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:21:39.271370109Z", "respons... (type: <class 'str'>)
# Response 121: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:21:40.727977658Z", "respons... (type: <class 'str'>)
# Response 122: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:21:43.62718452Z", "response... (type: <class 'str'>)
# Response 123: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:21:44.979799977Z", "respons... (type: <class 'str'>)
# Response 124: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:21:46.460657416Z", "respons... (type: <class 'str'>)
# Response 125: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:21:47.657369099Z", "respons... (type: <class 'str'>)
# Response 126: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:21:49.485932214Z", "respons... (type: <class 'str'>)
# Response 127: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:21:51.540592184Z", "respons... (type: <class 'str'>)
# Response 128: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:21:52.381781013Z", "respons... (type: <class 'str'>)
# Response 129: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:21:53.836872052Z", "respons... (type: <class 'str'>)
# Response 130: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:21:54.923169075Z", "respons... (type: <class 'str'>)
# Response 131: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:21:56.613094076Z", "respons... (type: <class 'str'>)
# Response 132: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:21:58.533816254Z", "respons... (type: <class 'str'>)
# Response 133: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:00.529265606Z", "respons... (type: <class 'str'>)
# Response 134: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:01.849666806Z", "respons... (type: <class 'str'>)
# Response 135: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:03.850740338Z", "respons... (type: <class 'str'>)
# Response 136: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:05.12932108Z", "response... (type: <class 'str'>)
# Response 137: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:06.604988299Z", "respons... (type: <class 'str'>)
# Response 138: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:08.570514017Z", "respons... (type: <class 'str'>)
# Response 139: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:10.387864455Z", "respons... (type: <class 'str'>)
# Response 140: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:11.78105296Z", "response... (type: <class 'str'>)
# Response 141: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:13.458559031Z", "respons... (type: <class 'str'>)
# Response 142: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:14.825233439Z", "respons... (type: <class 'str'>)
# Response 143: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:16.20950087Z", "response... (type: <class 'str'>)
# Response 144: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:18.052216684Z", "respons... (type: <class 'str'>)
# Response 145: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:18.902752041Z", "respons... (type: <class 'str'>)
# Response 146: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:19.640822751Z", "respons... (type: <class 'str'>)
# Response 147: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:20.424797292Z", "respons... (type: <class 'str'>)
# Response 148: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:25.527187464Z", "respons... (type: <class 'str'>)
# Response 149: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:28.6433173Z", "response"... (type: <class 'str'>)
# Response 150: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:30.134301297Z", "respons... (type: <class 'str'>)
# Response 151: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:33.42917785Z", "response... (type: <class 'str'>)
# Response 152: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:34.74664524Z", "response... (type: <class 'str'>)
# Response 153: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:40.566997892Z", "respons... (type: <class 'str'>)
# Response 154: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:41.961420605Z", "respons... (type: <class 'str'>)
# Response 155: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:44.058721045Z", "respons... (type: <class 'str'>)
# Response 156: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:45.161016478Z", "respons... (type: <class 'str'>)
# Response 157: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:46.491234058Z", "respons... (type: <class 'str'>)
# Response 158: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:49.633035395Z", "respons... (type: <class 'str'>)
# Response 159: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:50.953977211Z", "respons... (type: <class 'str'>)
# Response 160: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:51.937189322Z", "respons... (type: <class 'str'>)
# Response 161: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:53.544662577Z", "respons... (type: <class 'str'>)
# Response 162: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:54.789120284Z", "respons... (type: <class 'str'>)
# Response 163: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:58.444170546Z", "respons... (type: <class 'str'>)
# Response 164: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:22:59.844189076Z", "respons... (type: <class 'str'>)
# Response 165: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:23:01.092152608Z", "respons... (type: <class 'str'>)
# Response 166: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:23:02.639212441Z", "respons... (type: <class 'str'>)
# Response 167: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:23:04.62367361Z", "response... (type: <class 'str'>)
# Response 168: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:23:06.438913437Z", "respons... (type: <class 'str'>)
# Response 169: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:23:08.235010218Z", "respons... (type: <class 'str'>)
# Response 170: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:23:09.908791524Z", "respons... (type: <class 'str'>)
# Response 171: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:23:12.936629369Z", "respons... (type: <class 'str'>)
# Response 172: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:23:14.454252965Z", "respons... (type: <class 'str'>)
# Response 173: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:23:16.443970359Z", "respons... (type: <class 'str'>)
# Response 174: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:23:17.695345992Z", "respons... (type: <class 'str'>)
# Response 175: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:23:21.445101126Z", "respons... (type: <class 'str'>)
# Response 176: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:23:23.706518873Z", "respons... (type: <class 'str'>)
# Response 177: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:23:24.934684883Z", "respons... (type: <class 'str'>)
# Response 178: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:23:34.877083233Z", "respons... (type: <class 'str'>)
# Response 179: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:23:36.306307376Z", "respons... (type: <class 'str'>)
# Response 180: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:23:37.746280019Z", "respons... (type: <class 'str'>)
# Response 181: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:23:41.215754194Z", "respons... (type: <class 'str'>)
# Response 182: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:23:42.422833776Z", "respons... (type: <class 'str'>)
# Response 183: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:23:44.080662591Z", "respons... (type: <class 'str'>)
# Response 184: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:23:44.902341388Z", "respons... (type: <class 'str'>)
# Response 185: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:23:46.470005043Z", "respons... (type: <class 'str'>)
# Response 186: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:23:48.190528922Z", "respons... (type: <class 'str'>)
# Response 187: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:23:49.566965161Z", "respons... (type: <class 'str'>)
# Response 188: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:23:50.998950598Z", "respons... (type: <class 'str'>)
# Response 189: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:23:52.660271716Z", "respons... (type: <class 'str'>)
# Response 190: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:24:07.999203859Z", "respons... (type: <class 'str'>)
# Response 191: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:24:09.107487057Z", "respons... (type: <class 'str'>)
# Response 192: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:24:09.948949685Z", "respons... (type: <class 'str'>)
# Response 193: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:24:11.559752906Z", "respons... (type: <class 'str'>)
# Response 194: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:24:13.294199166Z", "respons... (type: <class 'str'>)
# Response 195: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:24:14.105926312Z", "respons... (type: <class 'str'>)
# Response 196: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:24:17.545792863Z", "respons... (type: <class 'str'>)
# Response 197: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:24:26.941304667Z", "respons... (type: <class 'str'>)
# Response 198: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:24:28.432105125Z", "respons... (type: <class 'str'>)
# Response 199: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:24:32.932901854Z", "respons... (type: <class 'str'>)
# Response 200: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:24:34.367332365Z", "respons... (type: <class 'str'>)
# Response 201: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:24:36.147876244Z", "respons... (type: <class 'str'>)
# Response 202: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:24:37.047974443Z", "respons... (type: <class 'str'>)
# Response 203: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:24:38.416726304Z", "respons... (type: <class 'str'>)
# Response 204: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:24:39.356794626Z", "respons... (type: <class 'str'>)
# Response 205: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:24:43.173468958Z", "respons... (type: <class 'str'>)
# Response 206: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:24:44.171601588Z", "respons... (type: <class 'str'>)
# Response 207: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:24:45.475677185Z", "respons... (type: <class 'str'>)
# Response 208: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:24:49.131279069Z", "respons... (type: <class 'str'>)
# Response 209: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:24:51.60482336Z", "response... (type: <class 'str'>)
# Response 210: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:24:53.497383823Z", "respons... (type: <class 'str'>)
# Response 211: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:24:55.046668156Z", "respons... (type: <class 'str'>)
# Response 212: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:24:56.314158755Z", "respons... (type: <class 'str'>)
# Response 213: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:25:00.546797883Z", "respons... (type: <class 'str'>)
# Response 214: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:25:03.081518258Z", "respons... (type: <class 'str'>)
# Response 215: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:25:05.684125644Z", "respons... (type: <class 'str'>)
# Response 216: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:25:07.448263341Z", "respons... (type: <class 'str'>)
# Response 217: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:25:08.4762847Z", "response"... (type: <class 'str'>)
# Response 218: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:25:09.289918596Z", "respons... (type: <class 'str'>)
# Response 219: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:25:10.617444214Z", "respons... (type: <class 'str'>)
# Response 220: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:25:13.769255148Z", "respons... (type: <class 'str'>)
# Response 221: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:25:15.250132088Z", "respons... (type: <class 'str'>)
# Response 222: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:25:16.374876938Z", "respons... (type: <class 'str'>)
# Response 223: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:25:20.425109903Z", "respons... (type: <class 'str'>)
# Response 224: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:25:26.859895224Z", "respons... (type: <class 'str'>)
# Response 225: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:25:28.689905539Z", "respons... (type: <class 'str'>)
# Response 226: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:25:30.751619375Z", "respons... (type: <class 'str'>)
# Response 227: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:25:44.982566249Z", "respons... (type: <class 'str'>)
# Response 228: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:25:46.959945043Z", "respons... (type: <class 'str'>)
# Response 229: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:25:50.627652774Z", "respons... (type: <class 'str'>)
# Response 230: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:25:51.945139737Z", "respons... (type: <class 'str'>)
# Response 231: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:25:55.600141355Z", "respons... (type: <class 'str'>)
# Response 232: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:25:58.574492871Z", "respons... (type: <class 'str'>)
# Response 233: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:25:59.319684903Z", "respons... (type: <class 'str'>)
# Response 234: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:26:00.701100299Z", "respons... (type: <class 'str'>)
# Response 235: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:26:02.151536654Z", "respons... (type: <class 'str'>)
# Response 236: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:26:06.873680929Z", "respons... (type: <class 'str'>)
# Response 237: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:26:08.416705937Z", "respons... (type: <class 'str'>)
# Response 238: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:26:09.833833485Z", "respons... (type: <class 'str'>)
# Response 239: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:26:10.911741521Z", "respons... (type: <class 'str'>)
# Response 240: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:26:12.618085675Z", "respons... (type: <class 'str'>)
# Response 241: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:26:13.890968878Z", "respons... (type: <class 'str'>)
# Response 242: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:26:15.695139517Z", "respons... (type: <class 'str'>)
# Response 243: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:26:16.542647612Z", "respons... (type: <class 'str'>)
# Response 244: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:26:17.356388101Z", "respons... (type: <class 'str'>)
# Response 245: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:26:18.661509669Z", "respons... (type: <class 'str'>)
# Response 246: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:26:32.795875714Z", "respons... (type: <class 'str'>)
# Response 247: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:26:34.011192682Z", "respons... (type: <class 'str'>)
# Response 248: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:26:35.171772318Z", "respons... (type: <class 'str'>)
# Response 249: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:26:36.32819125Z", "response... (type: <class 'str'>)
# Response 250: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:26:37.564571128Z", "respons... (type: <class 'str'>)
# Response 251: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:26:39.199082065Z", "respons... (type: <class 'str'>)
# Response 252: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:26:41.301567586Z", "respons... (type: <class 'str'>)
# Response 253: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:26:44.421743371Z", "respons... (type: <class 'str'>)
# Response 254: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:26:53.625699548Z", "respons... (type: <class 'str'>)
# Response 255: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:26:57.019463433Z", "respons... (type: <class 'str'>)
# Response 256: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:26:58.338255108Z", "respons... (type: <class 'str'>)
# Response 257: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:26:59.551939236Z", "respons... (type: <class 'str'>)
# Response 258: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:27:00.963240182Z", "respons... (type: <class 'str'>)
# Response 259: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:27:02.481226208Z", "respons... (type: <class 'str'>)
# Response 260: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:27:04.44748363Z", "response... (type: <class 'str'>)
# Response 261: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:27:05.500397553Z", "respons... (type: <class 'str'>)
# Response 262: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:27:06.344638374Z", "respons... (type: <class 'str'>)
# Response 263: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:27:07.787459618Z", "respons... (type: <class 'str'>)
# Response 264: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:27:09.001531739Z", "respons... (type: <class 'str'>)
# Response 265: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:27:11.704773311Z", "respons... (type: <class 'str'>)
# Response 266: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:27:14.995915787Z", "respons... (type: <class 'str'>)
# Response 267: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:27:18.250850683Z", "respons... (type: <class 'str'>)
# Response 268: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:27:19.964601537Z", "respons... (type: <class 'str'>)
# Response 269: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:27:20.751664978Z", "respons... (type: <class 'str'>)
# Response 270: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:27:22.714833828Z", "respons... (type: <class 'str'>)
# Response 271: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:27:23.675671617Z", "respons... (type: <class 'str'>)
# Response 272: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:27:25.738017588Z", "respons... (type: <class 'str'>)
# Response 273: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:27:27.110657593Z", "respons... (type: <class 'str'>)
# Response 274: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:27:28.053605447Z", "respons... (type: <class 'str'>)
# Response 275: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:27:43.143448149Z", "respons... (type: <class 'str'>)
# Response 276: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:27:44.924543438Z", "respons... (type: <class 'str'>)
# Response 277: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:27:46.468983145Z", "respons... (type: <class 'str'>)
# Response 278: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:27:47.924015314Z", "respons... (type: <class 'str'>)
# Response 279: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:27:49.621118447Z", "respons... (type: <class 'str'>)
# Response 280: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:27:51.082910825Z", "respons... (type: <class 'str'>)
# Response 281: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:27:52.812642964Z", "respons... (type: <class 'str'>)
# Response 282: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:27:55.249765999Z", "respons... (type: <class 'str'>)
# Response 283: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:28:04.151712724Z", "respons... (type: <class 'str'>)
# Response 284: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:28:04.962836701Z", "respons... (type: <class 'str'>)
# Response 285: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:28:06.104614404Z", "respons... (type: <class 'str'>)
# Response 286: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:28:07.696617186Z", "respons... (type: <class 'str'>)
# Response 287: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:28:10.887443671Z", "respons... (type: <class 'str'>)
# Response 288: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:28:12.582860308Z", "respons... (type: <class 'str'>)
# Response 289: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:28:16.083033077Z", "respons... (type: <class 'str'>)
# Response 290: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:28:17.789547309Z", "respons... (type: <class 'str'>)
# Response 291: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:28:19.339195322Z", "respons... (type: <class 'str'>)
# Response 292: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:28:20.180491175Z", "respons... (type: <class 'str'>)
# Response 293: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:28:21.474836307Z", "respons... (type: <class 'str'>)
# Response 294: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:28:31.277088038Z", "respons... (type: <class 'str'>)
# Response 295: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:28:34.656134781Z", "respons... (type: <class 'str'>)
# Response 296: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:28:36.834569086Z", "respons... (type: <class 'str'>)
# Response 297: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:28:38.886866927Z", "respons... (type: <class 'str'>)
# Response 298: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:28:40.750295463Z", "respons... (type: <class 'str'>)
# Response 299: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:28:42.002221983Z", "respons... (type: <class 'str'>)
# Response 300: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:28:42.827952945Z", "respons... (type: <class 'str'>)
# Response 301: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:28:44.125171893Z", "respons... (type: <class 'str'>)
# Response 302: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:28:46.258780514Z", "respons... (type: <class 'str'>)
# Response 303: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:28:48.058567568Z", "respons... (type: <class 'str'>)
# Response 304: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:28:49.483249518Z", "respons... (type: <class 'str'>)
# Response 305: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:28:51.072033923Z", "respons... (type: <class 'str'>)
# Response 306: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:28:52.854707018Z", "respons... (type: <class 'str'>)
# Response 307: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:28:54.067681048Z", "respons... (type: <class 'str'>)
# Response 308: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:28:56.271717344Z", "respons... (type: <class 'str'>)
# Response 309: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:28:57.237198984Z", "respons... (type: <class 'str'>)
# Response 310: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:28:58.353172852Z", "respons... (type: <class 'str'>)
# Response 311: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:28:59.625007924Z", "respons... (type: <class 'str'>)
# Response 312: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:29:01.351334822Z", "respons... (type: <class 'str'>)
# Response 313: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:29:03.694784765Z", "respons... (type: <class 'str'>)
# Response 314: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:29:05.130781116Z", "respons... (type: <class 'str'>)
# Response 315: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:29:07.157799623Z", "respons... (type: <class 'str'>)
# Response 316: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:29:11.344415317Z", "respons... (type: <class 'str'>)
# Response 317: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:29:13.295359857Z", "respons... (type: <class 'str'>)
# Response 318: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:29:14.472863652Z", "respons... (type: <class 'str'>)
# Response 319: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:29:18.187713337Z", "respons... (type: <class 'str'>)
# Response 320: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:29:20.486518085Z", "respons... (type: <class 'str'>)
# Response 321: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:29:21.532950877Z", "respons... (type: <class 'str'>)
# Response 322: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:29:22.690154191Z", "respons... (type: <class 'str'>)
# Response 323: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:29:24.050687982Z", "respons... (type: <class 'str'>)
# Response 324: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:29:25.386008314Z", "respons... (type: <class 'str'>)
# Response 325: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:29:26.825364175Z", "respons... (type: <class 'str'>)
# Response 326: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:29:27.697073291Z", "respons... (type: <class 'str'>)
# Response 327: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:29:29.700651544Z", "respons... (type: <class 'str'>)
# Response 328: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:29:31.702850061Z", "respons... (type: <class 'str'>)
# Response 329: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:29:33.179339329Z", "respons... (type: <class 'str'>)
# Response 330: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:29:35.17214162Z", "response... (type: <class 'str'>)
# Response 331: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:29:36.762279054Z", "respons... (type: <class 'str'>)
# Response 332: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:29:41.899098998Z", "respons... (type: <class 'str'>)
# Response 333: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:29:43.327430144Z", "respons... (type: <class 'str'>)
# Response 334: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:29:45.601561637Z", "respons... (type: <class 'str'>)
# Response 335: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:29:47.081000641Z", "respons... (type: <class 'str'>)
# Response 336: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:29:48.189908906Z", "respons... (type: <class 'str'>)
# Response 337: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:29:49.848834632Z", "respons... (type: <class 'str'>)
# Response 338: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:29:51.236509086Z", "respons... (type: <class 'str'>)
# Response 339: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:29:52.542301672Z", "respons... (type: <class 'str'>)
# Response 340: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T10:29:54.772368549Z", "respons... (type: <class 'str'>)
# ...
# Response 367: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:54:31.844605113Z", "respons... (type: <class 'str'>)
# Response 368: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:54:34.0381223Z", "response"... (type: <class 'str'>)
# Response 369: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:54:35.813733306Z", "respons... (type: <class 'str'>)
# Response 370: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:54:36.903052799Z", "respons... (type: <class 'str'>)
# Response 371: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:54:38.596198487Z", "respons... (type: <class 'str'>)
# Response 372: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:54:40.259511999Z", "respons... (type: <class 'str'>)
# Response 373: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:54:42.712499981Z", "respons... (type: <class 'str'>)
# Response 374: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:54:44.824282303Z", "respons... (type: <class 'str'>)
# Response 375: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:54:46.529132134Z", "respons... (type: <class 'str'>)
# Response 376: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:54:50.601956795Z", "respons... (type: <class 'str'>)
# Response 377: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:54:52.405177362Z", "respons... (type: <class 'str'>)
# Response 378: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:54:54.028124257Z", "respons... (type: <class 'str'>)
# Response 379: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:54:55.747047016Z", "respons... (type: <class 'str'>)
# Response 380: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:54:57.606943399Z", "respons... (type: <class 'str'>)
# Response 381: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:54:59.285165521Z", "respons... (type: <class 'str'>)
# Response 382: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:00.658341028Z", "respons... (type: <class 'str'>)
# Response 383: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:01.77752581Z", "response... (type: <class 'str'>)
# Response 384: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:05.971745638Z", "respons... (type: <class 'str'>)
# Response 385: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:07.842588884Z", "respons... (type: <class 'str'>)
# Response 386: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:09.700295805Z", "respons... (type: <class 'str'>)
# Response 387: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:10.845765581Z", "respons... (type: <class 'str'>)
# Response 388: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:12.968785399Z", "respons... (type: <class 'str'>)
# Response 389: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:14.955243696Z", "respons... (type: <class 'str'>)
# Response 390: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:17.610072709Z", "respons... (type: <class 'str'>)
# Response 391: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:21.745476434Z", "respons... (type: <class 'str'>)
# Response 392: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:25.802115011Z", "respons... (type: <class 'str'>)
# Response 393: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:26.87987796Z", "response... (type: <class 'str'>)
# Response 394: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:28.889219861Z", "respons... (type: <class 'str'>)
# Response 395: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:30.614531315Z", "respons... (type: <class 'str'>)
# Response 396: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:32.089506919Z", "respons... (type: <class 'str'>)
# Response 397: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:33.528644165Z", "respons... (type: <class 'str'>)
# Response 398: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:35.66955217Z", "response... (type: <class 'str'>)
# Response 399: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:37.252327241Z", "respons... (type: <class 'str'>)
# Response 400: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:39.153037899Z", "respons... (type: <class 'str'>)
# Response 401: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:40.770179195Z", "respons... (type: <class 'str'>)
# Response 402: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:41.771255233Z", "respons... (type: <class 'str'>)
# Response 403: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:43.363762456Z", "respons... (type: <class 'str'>)
# Response 404: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:46.106570533Z", "respons... (type: <class 'str'>)
# Response 405: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:47.373449008Z", "respons... (type: <class 'str'>)
# Response 406: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:49.336544798Z", "respons... (type: <class 'str'>)
# Response 407: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:51.714656778Z", "respons... (type: <class 'str'>)
# Response 408: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:53.346998793Z", "respons... (type: <class 'str'>)
# Response 409: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:55.418670137Z", "respons... (type: <class 'str'>)
# Response 410: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:56.22449659Z", "response... (type: <class 'str'>)
# Response 411: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:58.013466887Z", "respons... (type: <class 'str'>)
# Response 412: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:55:59.821506477Z", "respons... (type: <class 'str'>)
# Response 413: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:56:01.262853972Z", "respons... (type: <class 'str'>)
# Response 414: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:56:03.037638857Z", "respons... (type: <class 'str'>)
# Response 415: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:56:04.241052287Z", "respons... (type: <class 'str'>)
# Response 416: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:56:14.074529583Z", "respons... (type: <class 'str'>)
# Response 417: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:56:15.690034822Z", "respons... (type: <class 'str'>)
# Response 418: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:56:16.512135876Z", "respons... (type: <class 'str'>)
# Response 419: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:56:21.558321438Z", "respons... (type: <class 'str'>)
# Response 420: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:56:22.996008586Z", "respons... (type: <class 'str'>)
# Response 421: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:56:24.60985867Z", "response... (type: <class 'str'>)
# Response 422: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:56:29.094886838Z", "respons... (type: <class 'str'>)
# Response 423: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:56:29.953660175Z", "respons... (type: <class 'str'>)
# Response 424: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:56:30.724383256Z", "respons... (type: <class 'str'>)
# Response 425: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:56:32.341902097Z", "respons... (type: <class 'str'>)
# Response 426: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:56:33.632787001Z", "respons... (type: <class 'str'>)
# Response 427: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:56:34.873265941Z", "respons... (type: <class 'str'>)
# Response 428: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:56:44.750432281Z", "respons... (type: <class 'str'>)
# Response 429: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:56:46.323459846Z", "respons... (type: <class 'str'>)
# Response 430: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:56:47.928910944Z", "respons... (type: <class 'str'>)
# Response 431: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:56:50.915670478Z", "respons... (type: <class 'str'>)
# Response 432: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:56:52.351516702Z", "respons... (type: <class 'str'>)
# Response 433: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:56:54.358355292Z", "respons... (type: <class 'str'>)
# Response 434: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:56:56.41717681Z", "response... (type: <class 'str'>)
# Response 435: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:56:57.683245511Z", "respons... (type: <class 'str'>)
# Response 436: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:56:59.775402545Z", "respons... (type: <class 'str'>)
# Response 437: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:57:01.067436078Z", "respons... (type: <class 'str'>)
# Response 438: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:57:02.302313068Z", "respons... (type: <class 'str'>)
# Response 439: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:57:04.21880894Z", "response... (type: <class 'str'>)
# Response 440: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:57:05.839031902Z", "respons... (type: <class 'str'>)
# Response 441: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:57:07.600854343Z", "respons... (type: <class 'str'>)
# Response 442: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:57:08.41602794Z", "response... (type: <class 'str'>)
# Response 443: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:57:10.297517897Z", "respons... (type: <class 'str'>)
# Response 444: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:57:13.193131158Z", "respons... (type: <class 'str'>)
# Response 445: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:57:36.724610041Z", "respons... (type: <class 'str'>)
# Response 446: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:57:38.441851572Z", "respons... (type: <class 'str'>)
# Response 447: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:57:39.848647038Z", "respons... (type: <class 'str'>)
# Response 448: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:57:41.399903662Z", "respons... (type: <class 'str'>)
# Response 449: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:57:43.473222776Z", "respons... (type: <class 'str'>)
# Response 450: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:57:44.518234763Z", "respons... (type: <class 'str'>)
# Response 451: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:57:54.356901468Z", "respons... (type: <class 'str'>)
# Response 452: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:57:55.944928267Z", "respons... (type: <class 'str'>)
# Response 453: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:57:56.978406135Z", "respons... (type: <class 'str'>)
# Response 454: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:57:58.593269121Z", "respons... (type: <class 'str'>)
# Response 455: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:58:00.699027694Z", "respons... (type: <class 'str'>)
# Response 456: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:58:01.960323497Z", "respons... (type: <class 'str'>)
# Response 457: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:58:03.709225948Z", "respons... (type: <class 'str'>)
# Response 458: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:58:05.39760139Z", "response... (type: <class 'str'>)
# Response 459: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:58:07.191530946Z", "respons... (type: <class 'str'>)
# Response 460: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:58:09.793771248Z", "respons... (type: <class 'str'>)
# Response 461: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:58:11.228553247Z", "respons... (type: <class 'str'>)
# Response 462: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:58:12.567786621Z", "respons... (type: <class 'str'>)
# Response 463: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:58:22.845730509Z", "respons... (type: <class 'str'>)
# Response 464: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:58:23.922353358Z", "respons... (type: <class 'str'>)
# Response 465: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:58:32.241737402Z", "respons... (type: <class 'str'>)
# Response 466: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:58:40.802510265Z", "respons... (type: <class 'str'>)
# Response 467: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:58:41.857118248Z", "respons... (type: <class 'str'>)
# Response 468: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:58:43.116213485Z", "respons... (type: <class 'str'>)
# Response 469: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:58:45.95393175Z", "response... (type: <class 'str'>)
# Response 470: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:58:47.512271463Z", "respons... (type: <class 'str'>)
# Response 471: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:58:54.287003753Z", "respons... (type: <class 'str'>)
# Response 472: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:58:55.954033217Z", "respons... (type: <class 'str'>)
# Response 473: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:58:59.23745847Z", "response... (type: <class 'str'>)
# Response 474: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:59:32.868295192Z", "respons... (type: <class 'str'>)
# Response 475: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:59:34.218979248Z", "respons... (type: <class 'str'>)
# Response 476: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:59:35.029747447Z", "respons... (type: <class 'str'>)
# Response 477: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:59:36.233609849Z", "respons... (type: <class 'str'>)
# Response 478: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:59:38.66713878Z", "response... (type: <class 'str'>)
# Response 479: {"model": "chevalblanc/gpt-4o-mini:latest", "created_at": "2025-06-12T11:59:41.064262541Z", "respons... (type: <class 'str'>)
# Responses saved to: /content/CodeSentinel/Backups/Result-chevalblanc-gpt-4o-mini_latest-CWE-test.csv
#
# All inference tasks complete.

# %%
# Cell 6: Parse and Evaluate Results (Fixed Multi-Class for Both Splits & Standardized Labels)
import re
import json
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np # For formatting confusion matrix

# Function to extract JSON from Ollama's full response object (KEEP THIS AS IS from last fix)
def extract_json_from_ollama_response(ollama_response_dict):
    """
    Extracts the JSON object from Ollama's 'response' field, handling potential malformed JSON.
    Expected input: a dictionary from response.json()
    Expected output: a dictionary {"reason": ..., "answer": ...} or a fallback.
    """
    raw_response_text = ollama_response_dict.get('response', '')
    if not raw_response_text:
        return {"reason": "Empty or missing 'response' field from Ollama", "answer": "none"}

    try:
        # Find the first and last curly braces to extract the JSON string
        start = raw_response_text.find('{')
        end = raw_response_text.rfind('}') + 1

        parsed_json = None
        if start != -1 and end != -1 and start < end:
            json_string = raw_response_text[start:end]
            try:
                parsed_json = json.loads(json_string)
            except json.JSONDecodeError:
                # If substring parse fails, try parsing the whole raw_response_text
                pass # Fall through to next attempt

        if parsed_json is None: # If substring didn't work, or was empty
            try:
                parsed_json = json.loads(raw_response_text)
            except json.JSONDecodeError:
                # If full text parse fails, try fixing quotes
                fixed_text = raw_response_text.replace("'", '"')
                try:
                    parsed_json = json.loads(fixed_text)
                except json.JSONDecodeError:
                    return {"reason": f"Failed to parse JSON even after quote fix: '{raw_response_text}'", "answer": "none"}

        # --- IMPORTANT NEW LOGIC (as in previous fix) ---
        # Handle cases where the model might output JSON wrapped in an array, e.g., '[{"reason":..., "answer":...}]'
        if isinstance(parsed_json, list) and len(parsed_json) > 0 and isinstance(parsed_json[0], dict):
            return parsed_json[0] # Take the first dictionary from the list
        elif isinstance(parsed_json, dict):
            return parsed_json
        else:
            # If it's not a dict and not a list containing a dict, it's an unexpected format
            return {"reason": f"Unexpected final JSON structure after parsing: {type(parsed_json).__name__} | Raw: '{raw_response_text}'", "answer": "none"}

    except Exception as e:
        # Catch any other unexpected errors during the process
        return {"reason": f"Critical error during JSON extraction: {e} | Raw: '{raw_response_text}'", "answer": "none"}

def evaluate_results(df_original, responses_list, data_split_name):
    """
    Processes responses, calculates metrics, and prints evaluation report for a given data split.
    """
    print(f"\n--- Evaluating Results for {data_split_name} Split ({len(responses_list)} samples) ---")

    if not responses_list:
        print(f"No responses to evaluate for {data_split_name} split.")
        return

    # Create a DataFrame for model answers
    model_answers_dicts = [extract_json_from_ollama_response(res_dict) for res_dict in responses_list]
    model_answers_df = pd.DataFrame(model_answers_dicts)

    # Ensure model_answer and model_reason columns exist, providing defaults
    model_answers_df['model_answer_raw'] = model_answers_df['answer'].fillna('none').astype(str)
    model_answers_df['model_reason'] = model_answers_df['reason'].fillna('No reason provided').astype(str)

    # --- NEW LOGIC: Standardize Model Answers ---
    # Define our target labels explicitly
    target_labels = ['CWE121', 'CWE78', 'CWE122', 'CWE190', 'CWE191', 'none']

    def standardize_label(raw_label):
        # Convert to string and uppercase for easier matching
        label = str(raw_label).upper()

        # Check for exact matches
        if label in target_labels:
            return label

        # Check for 'none' variations
        if 'NO VULNERABILITY' in label or 'NONE' == label.strip():
            return 'none'

        # Check for specific CWE patterns
        if 'CWE121' in label:
            return 'CWE121'
        if 'CWE78' in label:
            return 'CWE78'
        if 'CWE122' in label:
            return 'CWE122'
        if 'CWE190' in label:
            return 'CWE190'
        if 'CWE191' in label:
            return 'CWE191'

        # If none of the above, default to 'none' or log it as an issue
        return 'none'

    # Apply the standardization
    model_answers_df['model_answer'] = model_answers_df['model_answer_raw'].apply(standardize_label)

    # Join with the original DataFrame subset to get true labels and other info
    combined_df = df_original.reset_index(drop=True).copy()
    combined_df['model_answer'] = model_answers_df['model_answer']
    combined_df['model_reason'] = model_answers_df['model_reason']
    combined_df['model_answer_raw'] = model_answers_df['model_answer_raw'] # Keep raw for debugging

    # Compute verdict
    combined_df['verdict'] = combined_df['cwe'] == combined_df['model_answer']

    # Compute multi-class metrics
    true_labels = combined_df['cwe']
    pred_labels = combined_df['model_answer']

    # Define all possible labels explicitly for consistent report and matrix
    all_labels = sorted(list(set(target_labels))) # Use target_labels directly for consistency

    # Accuracy (overall accuracy)
    accuracy = combined_df['verdict'].mean()
    print(f"Accuracy ({data_split_name}): {accuracy:.3f}")

    # Confusion Matrix
    cm = confusion_matrix(true_labels, pred_labels, labels=all_labels)
    print(f"\nConfusion Matrix ({data_split_name}):")
    print("Labels order:", all_labels)
    # --- CUSTOM CONFUSION MATRIX PRINTING ---
    cm_list = cm.tolist()
    # Determine maximum width for each number to align columns
    # We add 1 for potential leading space if a number is negative (though unlikely for CM counts)
    max_widths = [max(len(str(item)) for item in col) for col in zip(*cm_list)]

    for row in cm_list:
        formatted_row = []
        for i, item in enumerate(row):
            formatted_row.append(f"{item:>{max_widths[i]}}") # Right-align each number within its max width
        print(f"[{' '.join(formatted_row)}]") # Join with space, wrap in brackets


    # Classification Report
    report = classification_report(true_labels, pred_labels, labels=all_labels, zero_division=0)
    print(f"\nClassification Report ({data_split_name}):")
    print(report)

    # Save filtered results
    output_filename_base = f"Result-{MODEL_NAME}-{data_split_name}-CWE.csv"
    output_path = RESULTS_DIR / output_filename_base
    filtered_df_output = combined_df[['cwe', 'model_answer', 'model_answer_raw', 'verdict', 'model_reason', 'file', 'code']]
    filtered_df_output.to_csv(output_path, index=False)
    print(f"Filtered results saved to '{output_path}'")

# --- Perform evaluation for each split ---
evaluate_results(train_split_df, training_responses, "Training")
evaluate_results(test_split_df, testing_responses, "Testing")

if all_err_logs:
    print("\n--- Consolidated Error Log ---")
    for log_entry in all_err_logs:
        print(f"Index: {log_entry['index']}, Error Type: {log_entry['error_type']}, Message: {log_entry['message']}")
        if log_entry.get('response_status_code') != 'N/A':
            print(f"  Status: {log_entry['response_status_code']}, Preview: {log_entry['response_text_preview']}")
else:
    print("\nNo errors logged during inference.")
# Out:
# --- Evaluating Results for Training Split (1920 samples) ---
# Accuracy (Training): 0.497
#
# Confusion Matrix (Training):
# Labels order: ['CWE121', 'CWE122', 'CWE190', 'CWE191', 'CWE78', 'none']
# [128 104  5  3   8  72]
# [ 79 175  4  2   5  55]
# [ 58  61 91 15   8  87]
# [ 65  79 30 59   4  83]
# [  7   0  2  0 281  30]
# [ 51  10 10  2  26 221]
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#       CWE121       0.33      0.40      0.36       320
#       CWE122       0.41      0.55      0.47       320
#       CWE190       0.64      0.28      0.39       320
#       CWE191       0.73      0.18      0.29       320
#        CWE78       0.85      0.88      0.86       320
#         none       0.40      0.69      0.51       320
#
#     accuracy                           0.50      1920
#    macro avg       0.56      0.50      0.48      1920
# weighted avg       0.56      0.50      0.48      1920
#
# Filtered results saved to '/content/CodeSentinel/Results/_2/Result-chevalblanc-gpt-4o-mini_latest-Training-CWE.csv'
#
# --- Evaluating Results for Testing Split (480 samples) ---
# Accuracy (Testing): 0.504
#
# Confusion Matrix (Testing):
# Labels order: ['CWE121', 'CWE122', 'CWE190', 'CWE191', 'CWE78', 'none']
# [33 26  0  0  0 21]
# [15 52  0  0  1 12]
# [16 24 20  2  2 16]
# [15 22  7 16  1 19]
# [ 1  0  0  1 68 10]
# [16  2  2  0  7 53]
#
# Classification Report (Testing):
#               precision    recall  f1-score   support
#
#       CWE121       0.34      0.41      0.38        80
#       CWE122       0.41      0.65      0.50        80
#       CWE190       0.69      0.25      0.37        80
#       CWE191       0.84      0.20      0.32        80
#        CWE78       0.86      0.85      0.86        80
#         none       0.40      0.66      0.50        80
#
#     accuracy                           0.50       480
#    macro avg       0.59      0.50      0.49       480
# weighted avg       0.59      0.50      0.49       480
#
# Filtered results saved to '/content/CodeSentinel/Results/_2/Result-chevalblanc-gpt-4o-mini_latest-Testing-CWE.csv'
#
# No errors logged during inference.
